# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # Top-N analysis using ranking window functions
# © ExploreAI Academy

# %% [markdown]
# In this notebook, we explore the use of ranking functions to order the elements in our database table based on a certain criterion.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn:
# - How to use the `ROW_NUMBER()` and `RANK()` functions to perform partition-wise ranking operations.
# - How the ranking results of these two functions differ from each other.

# %% [markdown]
# ## Overview
#
# Let's say we want to quickly order the countries from worst to best in terms of levels of access to drinking water services per year.
#
# We can use Top-N analysis which focuses on identifying and analysing the highest-ranked elements in a dataset based on a specific criterion. The criterion in our case is ‘levels of access to managed drinking water services per year.’
#
# **SQL ranking functions** will be useful in this case.

# %% [markdown]
# ## Connecting to our MySQL database
#
# We will use our `Access_to_Basic_Services` table in our `united_nations` database that we created in MySQL Workbench. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:Kofi1999$@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %% [markdown]
# ## Exercise

# %% [markdown]
# Let's enter the following base query which selects the three columns we will be using from our `Access_to_Basic_Services` table: `Country_name`, `Time_period`, and `Pct_managed_drinking_water_services`.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services
# FROM
#     united_nations.Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Kazakhstan', 2015, Decimal('94.67')),
#  ('Kazakhstan', 2016, Decimal('94.67')),
#  ('Kazakhstan', 2017, Decimal('95.00')),
#  ('Kazakhstan', 2018, Decimal('95.00')),
#  ('Kazakhstan', 2019, Decimal('95.00')),
#  ('Kazakhstan', 2020, Decimal('95.00')),
#  ('Kyrgyzstan', 2015, Decimal('89.67')),
#  ('Kyrgyzstan', 2016, Decimal('90.33')),
#  ('Kyrgyzstan', 2017, Decimal('91.00')),
#  ('Kyrgyzstan', 2018, Decimal('91.33')),
#  ('Kyrgyzstan', 2019, Decimal('91.67')),
#  ('Kyrgyzstan', 2020, Decimal('92.67')),
#  ('Tajikistan', 2015, Decimal('80.33')),
#  ('Tajikistan', 2016, Decimal('81.33')),
#  ('Tajikistan', 2017, Decimal('82.33')),
#  ('Tajikistan', 2018, Decimal('83.33')),
#  ('Tajikistan', 2019, Decimal('85.00')),
#  ('Tajikistan', 2020, Decimal('85.00')),
#  ('Turkmenistan', 2015, Decimal('97.67')),
#  ('Turkmenistan', 2016, Decimal('98.00')),
#  ('Turkmenistan', 2017, Decimal('98.67')),
#  ('Turkmenistan', 2018, Decimal('99.33')),
#  ('Turkmenistan', 2019, Decimal('100.00')),
#  ('Turkmenistan', 2020, Decimal('100.00')),
#  ('Uzbekistan', 2015, Decimal('97.67')),
#  ('Uzbekistan', 2016, Decimal('97.67')),
#  ('Uzbekistan', 2017, Decimal('98.00')),
#  ('Uzbekistan', 2018, Decimal('98.00')),
#  ('Uzbekistan', 2019, Decimal('98.00')),
#  ('Uzbekistan', 2020, Decimal('98.00')),
#  ('Afghanistan', 2015, Decimal('67.00')),
#  ('Afghanistan', 2016, Decimal('69.67')),
#  ('Afghanistan', 2017, Decimal('72.33')),
#  ('Afghanistan', 2018, Decimal('75.33')),
#  ('Afghanistan', 2019, Decimal('78.00')),
#  ('Afghanistan', 2020, Decimal('80.33')),
#  ('Bangladesh', 2015, Decimal('97.33')),
#  ('Bangladesh', 2016, Decimal('97.33')),
#  ('Bangladesh', 2017, Decimal('97.33')),
#  ('Bangladesh', 2018, Decimal('97.33')),
#  ('Bangladesh', 2019, Decimal('97.67')),
#  ('Bangladesh', 2020, Decimal('97.67')),
#  ('Bhutan', 2015, Decimal('96.33')),
#  ('Bhutan', 2016, Decimal('97.00')),
#  ('Bhutan', 2017, Decimal('97.33')),
#  ('Bhutan', 2018, Decimal('97.33')),
#  ('Bhutan', 2019, Decimal('97.33')),
#  ('Bhutan', 2020, Decimal('97.33')),
#  ('India', 2015, Decimal('89.00')),
#  ('India', 2016, Decimal('89.33')),
#  ('India', 2017, Decimal('90.00')),
#  ('India', 2018, Decimal('90.33')),
#  ('India', 2019, Decimal('90.67')),
#  ('India', 2020, Decimal('91.00')),
#  ('Iran (Islamic Republic of)', 2015, Decimal('95.67')),
#  ('Iran (Islamic Republic of)', 2016, Decimal('96.00')),
#  ('Iran (Islamic Republic of)', 2017, Decimal('96.33')),
#  ('Iran (Islamic Republic of)', 2018, Decimal('96.33')),
#  ('Iran (Islamic Republic of)', 2019, Decimal('96.33')),
#  ('Iran (Islamic Republic of)', 2020, Decimal('96.67')),
#  ('Maldives', 2015, Decimal('99.00')),
#  ('Maldives', 2016, Decimal('99.00')),
#  ('Maldives', 2017, Decimal('99.33')),
#  ('Maldives', 2018, Decimal('99.33')),
#  ('Maldives', 2019, Decimal('99.67')),
#  ('Maldives', 2020, Decimal('99.67')),
#  ('Nepal', 2015, Decimal('88.33')),
#  ('Nepal', 2016, Decimal('88.67')),
#  ('Nepal', 2017, Decimal('89.00')),
#  ('Nepal', 2018, Decimal('89.33')),
#  ('Nepal', 2019, Decimal('90.00')),
#  ('Nepal', 2020, Decimal('90.00')),
#  ('Pakistan', 2015, Decimal('90.00')),
#  ('Pakistan', 2016, Decimal('90.00')),
#  ('Pakistan', 2017, Decimal('90.33')),
#  ('Pakistan', 2018, Decimal('90.33')),
#  ('Pakistan', 2019, Decimal('90.33')),
#  ('Pakistan', 2020, Decimal('90.67')),
#  ('Sri Lanka', 2015, Decimal('92.00')),
#  ('Sri Lanka', 2016, Decimal('93.00')),
#  ('Sri Lanka', 2017, Decimal('93.67')),
#  ('Sri Lanka', 2018, Decimal('94.33')),
#  ('Sri Lanka', 2019, Decimal('94.33')),
#  ('Sri Lanka', 2020, Decimal('94.33')),
#  ('China', 2015, Decimal('91.33')),
#  ('China', 2016, Decimal('91.33')),
#  ('China', 2017, Decimal('92.00')),
#  ('China', 2018, Decimal('92.67')),
#  ('China', 2019, Decimal('93.33')),
#  ('China', 2020, Decimal('93.67')),
#  ("Democratic People's Republic of Korea", 2015, Decimal('94.67')),
#  ("Democratic People's Republic of Korea", 2016, Decimal('94.33')),
#  ("Democratic People's Republic of Korea", 2017, Decimal('94.00')),
#  ("Democratic People's Republic of Korea", 2018, Decimal('93.33')),
#  ("Democratic People's Republic of Korea", 2019, Decimal('93.33')),
#  ("Democratic People's Republic of Korea", 2020, Decimal('93.33')),
#  ('Japan', 2015, Decimal('99.00')),
#  ('Japan', 2016, Decimal('99.00')),
#  ('Japan', 2017, Decimal('99.00')),
#  ('Japan', 2018, Decimal('99.00')),
#  ('Japan', 2019, Decimal('99.00')),
#  ('Japan', 2020, Decimal('99.00')),
#  ('Mongolia', 2015, Decimal('75.67')),
#  ('Mongolia', 2016, Decimal('77.00')),
#  ('Mongolia', 2017, Decimal('78.00')),
#  ('Mongolia', 2018, Decimal('79.00')),
#  ('Mongolia', 2019, Decimal('80.00')),
#  ('Mongolia', 2020, Decimal('81.00')),
#  ('Republic of Korea', 2015, Decimal('99.00')),
#  ('Republic of Korea', 2016, Decimal('100.00')),
#  ('Republic of Korea', 2017, Decimal('100.00')),
#  ('Republic of Korea', 2018, Decimal('100.00')),
#  ('Republic of Korea', 2019, Decimal('100.00')),
#  ('Republic of Korea', 2020, Decimal('100.00')),
#  ('Brunei Darussalam', 2015, Decimal('99.67')),
#  ('Brunei Darussalam', 2016, Decimal('100.00')),
#  ('Brunei Darussalam', 2017, Decimal('100.00')),
#  ('Brunei Darussalam', 2018, Decimal('100.00')),
#  ('Brunei Darussalam', 2019, Decimal('100.00')),
#  ('Brunei Darussalam', 2020, Decimal('100.00')),
#  ('Cambodia', 2015, Decimal('73.33')),
#  ('Cambodia', 2016, Decimal('73.67')),
#  ('Cambodia', 2017, Decimal('74.33')),
#  ('Cambodia', 2018, Decimal('74.67')),
#  ('Cambodia', 2019, Decimal('75.33')),
#  ('Cambodia', 2020, Decimal('75.33')),
#  ('Indonesia', 2015, Decimal('88.33')),
#  ('Indonesia', 2016, Decimal('89.00')),
#  ('Indonesia', 2017, Decimal('89.67')),
#  ('Indonesia', 2018, Decimal('90.67')),
#  ('Indonesia', 2019, Decimal('91.33')),
#  ('Indonesia', 2020, Decimal('92.00')),
#  ("Lao People's Democratic Republic", 2015, Decimal('79.67')),
#  ("Lao People's Democratic Republic", 2016, Decimal('82.00')),
#  ("Lao People's Democratic Republic", 2017, Decimal('83.33')),
#  ("Lao People's Democratic Republic", 2018, Decimal('85.00')),
#  ("Lao People's Democratic Republic", 2019, Decimal('86.67')),
#  ("Lao People's Democratic Republic", 2020, Decimal('86.67')),
#  ('Malaysia', 2015, Decimal('95.67')),
#  ('Malaysia', 2016, Decimal('95.67')),
#  ('Malaysia', 2017, Decimal('95.67')),
#  ('Malaysia', 2018, Decimal('95.33')),
#  ('Malaysia', 2019, Decimal('95.33')),
#  ('Malaysia', 2020, Decimal('95.33')),
#  ('Myanmar', 2015, Decimal('76.33')),
#  ('Myanmar', 2016, Decimal('78.33')),
#  ('Myanmar', 2017, Decimal('80.33')),
#  ('Myanmar', 2018, Decimal('82.33')),
#  ('Myanmar', 2019, Decimal('84.00')),
#  ('Myanmar', 2020, Decimal('85.67')),
#  ('Philippines', 2015, Decimal('92.00')),
#  ('Philippines', 2016, Decimal('92.67')),
#  ('Philippines', 2017, Decimal('93.00')),
#  ('Philippines', 2018, Decimal('93.33')),
#  ('Philippines', 2019, Decimal('93.67')),
#  ('Philippines', 2020, Decimal('94.00')),
#  ('Singapore', 2015, Decimal('100.00')),
#  ('Singapore', 2016, Decimal('100.00')),
#  ('Singapore', 2017, Decimal('100.00')),
#  ('Singapore', 2018, Decimal('100.00')),
#  ('Singapore', 2019, Decimal('100.00')),
#  ('Singapore', 2020, Decimal('100.00')),
#  ('Thailand', 2015, Decimal('99.33')),
#  ('Thailand', 2016, Decimal('99.33')),
#  ('Thailand', 2017, Decimal('100.00')),
#  ('Thailand', 2018, Decimal('100.00')),
#  ('Thailand', 2019, Decimal('100.00')),
#  ('Thailand', 2020, Decimal('100.00')),
#  ('Timor-Leste', 2015, Decimal('78.00')),
#  ('Timor-Leste', 2016, Decimal('80.67')),
#  ('Timor-Leste', 2017, Decimal('82.33')),
#  ('Timor-Leste', 2018, Decimal('84.33')),
#  ('Timor-Leste', 2019, Decimal('86.00')),
#  ('Timor-Leste', 2020, Decimal('87.00')),
#  ('Viet Nam', 2015, Decimal('94.00')),
#  ('Viet Nam', 2016, Decimal('95.00')),
#  ('Viet Nam', 2017, Decimal('95.67')),
#  ('Viet Nam', 2018, Decimal('96.33')),
#  ('Viet Nam', 2019, Decimal('96.67')),
#  ('Viet Nam', 2020, Decimal('97.33')),
#  ('Bermuda', 2015, Decimal('100.00')),
#  ('Bermuda', 2016, Decimal('100.00')),
#  ('Bermuda', 2017, Decimal('100.00')),
#  ('Bermuda', 2018, Decimal('100.00')),
#  ('Bermuda', 2019, Decimal('100.00')),
#  ('Bermuda', 2020, Decimal('100.00')),
#  ('Canada', 2015, Decimal('99.00')),
#  ('Canada', 2016, Decimal('99.00')),
#  ('Canada', 2017, Decimal('99.00')),
#  ('Canada', 2018, Decimal('99.00')),
#  ('Canada', 2019, Decimal('99.00')),
#  ('Canada', 2020, Decimal('99.00')),
#  ('Greenland', 2015, Decimal('100.00')),
#  ('Greenland', 2016, Decimal('100.00')),
#  ('Greenland', 2017, Decimal('100.00')),
#  ('Greenland', 2018, Decimal('100.00')),
#  ('Greenland', 2019, Decimal('100.00')),
#  ('Greenland', 2020, Decimal('100.00')),
#  ('Saint Pierre and Miquelon', 2015, Decimal('91.00')),
#  ('Saint Pierre and Miquelon', 2016, Decimal('91.00')),
#  ('Saint Pierre and Miquelon', 2017, Decimal('91.00')),
#  ('Saint Pierre and Miquelon', 2018, Decimal('91.00')),
#  ('Saint Pierre and Miquelon', 2019, Decimal('91.00')),
#  ('Saint Pierre and Miquelon', 2020, Decimal('91.00')),
#  ('United States of America', 2015, Decimal('99.00')),
#  ('United States of America', 2016, Decimal('99.33')),
#  ('United States of America', 2017, Decimal('99.67')),
#  ('United States of America', 2018, Decimal('99.67')),
#  ('United States of America', 2019, Decimal('99.67')),
#  ('United States of America', 2020, Decimal('100.00')),
#  ('Anguilla', 2015, Decimal('97.00')),
#  ('Anguilla', 2016, Decimal('97.00')),
#  ('Anguilla', 2017, Decimal('97.00')),
#  ('Antigua and Barbuda', 2015, Decimal('97.00')),
#  ('Antigua and Barbuda', 2016, Decimal('97.00')),
#  ('Antigua and Barbuda', 2017, Decimal('97.00')),
#  ('Aruba', 2015, Decimal('98.00')),
#  ('Aruba', 2016, Decimal('98.00')),
#  ('Bahamas', 2015, Decimal('99.00')),
#  ('Bahamas', 2016, Decimal('99.00')),
#  ('Bahamas', 2017, Decimal('99.00')),
#  ('Bahamas', 2018, Decimal('99.00')),
#  ('Bahamas', 2019, Decimal('99.00')),
#  ('Barbados', 2015, Decimal('98.00')),
#  ('Barbados', 2016, Decimal('98.00')),
#  ('Barbados', 2017, Decimal('98.00')),
#  ('Barbados', 2018, Decimal('99.00')),
#  ('Barbados', 2019, Decimal('99.00')),
#  ('Barbados', 2020, Decimal('99.00')),
#  ('British Virgin Islands', 2015, Decimal('100.00')),
#  ('British Virgin Islands', 2016, Decimal('100.00')),
#  ('British Virgin Islands', 2017, Decimal('100.00')),
#  ('British Virgin Islands', 2018, Decimal('100.00')),
#  ('British Virgin Islands', 2019, Decimal('100.00')),
#  ('British Virgin Islands', 2020, Decimal('100.00')),
#  ('Cayman Islands', 2015, Decimal('96.00')),
#  ('Cayman Islands', 2016, Decimal('96.00')),
#  ('Cuba', 2015, Decimal('94.67')),
#  ('Cuba', 2016, Decimal('95.00')),
#  ('Cuba', 2017, Decimal('95.33')),
#  ('Cuba', 2018, Decimal('96.00')),
#  ('Cuba', 2019, Decimal('96.33')),
#  ('Cuba', 2020, Decimal('96.33')),
#  ('Curaçao', 2015, Decimal('99.00')),
#  ('Curaçao', 2016, Decimal('99.00')),
#  ('Curaçao', 2017, Decimal('99.00')),
#  ('Dominica', 2015, Decimal('95.00')),
#  ('Dominica', 2016, Decimal('95.00')),
#  ('Dominica', 2017, Decimal('95.00')),
#  ('Dominican Republic', 2015, Decimal('94.33')),
#  ('Dominican Republic', 2016, Decimal('94.67')),
#  ('Dominican Republic', 2017, Decimal('94.67')),
#  ('Dominican Republic', 2018, Decimal('95.00')),
#  ('Dominican Republic', 2019, Decimal('95.00')),
#  ('Dominican Republic', 2020, Decimal('95.00')),
#  ('Grenada', 2015, Decimal('96.00')),
#  ('Grenada', 2016, Decimal('96.00')),
#  ('Grenada', 2017, Decimal('96.00')),
#  ('Guadeloupe', 2015, Decimal('100.00')),
#  ('Guadeloupe', 2016, Decimal('100.00')),
#  ('Guadeloupe', 2017, Decimal('100.00')),
#  ('Guadeloupe', 2018, Decimal('100.00')),
#  ('Guadeloupe', 2019, Decimal('100.00')),
#  ('Guadeloupe', 2020, Decimal('100.00')),
#  ('Haiti', 2015, Decimal('64.00')),
#  ('Haiti', 2016, Decimal('64.33')),
#  ('Haiti', 2017, Decimal('64.33')),
#  ('Haiti', 2018, Decimal('64.67')),
#  ('Haiti', 2019, Decimal('64.67')),
#  ('Haiti', 2020, Decimal('65.00')),
#  ('Jamaica', 2015, Decimal('90.00')),
#  ('Jamaica', 2016, Decimal('90.33')),
#  ('Jamaica', 2017, Decimal('90.33')),
#  ('Jamaica', 2018, Decimal('90.33')),
#  ('Jamaica', 2019, Decimal('90.33')),
#  ('Jamaica', 2020, Decimal('90.33')),
#  ('Martinique', 2015, Decimal('100.00')),
#  ('Martinique', 2016, Decimal('100.00')),
#  ('Martinique', 2017, Decimal('100.00')),
#  ('Martinique', 2018, Decimal('100.00')),
#  ('Martinique', 2019, Decimal('100.00')),
#  ('Martinique', 2020, Decimal('100.00')),
#  ('Montserrat', 2015, Decimal('98.00')),
#  ('Montserrat', 2016, Decimal('98.00')),
#  ('Montserrat', 2017, Decimal('98.00')),
#  ('Montserrat', 2018, Decimal('98.00')),
#  ('Montserrat', 2019, Decimal('98.00')),
#  ('Montserrat', 2020, Decimal('98.00')),
#  ('Puerto Rico', 2015, Decimal('99.00')),
#  ('Puerto Rico', 2016, Decimal('100.00')),
#  ('Puerto Rico', 2017, Decimal('100.00')),
#  ('Puerto Rico', 2018, Decimal('100.00')),
#  ('Puerto Rico', 2019, Decimal('100.00')),
#  ('Puerto Rico', 2020, Decimal('100.00')),
#  ('Saint Barthélemy', 2015, Decimal('100.00')),
#  ('Saint Barthélemy', 2016, Decimal('100.00')),
#  ('Saint Barthélemy', 2017, Decimal('100.00')),
#  ('Saint Barthélemy', 2018, Decimal('100.00')),
#  ('Saint Barthélemy', 2019, Decimal('100.00')),
#  ('Saint Barthélemy', 2020, Decimal('100.00')),
#  ('Saint Kitts and Nevis', 2015, Decimal('99.00')),
#  ('Saint Kitts and Nevis', 2016, Decimal('99.00')),
#  ('Saint Kitts and Nevis', 2017, Decimal('99.00')),
#  ('Saint Lucia', 2015, Decimal('96.00')),
#  ('Saint Lucia', 2016, Decimal('96.33')),
#  ('Saint Lucia', 2017, Decimal('96.33')),
#  ('Saint Lucia', 2018, Decimal('97.00')),
#  ('Saint Lucia', 2019, Decimal('97.00')),
#  ('Saint Lucia', 2020, Decimal('97.00')),
#  ('Saint Martin (French Part)', 2015, Decimal('100.00')),
#  ('Saint Martin (French Part)', 2016, Decimal('100.00')),
#  ('Saint Martin (French Part)', 2017, Decimal('100.00')),
#  ('Saint Martin (French Part)', 2018, Decimal('100.00')),
#  ('Saint Martin (French Part)', 2019, Decimal('100.00')),
#  ('Saint Martin (French Part)', 2020, Decimal('100.00')),
#  ('Saint Vincent and the Grenadines', 2015, Decimal('95.00')),
#  ('Saint Vincent and the Grenadines', 2016, Decimal('95.00')),
#  ('Saint Vincent and the Grenadines', 2017, Decimal('95.00')),
#  ('Saint Vincent and the Grenadines', 2018, Decimal('95.00')),
#  ('Sint Maarten (Dutch part)', 2015, Decimal('95.00')),
#  ('Sint Maarten (Dutch part)', 2016, Decimal('95.00')),
#  ('Sint Maarten (Dutch part)', 2017, Decimal('95.00')),
#  ('Trinidad and Tobago', 2015, Decimal('98.00')),
#  ('Trinidad and Tobago', 2016, Decimal('99.00')),
#  ('Trinidad and Tobago', 2017, Decimal('99.00')),
#  ('Trinidad and Tobago', 2018, Decimal('99.00')),
#  ('Trinidad and Tobago', 2019, Decimal('99.00')),
#  ('Trinidad and Tobago', 2020, Decimal('99.00')),
#  ('Turks and Caicos Islands', 2015, Decimal('94.00')),
#  ('Turks and Caicos Islands', 2016, Decimal('94.00')),
#  ('Turks and Caicos Islands', 2017, Decimal('94.00')),
#  ('Turks and Caicos Islands', 2018, Decimal('94.00')),
#  ('United States Virgin Islands', 2015, Decimal('99.00')),
#  ('United States Virgin Islands', 2016, Decimal('99.00')),
#  ('United States Virgin Islands', 2017, Decimal('99.00')),
#  ('United States Virgin Islands', 2018, Decimal('99.00')),
#  ('United States Virgin Islands', 2019, Decimal('99.00')),
#  ('United States Virgin Islands', 2020, Decimal('99.00')),
#  ('Belize', 2015, Decimal('97.33')),
#  ('Belize', 2016, Decimal('97.67')),
#  ('Belize', 2017, Decimal('98.00')),
#  ('Belize', 2018, Decimal('98.33')),
#  ('Belize', 2019, Decimal('98.33')),
#  ('Belize', 2020, Decimal('98.33')),
#  ('Costa Rica', 2015, Decimal('99.00')),
#  ('Costa Rica', 2016, Decimal('99.67')),
#  ('Costa Rica', 2017, Decimal('100.00')),
#  ('Costa Rica', 2018, Decimal('100.00')),
#  ('Costa Rica', 2019, Decimal('100.00')),
#  ('Costa Rica', 2020, Decimal('100.00')),
#  ('El Salvador', 2015, Decimal('94.33')),
#  ('El Salvador', 2016, Decimal('95.33')),
#  ('El Salvador', 2017, Decimal('96.00')),
#  ('El Salvador', 2018, Decimal('97.00')),
#  ('El Salvador', 2019, Decimal('97.00')),
#  ('El Salvador', 2020, Decimal('97.00')),
#  ('Guatemala', 2015, Decimal('92.00')),
#  ('Guatemala', 2016, Decimal('92.33')),
#  ('Guatemala', 2017, Decimal('92.67')),
#  ('Guatemala', 2018, Decimal('93.00')),
#  ('Guatemala', 2019, Decimal('94.00')),
#  ('Guatemala', 2020, Decimal('94.00')),
#  ('Honduras', 2015, Decimal('92.67')),
#  ('Honduras', 2016, Decimal('93.33')),
#  ('Honduras', 2017, Decimal('93.67')),
#  ('Honduras', 2018, Decimal('94.33')),
#  ('Honduras', 2019, Decimal('94.67')),
#  ('Honduras', 2020, Decimal('95.33')),
#  ('Mexico', 2015, Decimal('96.67')),
#  ('Mexico', 2016, Decimal('97.33')),
#  ('Mexico', 2017, Decimal('98.00')),
#  ('Mexico', 2018, Decimal('98.33')),
#  ('Mexico', 2019, Decimal('98.67')),
#  ('Mexico', 2020, Decimal('99.33')),
#  ('Nicaragua', 2015, Decimal('79.33')),
#  ('Nicaragua', 2016, Decimal('79.00')),
#  ('Nicaragua', 2017, Decimal('79.00')),
#  ('Nicaragua', 2018, Decimal('79.33')),
#  ('Nicaragua', 2019, Decimal('79.33')),
#  ('Nicaragua', 2020, Decimal('79.33')),
#  ('Panama', 2015, Decimal('91.67')),
#  ('Panama', 2016, Decimal('91.67')),
#  ('Panama', 2017, Decimal('92.33')),
#  ('Panama', 2018, Decimal('92.33')),
#  ('Panama', 2019, Decimal('92.67')),
#  ('Panama', 2020, Decimal('92.67')),
#  ('Argentina', 2015, Decimal('97.33')),
#  ('Argentina', 2016, Decimal('97.33')),
#  ('Argentina', 2017, Decimal('100.00')),
#  ('Argentina', 2018, Decimal('100.00')),
#  ('Argentina', 2019, Decimal('100.00')),
#  ('Argentina', 2020, Decimal('100.00')),
#  ('Bolivia (Plurinational State of)', 2015, Decimal('87.33')),
#  ('Bolivia (Plurinational State of)', 2016, Decimal('88.00')),
#  ('Bolivia (Plurinational State of)', 2017, Decimal('89.00')),
#  ('Bolivia (Plurinational State of)', 2018, Decimal('89.67')),
#  ('Bolivia (Plurinational State of)', 2019, Decimal('90.33')),
#  ('Bolivia (Plurinational State of)', 2020, Decimal('90.67')),
#  ('Brazil', 2015, Decimal('95.33')),
#  ('Brazil', 2016, Decimal('95.33')),
#  ('Brazil', 2017, Decimal('96.33')),
#  ('Brazil', 2018, Decimal('97.00')),
#  ('Brazil', 2019, Decimal('97.33')),
#  ('Brazil', 2020, Decimal('98.33')),
#  ('Chile', 2015, Decimal('99.00')),
#  ('Chile', 2016, Decimal('99.67')),
#  ('Chile', 2017, Decimal('100.00')),
#  ('Chile', 2018, Decimal('100.00')),
#  ('Chile', 2019, Decimal('100.00')),
#  ('Chile', 2020, Decimal('100.00')),
#  ('Colombia', 2015, Decimal('93.00')),
#  ('Colombia', 2016, Decimal('93.67')),
#  ('Colombia', 2017, Decimal('94.00')),
#  ('Colombia', 2018, Decimal('94.00')),
#  ('Colombia', 2019, Decimal('94.33')),
#  ('Colombia', 2020, Decimal('94.67')),
#  ('Ecuador', 2015, Decimal('91.67')),
#  ('Ecuador', 2016, Decimal('92.33')),
#  ('Ecuador', 2017, Decimal('92.67')),
#  ('Ecuador', 2018, Decimal('93.33')),
#  ('Ecuador', 2019, Decimal('93.67')),
#  ('Ecuador', 2020, Decimal('94.00')),
#  ('Falkland Islands (Malvinas)', 2015, Decimal('91.00')),
#  ('Falkland Islands (Malvinas)', 2016, Decimal('91.00')),
#  ('Falkland Islands (Malvinas)', 2017, Decimal('91.00')),
#  ('Falkland Islands (Malvinas)', 2018, Decimal('91.00')),
#  ('Falkland Islands (Malvinas)', 2019, Decimal('91.00')),
#  ('Falkland Islands (Malvinas)', 2020, Decimal('91.00')),
#  ('French Guiana', 2015, Decimal('94.00')),
#  ('French Guiana', 2016, Decimal('94.00')),
#  ('French Guiana', 2017, Decimal('94.00')),
#  ('French Guiana', 2018, Decimal('94.00')),
#  ('French Guiana', 2019, Decimal('94.00')),
#  ('French Guiana', 2020, Decimal('94.00')),
#  ('Guyana', 2015, Decimal('96.00')),
#  ('Guyana', 2016, Decimal('96.67')),
#  ('Guyana', 2017, Decimal('96.67')),
#  ('Guyana', 2018, Decimal('96.67')),
#  ('Guyana', 2019, Decimal('96.67')),
#  ('Guyana', 2020, Decimal('96.67')),
#  ('Paraguay', 2015, Decimal('96.33')),
#  ('Paraguay', 2016, Decimal('97.67')),
#  ('Paraguay', 2017, Decimal('99.33')),
#  ('Paraguay', 2018, Decimal('99.67')),
#  ('Paraguay', 2019, Decimal('99.67')),
#  ('Paraguay', 2020, Decimal('99.67')),
#  ('Peru', 2015, Decimal('86.00')),
#  ('Peru', 2016, Decimal('87.33')),
#  ('Peru', 2017, Decimal('87.67')),
#  ('Peru', 2018, Decimal('88.67')),
#  ('Peru', 2019, Decimal('89.33')),
#  ('Peru', 2020, Decimal('90.33')),
#  ('Suriname', 2015, Decimal('95.00')),
#  ('Suriname', 2016, Decimal('95.33')),
#  ('Suriname', 2017, Decimal('96.33')),
#  ('Suriname', 2018, Decimal('96.67')),
#  ('Suriname', 2019, Decimal('97.33')),
#  ('Suriname', 2020, Decimal('98.00')),
#  ('Uruguay', 2015, Decimal('96.67')),
#  ('Uruguay', 2016, Decimal('97.33')),
#  ('Uruguay', 2017, Decimal('98.00')),
#  ('Uruguay', 2018, Decimal('98.00')),
#  ('Uruguay', 2019, Decimal('98.00')),
#  ('Uruguay', 2020, Decimal('98.00')),
#  ('Venezuela (Bolivarian Republic of)', 2015, Decimal('95.00')),
#  ('Venezuela (Bolivarian Republic of)', 2016, Decimal('94.00')),
#  ('Venezuela (Bolivarian Republic of)', 2017, Decimal('94.00')),
#  ('Venezuela (Bolivarian Republic of)', 2018, Decimal('94.00')),
#  ('Venezuela (Bolivarian Republic of)', 2019, Decimal('94.00')),
#  ('Venezuela (Bolivarian Republic of)', 2020, Decimal('94.00')),
#  ('Algeria', 2015, Decimal('92.00')),
#  ('Algeria', 2016, Decimal('93.00')),
#  ('Algeria', 2017, Decimal('93.00')),
#  ('Algeria', 2018, Decimal('93.00')),
#  ('Algeria', 2019, Decimal('93.33')),
#  ('Algeria', 2020, Decimal('93.33')),
#  ('Egypt', 2015, Decimal('99.33')),
#  ('Egypt', 2016, Decimal('99.33')),
#  ('Egypt', 2017, Decimal('99.33')),
#  ('Egypt', 2018, Decimal('99.33')),
#  ('Egypt', 2019, Decimal('99.33')),
#  ('Egypt', 2020, Decimal('99.33')),
#  ('Libya', 2015, Decimal('97.00')),
#  ('Libya', 2016, Decimal('98.00')),
#  ('Libya', 2017, Decimal('99.00')),
#  ('Libya', 2018, Decimal('100.00')),
#  ('Libya', 2019, Decimal('100.00')),
#  ('Libya', 2020, Decimal('100.00')),
#  ('Morocco', 2015, Decimal('81.33')),
#  ('Morocco', 2016, Decimal('83.00')),
#  ('Morocco', 2017, Decimal('84.00')),
#  ('Morocco', 2018, Decimal('85.67')),
#  ('Morocco', 2019, Decimal('87.33')),
#  ('Morocco', 2020, Decimal('88.33')),
#  ('Sudan', 2015, Decimal('61.33')),
#  ('Sudan', 2016, Decimal('62.33')),
#  ('Sudan', 2017, Decimal('62.33')),
#  ('Sudan', 2018, Decimal('62.33')),
#  ('Sudan', 2019, Decimal('62.33')),
#  ('Sudan', 2020, Decimal('62.33')),
#  ('Tunisia', 2015, Decimal('93.33')),
#  ('Tunisia', 2016, Decimal('93.67')),
#  ('Tunisia', 2017, Decimal('94.67')),
#  ('Tunisia', 2018, Decimal('95.67')),
#  ('Tunisia', 2019, Decimal('96.00')),
#  ('Tunisia', 2020, Decimal('97.00')),
#  ('Armenia', 2015, Decimal('99.67')),
#  ('Armenia', 2016, Decimal('99.67')),
#  ('Armenia', 2017, Decimal('100.00')),
#  ('Armenia', 2018, Decimal('100.00')),
#  ('Armenia', 2019, Decimal('100.00')),
#  ('Armenia', 2020, Decimal('100.00')),
#  ('Azerbaijan', 2015, Decimal('91.67')),
#  ('Azerbaijan', 2016, Decimal('92.33')),
#  ('Azerbaijan', 2017, Decimal('93.67')),
#  ('Azerbaijan', 2018, Decimal('94.33')),
#  ('Azerbaijan', 2019, Decimal('95.00')),
#  ('Azerbaijan', 2020, Decimal('95.67')),
#  ('Bahrain', 2015, Decimal('100.00')),
#  ('Bahrain', 2016, Decimal('100.00')),
#  ('Bahrain', 2017, Decimal('100.00')),
#  ('Bahrain', 2018, Decimal('100.00')),
#  ('Bahrain', 2019, Decimal('100.00')),
#  ('Bahrain', 2020, Decimal('100.00')),
#  ('Cyprus', 2015, Decimal('100.00')),
#  ('Cyprus', 2016, Decimal('100.00')),
#  ('Cyprus', 2017, Decimal('100.00')),
#  ('Cyprus', 2018, Decimal('100.00')),
#  ('Cyprus', 2019, Decimal('100.00')),
#  ('Cyprus', 2020, Decimal('100.00')),
#  ('Georgia', 2015, Decimal('95.33')),
#  ('Georgia', 2016, Decimal('96.00')),
#  ('Georgia', 2017, Decimal('96.67')),
#  ('Georgia', 2018, Decimal('96.67')),
#  ('Georgia', 2019, Decimal('96.67')),
#  ('Georgia', 2020, Decimal('96.67')),
#  ('Iraq', 2015, Decimal('92.33')),
#  ('Iraq', 2016, Decimal('93.67')),
#  ('Iraq', 2017, Decimal('94.67')),
#  ('Iraq', 2018, Decimal('95.67')),
#  ('Iraq', 2019, Decimal('97.00')),
#  ('Iraq', 2020, Decimal('97.67')),
#  ('Israel', 2015, Decimal('100.00')),
#  ('Israel', 2016, Decimal('100.00')),
#  ('Israel', 2017, Decimal('100.00')),
#  ('Israel', 2018, Decimal('100.00')),
#  ('Israel', 2019, Decimal('100.00')),
#  ('Israel', 2020, Decimal('100.00')),
#  ('Jordan', 2015, Decimal('98.33')),
#  ('Jordan', 2016, Decimal('98.33')),
#  ('Jordan', 2017, Decimal('98.33')),
#  ('Jordan', 2018, Decimal('98.33')),
#  ('Jordan', 2019, Decimal('98.33')),
#  ('Jordan', 2020, Decimal('98.33')),
#  ('Kuwait', 2015, Decimal('100.00')),
#  ('Kuwait', 2016, Decimal('100.00')),
#  ('Kuwait', 2017, Decimal('100.00')),
#  ('Kuwait', 2018, Decimal('100.00')),
#  ('Kuwait', 2019, Decimal('100.00')),
#  ('Kuwait', 2020, Decimal('100.00')),
#  ('Lebanon', 2015, Decimal('91.00')),
#  ('Lebanon', 2016, Decimal('92.00')),
#  ('Lebanon', 2017, Decimal('92.00')),
#  ('Lebanon', 2018, Decimal('92.00')),
#  ('Lebanon', 2019, Decimal('93.00')),
#  ('Lebanon', 2020, Decimal('93.00')),
#  ('Oman', 2015, Decimal('86.00')),
#  ('Oman', 2016, Decimal('86.67')),
#  ('Oman', 2017, Decimal('86.67')),
#  ('Oman', 2018, Decimal('87.00')),
#  ('Oman', 2019, Decimal('87.67')),
#  ('Oman', 2020, Decimal('87.67')),
#  ('Qatar', 2015, Decimal('100.00')),
#  ('Qatar', 2016, Decimal('100.00')),
#  ('Qatar', 2017, Decimal('100.00')),
#  ('Qatar', 2018, Decimal('100.00')),
#  ('Qatar', 2019, Decimal('100.00')),
#  ('Qatar', 2020, Decimal('100.00')),
#  ('Saudi Arabia', 2015, Decimal('100.00')),
#  ('Saudi Arabia', 2016, Decimal('100.00')),
#  ('Saudi Arabia', 2017, Decimal('100.00')),
#  ('Saudi Arabia', 2018, Decimal('100.00')),
#  ('Saudi Arabia', 2019, Decimal('100.00')),
#  ('Saudi Arabia', 2020, Decimal('100.00')),
#  ('State of Palestine', 2015, Decimal('96.00')),
#  ('State of Palestine', 2016, Decimal('96.67')),
#  ('State of Palestine', 2017, Decimal('97.00')),
#  ('State of Palestine', 2018, Decimal('97.00')),
#  ('State of Palestine', 2019, Decimal('97.67')),
#  ('State of Palestine', 2020, Decimal('98.33')),
#  ('Syrian Arab Republic', 2015, Decimal('93.33')),
#  ('Syrian Arab Republic', 2016, Decimal('93.67')),
#  ('Syrian Arab Republic', 2017, Decimal('93.67')),
#  ('Syrian Arab Republic', 2018, Decimal('93.67')),
#  ('Syrian Arab Republic', 2019, Decimal('93.67')),
#  ('Syrian Arab Republic', 2020, Decimal('93.67')),
#  ('Türkiye', 2015, Decimal('95.67')),
#  ('Türkiye', 2016, Decimal('96.00')),
#  ('Türkiye', 2017, Decimal('96.33')),
#  ('Türkiye', 2018, Decimal('96.33')),
#  ('Türkiye', 2019, Decimal('96.67')),
#  ('Türkiye', 2020, Decimal('96.67')),
#  ('United Arab Emirates', 2015, Decimal('100.00')),
#  ('United Arab Emirates', 2016, Decimal('100.00')),
#  ('United Arab Emirates', 2017, Decimal('100.00')),
#  ('United Arab Emirates', 2018, Decimal('100.00')),
#  ('United Arab Emirates', 2019, Decimal('100.00')),
#  ('United Arab Emirates', 2020, Decimal('100.00')),
#  ('Yemen', 2015, Decimal('59.00')),
#  ('Yemen', 2016, Decimal('59.67')),
#  ('Yemen', 2017, Decimal('60.33')),
#  ('Yemen', 2018, Decimal('61.33')),
#  ('Yemen', 2019, Decimal('62.33')),
#  ('Yemen', 2020, Decimal('63.00')),
#  ('Australia', 2015, Decimal('100.00')),
#  ('Australia', 2016, Decimal('100.00')),
#  ('Australia', 2017, Decimal('100.00')),
#  ('Australia', 2018, Decimal('100.00')),
#  ('Australia', 2019, Decimal('100.00')),
#  ('Australia', 2020, Decimal('100.00')),
#  ('New Zealand', 2015, Decimal('100.00')),
#  ('New Zealand', 2016, Decimal('100.00')),
#  ('New Zealand', 2017, Decimal('100.00')),
#  ('New Zealand', 2018, Decimal('100.00')),
#  ('New Zealand', 2019, Decimal('100.00')),
#  ('New Zealand', 2020, Decimal('100.00')),
#  ('Fiji', 2015, Decimal('93.67')),
#  ('Fiji', 2016, Decimal('93.67')),
#  ('Fiji', 2017, Decimal('93.67')),
#  ('Fiji', 2018, Decimal('93.67')),
#  ('Fiji', 2019, Decimal('93.67')),
#  ('Fiji', 2020, Decimal('93.67')),
#  ('New Caledonia', 2015, Decimal('98.00')),
#  ('New Caledonia', 2016, Decimal('98.00')),
#  ('New Caledonia', 2017, Decimal('99.00')),
#  ('New Caledonia', 2018, Decimal('99.00')),
#  ('New Caledonia', 2019, Decimal('99.00')),
#  ('New Caledonia', 2020, Decimal('99.00')),
#  ('Papua New Guinea', 2015, Decimal('53.67')),
#  ('Papua New Guinea', 2016, Decimal('54.33')),
#  ('Papua New Guinea', 2017, Decimal('55.00')),
#  ('Papua New Guinea', 2018, Decimal('55.67')),
#  ('Papua New Guinea', 2019, Decimal('56.33')),
#  ('Papua New Guinea', 2020, Decimal('56.67')),
#  ('Solomon Islands', 2015, Decimal('74.33')),
#  ('Solomon Islands', 2016, Decimal('74.00')),
#  ('Solomon Islands', 2017, Decimal('73.33')),
#  ('Solomon Islands', 2018, Decimal('72.33')),
#  ('Solomon Islands', 2019, Decimal('72.33')),
#  ('Solomon Islands', 2020, Decimal('72.33')),
#  ('Vanuatu', 2015, Decimal('92.00')),
#  ('Vanuatu', 2016, Decimal('92.67')),
#  ('Vanuatu', 2017, Decimal('93.00')),
#  ('Vanuatu', 2018, Decimal('93.00')),
#  ('Vanuatu', 2019, Decimal('93.00')),
#  ('Vanuatu', 2020, Decimal('93.00')),
#  ('Guam', 2015, Decimal('100.00')),
#  ('Guam', 2016, Decimal('100.00')),
#  ('Guam', 2017, Decimal('100.00')),
#  ('Guam', 2018, Decimal('100.00')),
#  ('Guam', 2019, Decimal('100.00')),
#  ('Guam', 2020, Decimal('100.00')),
#  ('Kiribati', 2015, Decimal('73.67')),
#  ('Kiribati', 2016, Decimal('74.33')),
#  ('Kiribati', 2017, Decimal('75.00')),
#  ('Kiribati', 2018, Decimal('75.33')),
#  ('Kiribati', 2019, Decimal('76.00')),
#  ('Kiribati', 2020, Decimal('77.00')),
#  ('Marshall Islands', 2015, Decimal('89.33')),
#  ('Marshall Islands', 2016, Decimal('89.67')),
#  ('Marshall Islands', 2017, Decimal('89.67')),
#  ('Marshall Islands', 2018, Decimal('90.00')),
#  ('Marshall Islands', 2019, Decimal('90.00')),
#  ('Marshall Islands', 2020, Decimal('90.00')),
#  ('Micronesia (Federated States of)', 2015, Decimal('88.00')),
#  ('Micronesia (Federated States of)', 2016, Decimal('88.00')),
#  ('Micronesia (Federated States of)', 2017, Decimal('88.00')),
#  ('Micronesia (Federated States of)', 2018, Decimal('88.00')),
#  ('Micronesia (Federated States of)', 2019, Decimal('88.00')),
#  ('Nauru', 2015, Decimal('100.00')),
#  ('Nauru', 2016, Decimal('100.00')),
#  ('Nauru', 2017, Decimal('100.00')),
#  ('Nauru', 2018, Decimal('100.00')),
#  ('Nauru', 2019, Decimal('100.00')),
#  ('Nauru', 2020, Decimal('100.00')),
#  ('Northern Mariana Islands', 2015, Decimal('100.00')),
#  ('Northern Mariana Islands', 2016, Decimal('100.00')),
#  ('Northern Mariana Islands', 2017, Decimal('100.00')),
#  ('Northern Mariana Islands', 2018, Decimal('100.00')),
#  ('Northern Mariana Islands', 2019, Decimal('100.00')),
#  ('Northern Mariana Islands', 2020, Decimal('100.00')),
#  ('Palau', 2015, Decimal('100.00')),
#  ('Palau', 2016, Decimal('100.00')),
#  ('Palau', 2017, Decimal('100.00')),
#  ('Palau', 2018, Decimal('100.00')),
#  ('Palau', 2019, Decimal('100.00')),
#  ('Palau', 2020, Decimal('100.00')),
#  ('American Samoa', 2015, Decimal('100.00')),
#  ('American Samoa', 2016, Decimal('100.00')),
#  ('American Samoa', 2017, Decimal('100.00')),
#  ('American Samoa', 2018, Decimal('100.00')),
#  ('American Samoa', 2019, Decimal('100.00')),
#  ('American Samoa', 2020, Decimal('100.00')),
#  ('Cook Islands', 2015, Decimal('100.00')),
#  ('Cook Islands', 2016, Decimal('100.00')),
#  ('Cook Islands', 2017, Decimal('100.00')),
#  ('Cook Islands', 2018, Decimal('100.00')),
#  ('Cook Islands', 2019, Decimal('100.00')),
#  ('Cook Islands', 2020, Decimal('100.00')),
#  ('French Polynesia', 2015, Decimal('100.00')),
#  ('French Polynesia', 2016, Decimal('100.00')),
#  ('French Polynesia', 2017, Decimal('100.00')),
#  ('French Polynesia', 2018, Decimal('100.00')),
#  ('French Polynesia', 2019, Decimal('100.00')),
#  ('French Polynesia', 2020, Decimal('100.00')),
#  ('Niue', 2015, Decimal('98.00')),
#  ('Niue', 2016, Decimal('97.00')),
#  ('Niue', 2017, Decimal('97.00')),
#  ('Niue', 2018, Decimal('97.00')),
#  ('Niue', 2019, Decimal('97.00')),
#  ('Niue', 2020, Decimal('97.00')),
#  ('Samoa', 2015, Decimal('91.00')),
#  ('Samoa', 2016, Decimal('92.00')),
#  ('Samoa', 2017, Decimal('92.00')),
#  ('Samoa', 2018, Decimal('92.00')),
#  ('Samoa', 2019, Decimal('92.00')),
#  ('Samoa', 2020, Decimal('92.00')),
#  ('Tokelau', 2015, Decimal('99.00')),
#  ('Tokelau', 2016, Decimal('100.00')),
#  ('Tokelau', 2017, Decimal('100.00')),
#  ('Tokelau', 2018, Decimal('100.00')),
#  ('Tokelau', 2019, Decimal('100.00')),
#  ('Tokelau', 2020, Decimal('100.00')),
#  ('Tonga', 2015, Decimal('98.67')),
#  ('Tonga', 2016, Decimal('98.67')),
#  ('Tonga', 2017, Decimal('98.67')),
#  ('Tonga', 2018, Decimal('98.67')),
#  ('Tonga', 2019, Decimal('98.67')),
#  ('Tonga', 2020, Decimal('99.00')),
#  ('Tuvalu', 2015, Decimal('100.00')),
#  ('Tuvalu', 2016, Decimal('100.00')),
#  ('Tuvalu', 2017, Decimal('100.00')),
#  ('Tuvalu', 2018, Decimal('100.00')),
#  ('Tuvalu', 2019, Decimal('100.00')),
#  ('Tuvalu', 2020, Decimal('100.00')),
#  ('Wallis and Futuna Islands', 2015, Decimal('99.00')),
#  ('Wallis and Futuna Islands', 2016, Decimal('99.00')),
#  ('Wallis and Futuna Islands', 2017, Decimal('99.00')),
#  ('Wallis and Futuna Islands', 2018, Decimal('99.00')),
#  ('Wallis and Futuna Islands', 2019, Decimal('99.00')),
#  ('Wallis and Futuna Islands', 2020, Decimal('99.00')),
#  ('Burundi', 2015, Decimal('68.33')),
#  ('Burundi', 2016, Decimal('68.33')),
#  ('Burundi', 2017, Decimal('69.33')),
#  ('Burundi', 2018, Decimal('69.33')),
#  ('Burundi', 2019, Decimal('70.33')),
#  ('Burundi', 2020, Decimal('70.33')),
#  ('Comoros', 2015, Decimal('81.67')),
#  ('Comoros', 2016, Decimal('81.67')),
#  ('Comoros', 2017, Decimal('81.67')),
#  ('Comoros', 2018, Decimal('81.67')),
#  ('Comoros', 2019, Decimal('81.67')),
#  ('Djibouti', 2015, Decimal('69.67')),
#  ('Djibouti', 2016, Decimal('69.33')),
#  ('Djibouti', 2017, Decimal('69.33')),
#  ('Djibouti', 2018, Decimal('69.33')),
#  ('Djibouti', 2019, Decimal('69.00')),
#  ('Djibouti', 2020, Decimal('69.00')),
#  ('Eritrea', 2015, Decimal('56.33')),
#  ('Eritrea', 2016, Decimal('56.67')),
#  ('Ethiopia', 2015, Decimal('52.00')),
#  ('Ethiopia', 2016, Decimal('53.33')),
#  ('Ethiopia', 2017, Decimal('54.67')),
#  ('Ethiopia', 2018, Decimal('55.67')),
#  ('Ethiopia', 2019, Decimal('57.00')),
#  ('Ethiopia', 2020, Decimal('58.00')),
#  ('Kenya', 2015, Decimal('64.33')),
#  ('Kenya', 2016, Decimal('65.00')),
#  ('Kenya', 2017, Decimal('65.67')),
#  ('Kenya', 2018, Decimal('65.67')),
#  ('Kenya', 2019, Decimal('66.33')),
#  ('Kenya', 2020, Decimal('67.00')),
#  ('Madagascar', 2015, Decimal('53.33')),
#  ('Madagascar', 2016, Decimal('54.00')),
#  ('Madagascar', 2017, Decimal('54.67')),
#  ('Madagascar', 2018, Decimal('55.33')),
#  ('Madagascar', 2019, Decimal('56.00')),
#  ('Madagascar', 2020, Decimal('56.33')),
#  ('Malawi', 2015, Decimal('71.33')),
#  ('Malawi', 2016, Decimal('72.00')),
#  ('Malawi', 2017, Decimal('72.67')),
#  ('Malawi', 2018, Decimal('73.33')),
#  ('Malawi', 2019, Decimal('73.67')),
#  ('Malawi', 2020, Decimal('74.33')),
#  ('Mauritius', 2015, Decimal('100.00')),
#  ('Mauritius', 2016, Decimal('100.00')),
#  ('Mauritius', 2017, Decimal('100.00')),
#  ('Mauritius', 2018, Decimal('100.00')),
#  ('Mauritius', 2019, Decimal('100.00')),
#  ('Mauritius', 2020, Decimal('100.00')),
#  ('Mayotte', 2015, Decimal('97.00')),
#  ('Mayotte', 2016, Decimal('97.00')),
#  ('Mayotte', 2017, Decimal('97.00')),
#  ('Mayotte', 2018, Decimal('96.00')),
#  ('Mayotte', 2019, Decimal('96.00')),
#  ('Mayotte', 2020, Decimal('96.00')),
#  ('Mozambique', 2015, Decimal('55.67')),
#  ('Mozambique', 2016, Decimal('58.00')),
#  ('Mozambique', 2017, Decimal('60.00')),
#  ('Mozambique', 2018, Decimal('62.33')),
#  ('Mozambique', 2019, Decimal('64.33')),
#  ('Mozambique', 2020, Decimal('66.67')),
#  ('Rwanda', 2015, Decimal('63.00')),
#  ('Rwanda', 2016, Decimal('64.00')),
#  ('Rwanda', 2017, Decimal('65.00')),
#  ('Rwanda', 2018, Decimal('65.67')),
#  ('Rwanda', 2019, Decimal('66.33')),
#  ('Rwanda', 2020, Decimal('66.33')),
#  ('Réunion', 2015, Decimal('100.00')),
#  ('Réunion', 2016, Decimal('100.00')),
#  ('Réunion', 2017, Decimal('100.00')),
#  ('Réunion', 2018, Decimal('100.00')),
#  ('Réunion', 2019, Decimal('100.00')),
#  ('Réunion', 2020, Decimal('100.00')),
#  ('Seychelles', 2015, Decimal('96.00')),
#  ('Seychelles', 2016, Decimal('96.00')),
#  ('Seychelles', 2017, Decimal('96.00')),
#  ('Seychelles', 2018, Decimal('96.00')),
#  ('Seychelles', 2019, Decimal('97.00')),
#  ('Somalia', 2015, Decimal('50.67')),
#  ('Somalia', 2016, Decimal('52.00')),
#  ('Somalia', 2017, Decimal('53.33')),
#  ('Somalia', 2018, Decimal('54.67')),
#  ('Somalia', 2019, Decimal('56.33')),
#  ('Somalia', 2020, Decimal('57.33')),
#  ('South Sudan', 2015, Decimal('46.33')),
#  ('South Sudan', 2016, Decimal('46.67')),
#  ('South Sudan', 2017, Decimal('47.00')),
#  ('South Sudan', 2018, Decimal('47.67')),
#  ('South Sudan', 2019, Decimal('48.33')),
#  ('South Sudan', 2020, Decimal('48.33')),
#  ('Uganda', 2015, Decimal('55.00')),
#  ('Uganda', 2016, Decimal('55.67')),
#  ('Uganda', 2017, Decimal('57.00')),
#  ('Uganda', 2018, Decimal('58.67')),
#  ('Uganda', 2019, Decimal('59.33')),
#  ('Uganda', 2020, Decimal('61.00')),
#  ('United Republic of Tanzania', 2015, Decimal('58.33')),
#  ('United Republic of Tanzania', 2016, Decimal('60.00')),
#  ('United Republic of Tanzania', 2017, Decimal('61.67')),
#  ('United Republic of Tanzania', 2018, Decimal('63.33')),
#  ('United Republic of Tanzania', 2019, Decimal('64.67')),
#  ('United Republic of Tanzania', 2020, Decimal('65.00')),
#  ('Zambia', 2015, Decimal('63.67')),
#  ('Zambia', 2016, Decimal('64.33')),
#  ('Zambia', 2017, Decimal('64.67')),
#  ('Zambia', 2018, Decimal('65.33')),
#  ('Zambia', 2019, Decimal('66.33')),
#  ('Zambia', 2020, Decimal('66.67')),
#  ('Zimbabwe', 2015, Decimal('70.00')),
#  ('Zimbabwe', 2016, Decimal('69.33')),
#  ('Zimbabwe', 2017, Decimal('69.00')),
#  ('Zimbabwe', 2018, Decimal('68.67')),
#  ('Zimbabwe', 2019, Decimal('68.33')),
#  ('Zimbabwe', 2020, Decimal('68.00')),
#  ('Angola', 2015, Decimal('50.33')),
#  ('Angola', 2016, Decimal('51.00')),
#  ('Angola', 2017, Decimal('51.33')),
#  ('Angola', 2018, Decimal('52.33')),
#  ('Angola', 2019, Decimal('52.33')),
#  ('Angola', 2020, Decimal('52.33')),
#  ('Cameroon', 2015, Decimal('62.67')),
#  ('Cameroon', 2016, Decimal('62.67')),
#  ('Cameroon', 2017, Decimal('63.33')),
#  ('Cameroon', 2018, Decimal('63.33')),
#  ('Cameroon', 2019, Decimal('63.33')),
#  ('Cameroon', 2020, Decimal('64.00')),
#  ('Central African Republic', 2015, Decimal('44.00')),
#  ('Central African Republic', 2016, Decimal('42.67')),
#  ('Central African Republic', 2017, Decimal('41.33')),
#  ('Central African Republic', 2018, Decimal('40.67')),
#  ('Central African Republic', 2019, Decimal('39.33')),
#  ('Central African Republic', 2020, Decimal('38.33')),
#  ('Chad', 2015, Decimal('51.67')),
#  ('Chad', 2016, Decimal('52.00')),
#  ('Chad', 2017, Decimal('52.00')),
#  ('Chad', 2018, Decimal('52.00')),
#  ('Chad', 2019, Decimal('52.33')),
#  ('Chad', 2020, Decimal('52.67')),
#  ('Congo', 2015, Decimal('66.33')),
#  ('Congo', 2016, Decimal('67.67')),
#  ('Congo', 2017, Decimal('68.67')),
#  ('Congo', 2018, Decimal('68.67')),
#  ('Congo', 2019, Decimal('69.00')),
#  ('Congo', 2020, Decimal('69.00')),
#  ('Democratic Republic of the Congo', 2015, Decimal('45.33')),
#  ('Democratic Republic of the Congo', 2016, Decimal('45.67')),
#  ('Democratic Republic of the Congo', 2017, Decimal('46.00')),
#  ('Democratic Republic of the Congo', 2018, Decimal('46.67')),
#  ('Democratic Republic of the Congo', 2019, Decimal('47.00')),
#  ('Democratic Republic of the Congo', 2020, Decimal('47.67')),
#  ('Equatorial Guinea', 2015, Decimal('57.67')),
#  ('Equatorial Guinea', 2016, Decimal('57.67')),
#  ('Equatorial Guinea', 2017, Decimal('58.00')),
#  ('Gabon', 2015, Decimal('72.00')),
#  ('Gabon', 2016, Decimal('72.33')),
#  ('Gabon', 2017, Decimal('73.00')),
#  ('Gabon', 2018, Decimal('73.00')),
#  ('Gabon', 2019, Decimal('73.33')),
#  ('Gabon', 2020, Decimal('73.33')),
#  ('Sao Tome and Principe', 2015, Decimal('76.00')),
#  ('Sao Tome and Principe', 2016, Decimal('76.67')),
#  ('Sao Tome and Principe', 2017, Decimal('77.00')),
#  ('Sao Tome and Principe', 2018, Decimal('77.00')),
#  ('Sao Tome and Principe', 2019, Decimal('77.33')),
#  ('Sao Tome and Principe', 2020, Decimal('77.33')),
#  ('Botswana', 2015, Decimal('85.67')),
#  ('Botswana', 2016, Decimal('86.67')),
#  ('Botswana', 2017, Decimal('87.67')),
#  ('Botswana', 2018, Decimal('88.33')),
#  ('Botswana', 2019, Decimal('89.67')),
#  ('Botswana', 2020, Decimal('89.67')),
#  ('Eswatini', 2015, Decimal('73.33')),
#  ('Eswatini', 2016, Decimal('74.00')),
#  ('Eswatini', 2017, Decimal('75.00')),
#  ('Eswatini', 2018, Decimal('75.67')),
#  ('Eswatini', 2019, Decimal('76.67')),
#  ('Eswatini', 2020, Decimal('76.67')),
#  ('Lesotho', 2015, Decimal('74.67')),
#  ('Lesotho', 2016, Decimal('75.00')),
#  ('Lesotho', 2017, Decimal('75.33')),
#  ('Lesotho', 2018, Decimal('76.00')),
#  ('Lesotho', 2019, Decimal('76.00')),
#  ('Lesotho', 2020, Decimal('76.33')),
#  ('Namibia', 2015, Decimal('83.33')),
#  ('Namibia', 2016, Decimal('83.00')),
#  ('Namibia', 2017, Decimal('83.33')),
#  ('Namibia', 2018, Decimal('83.67')),
#  ('Namibia', 2019, Decimal('83.67')),
#  ('Namibia', 2020, Decimal('83.67')),
#  ('South Africa', 2015, Decimal('90.00')),
#  ('South Africa', 2016, Decimal('90.33')),
#  ('South Africa', 2017, Decimal('91.00')),
#  ('South Africa', 2018, Decimal('91.33')),
#  ('South Africa', 2019, Decimal('91.67')),
#  ('South Africa', 2020, Decimal('92.00')),
#  ('Benin', 2015, Decimal('65.33')),
#  ('Benin', 2016, Decimal('65.33')),
#  ('Benin', 2017, Decimal('65.33')),
#  ('Benin', 2018, Decimal('65.67')),
#  ('Benin', 2019, Decimal('65.33')),
#  ('Benin', 2020, Decimal('65.33')),
#  ('Burkina Faso', 2015, Decimal('56.33')),
#  ('Burkina Faso', 2016, Decimal('56.00')),
#  ('Burkina Faso', 2017, Decimal('55.00')),
#  ('Burkina Faso', 2018, Decimal('54.33')),
#  ('Burkina Faso', 2019, Decimal('54.00')),
#  ('Burkina Faso', 2020, Decimal('53.33')),
#  ('Cabo Verde', 2015, Decimal('83.33')),
#  ('Cabo Verde', 2016, Decimal('84.33')),
#  ('Cabo Verde', 2017, Decimal('85.33')),
#  ('Cabo Verde', 2018, Decimal('86.00')),
#  ('Cabo Verde', 2019, Decimal('86.67')),
#  ('Cabo Verde', 2020, Decimal('87.33')),
#  ("Côte d'Ivoire", 2015, Decimal('71.33')),
#  ("Côte d'Ivoire", 2016, Decimal('71.00')),
#  ("Côte d'Ivoire", 2017, Decimal('71.00')),
#  ("Côte d'Ivoire", 2018, Decimal('71.00')),
#  ("Côte d'Ivoire", 2019, Decimal('70.67')),
#  ("Côte d'Ivoire", 2020, Decimal('70.67')),
#  ('Gambia', 2015, Decimal('78.00')),
#  ('Gambia', 2016, Decimal('78.33')),
#  ('Gambia', 2017, Decimal('78.67')),
#  ('Gambia', 2018, Decimal('78.67')),
#  ('Gambia', 2019, Decimal('79.33')),
#  ('Gambia', 2020, Decimal('79.33')),
#  ('Ghana', 2015, Decimal('79.33')),
#  ('Ghana', 2016, Decimal('80.33')),
#  ('Ghana', 2017, Decimal('81.33')),
#  ('Ghana', 2018, Decimal('82.67')),
#  ('Ghana', 2019, Decimal('83.67')),
#  ('Ghana', 2020, Decimal('84.67')),
#  ('Guinea', 2015, Decimal('67.00')),
#  ('Guinea', 2016, Decimal('67.00')),
#  ('Guinea', 2017, Decimal('67.33')),
#  ('Guinea', 2018, Decimal('67.00')),
#  ('Guinea', 2019, Decimal('67.00')),
#  ('Guinea', 2020, Decimal('67.33')),
#  ('Guinea-Bissau', 2015, Decimal('60.00')),
#  ('Guinea-Bissau', 2016, Decimal('60.33')),
#  ('Guinea-Bissau', 2017, Decimal('60.00')),
#  ('Guinea-Bissau', 2018, Decimal('60.00')),
#  ('Guinea-Bissau', 2019, Decimal('60.00')),
#  ('Guinea-Bissau', 2020, Decimal('60.00')),
#  ('Liberia', 2015, Decimal('72.67')),
#  ('Liberia', 2016, Decimal('73.00')),
#  ('Liberia', 2017, Decimal('74.00')),
#  ('Liberia', 2018, Decimal('74.00')),
#  ('Liberia', 2019, Decimal('75.00')),
#  ('Liberia', 2020, Decimal('75.00')),
#  ...]

# %% [markdown]
# ### 1. Order countries based on their water access levels per year.
#
# Use the `ROW_NUMBER()` function to order the countries based on their water access levels per year.

# %%
# %%sql
# # Add your code here
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     ROW_NUMBER() OVER (PARTITION BY Country_name ORDER BY Pct_managed_drinking_water_services desc) AS Rank_water_access
# FROM
#     united_nations.Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Afghanistan', 2020, Decimal('80.33'), 1),
#  ('Afghanistan', 2019, Decimal('78.00'), 2),
#  ('Afghanistan', 2018, Decimal('75.33'), 3),
#  ('Afghanistan', 2017, Decimal('72.33'), 4),
#  ('Afghanistan', 2016, Decimal('69.67'), 5),
#  ('Afghanistan', 2015, Decimal('67.00'), 6),
#  ('Algeria', 2020, Decimal('93.33'), 1),
#  ('Algeria', 2019, Decimal('93.33'), 2),
#  ('Algeria', 2016, Decimal('93.00'), 3),
#  ('Algeria', 2018, Decimal('93.00'), 4),
#  ('Algeria', 2017, Decimal('93.00'), 5),
#  ('Algeria', 2015, Decimal('92.00'), 6),
#  ('American Samoa', 2020, Decimal('100.00'), 1),
#  ('American Samoa', 2018, Decimal('100.00'), 2),
#  ('American Samoa', 2017, Decimal('100.00'), 3),
#  ('American Samoa', 2016, Decimal('100.00'), 4),
#  ('American Samoa', 2019, Decimal('100.00'), 5),
#  ('American Samoa', 2015, Decimal('100.00'), 6),
#  ('Angola', 2020, Decimal('52.33'), 1),
#  ('Angola', 2018, Decimal('52.33'), 2),
#  ('Angola', 2019, Decimal('52.33'), 3),
#  ('Angola', 2017, Decimal('51.33'), 4),
#  ('Angola', 2016, Decimal('51.00'), 5),
#  ('Angola', 2015, Decimal('50.33'), 6),
#  ('Anguilla', 2015, Decimal('97.00'), 1),
#  ('Anguilla', 2016, Decimal('97.00'), 2),
#  ('Anguilla', 2017, Decimal('97.00'), 3),
#  ('Antigua and Barbuda', 2015, Decimal('97.00'), 1),
#  ('Antigua and Barbuda', 2017, Decimal('97.00'), 2),
#  ('Antigua and Barbuda', 2016, Decimal('97.00'), 3),
#  ('Argentina', 2020, Decimal('100.00'), 1),
#  ('Argentina', 2019, Decimal('100.00'), 2),
#  ('Argentina', 2018, Decimal('100.00'), 3),
#  ('Argentina', 2017, Decimal('100.00'), 4),
#  ('Argentina', 2016, Decimal('97.33'), 5),
#  ('Argentina', 2015, Decimal('97.33'), 6),
#  ('Armenia', 2018, Decimal('100.00'), 1),
#  ('Armenia', 2019, Decimal('100.00'), 2),
#  ('Armenia', 2020, Decimal('100.00'), 3),
#  ('Armenia', 2017, Decimal('100.00'), 4),
#  ('Armenia', 2016, Decimal('99.67'), 5),
#  ('Armenia', 2015, Decimal('99.67'), 6),
#  ('Aruba', 2016, Decimal('98.00'), 1),
#  ('Aruba', 2015, Decimal('98.00'), 2),
#  ('Australia', 2015, Decimal('100.00'), 1),
#  ('Australia', 2016, Decimal('100.00'), 2),
#  ('Australia', 2017, Decimal('100.00'), 3),
#  ('Australia', 2018, Decimal('100.00'), 4),
#  ('Australia', 2019, Decimal('100.00'), 5),
#  ('Australia', 2020, Decimal('100.00'), 6),
#  ('Azerbaijan', 2020, Decimal('95.67'), 1),
#  ('Azerbaijan', 2019, Decimal('95.00'), 2),
#  ('Azerbaijan', 2018, Decimal('94.33'), 3),
#  ('Azerbaijan', 2017, Decimal('93.67'), 4),
#  ('Azerbaijan', 2016, Decimal('92.33'), 5),
#  ('Azerbaijan', 2015, Decimal('91.67'), 6),
#  ('Bahamas', 2015, Decimal('99.00'), 1),
#  ('Bahamas', 2016, Decimal('99.00'), 2),
#  ('Bahamas', 2019, Decimal('99.00'), 3),
#  ('Bahamas', 2017, Decimal('99.00'), 4),
#  ('Bahamas', 2018, Decimal('99.00'), 5),
#  ('Bahrain', 2016, Decimal('100.00'), 1),
#  ('Bahrain', 2020, Decimal('100.00'), 2),
#  ('Bahrain', 2019, Decimal('100.00'), 3),
#  ('Bahrain', 2018, Decimal('100.00'), 4),
#  ('Bahrain', 2017, Decimal('100.00'), 5),
#  ('Bahrain', 2015, Decimal('100.00'), 6),
#  ('Bangladesh', 2019, Decimal('97.67'), 1),
#  ('Bangladesh', 2020, Decimal('97.67'), 2),
#  ('Bangladesh', 2017, Decimal('97.33'), 3),
#  ('Bangladesh', 2016, Decimal('97.33'), 4),
#  ('Bangladesh', 2018, Decimal('97.33'), 5),
#  ('Bangladesh', 2015, Decimal('97.33'), 6),
#  ('Barbados', 2020, Decimal('99.00'), 1),
#  ('Barbados', 2019, Decimal('99.00'), 2),
#  ('Barbados', 2018, Decimal('99.00'), 3),
#  ('Barbados', 2017, Decimal('98.00'), 4),
#  ('Barbados', 2016, Decimal('98.00'), 5),
#  ('Barbados', 2015, Decimal('98.00'), 6),
#  ('Belize', 2018, Decimal('98.33'), 1),
#  ('Belize', 2019, Decimal('98.33'), 2),
#  ('Belize', 2020, Decimal('98.33'), 3),
#  ('Belize', 2017, Decimal('98.00'), 4),
#  ('Belize', 2016, Decimal('97.67'), 5),
#  ('Belize', 2015, Decimal('97.33'), 6),
#  ('Benin', 2018, Decimal('65.67'), 1),
#  ('Benin', 2017, Decimal('65.33'), 2),
#  ('Benin', 2019, Decimal('65.33'), 3),
#  ('Benin', 2020, Decimal('65.33'), 4),
#  ('Benin', 2015, Decimal('65.33'), 5),
#  ('Benin', 2016, Decimal('65.33'), 6),
#  ('Bermuda', 2015, Decimal('100.00'), 1),
#  ('Bermuda', 2016, Decimal('100.00'), 2),
#  ('Bermuda', 2020, Decimal('100.00'), 3),
#  ('Bermuda', 2019, Decimal('100.00'), 4),
#  ('Bermuda', 2018, Decimal('100.00'), 5),
#  ('Bermuda', 2017, Decimal('100.00'), 6),
#  ('Bhutan', 2020, Decimal('97.33'), 1),
#  ('Bhutan', 2019, Decimal('97.33'), 2),
#  ('Bhutan', 2017, Decimal('97.33'), 3),
#  ('Bhutan', 2018, Decimal('97.33'), 4),
#  ('Bhutan', 2016, Decimal('97.00'), 5),
#  ('Bhutan', 2015, Decimal('96.33'), 6),
#  ('Bolivia (Plurinational State of)', 2020, Decimal('90.67'), 1),
#  ('Bolivia (Plurinational State of)', 2019, Decimal('90.33'), 2),
#  ('Bolivia (Plurinational State of)', 2018, Decimal('89.67'), 3),
#  ('Bolivia (Plurinational State of)', 2017, Decimal('89.00'), 4),
#  ('Bolivia (Plurinational State of)', 2016, Decimal('88.00'), 5),
#  ('Bolivia (Plurinational State of)', 2015, Decimal('87.33'), 6),
#  ('Botswana', 2019, Decimal('89.67'), 1),
#  ('Botswana', 2020, Decimal('89.67'), 2),
#  ('Botswana', 2018, Decimal('88.33'), 3),
#  ('Botswana', 2017, Decimal('87.67'), 4),
#  ('Botswana', 2016, Decimal('86.67'), 5),
#  ('Botswana', 2015, Decimal('85.67'), 6),
#  ('Brazil', 2020, Decimal('98.33'), 1),
#  ('Brazil', 2019, Decimal('97.33'), 2),
#  ('Brazil', 2018, Decimal('97.00'), 3),
#  ('Brazil', 2017, Decimal('96.33'), 4),
#  ('Brazil', 2015, Decimal('95.33'), 5),
#  ('Brazil', 2016, Decimal('95.33'), 6),
#  ('British Virgin Islands', 2019, Decimal('100.00'), 1),
#  ('British Virgin Islands', 2015, Decimal('100.00'), 2),
#  ('British Virgin Islands', 2017, Decimal('100.00'), 3),
#  ('British Virgin Islands', 2020, Decimal('100.00'), 4),
#  ('British Virgin Islands', 2016, Decimal('100.00'), 5),
#  ('British Virgin Islands', 2018, Decimal('100.00'), 6),
#  ('Brunei Darussalam', 2016, Decimal('100.00'), 1),
#  ('Brunei Darussalam', 2017, Decimal('100.00'), 2),
#  ('Brunei Darussalam', 2019, Decimal('100.00'), 3),
#  ('Brunei Darussalam', 2020, Decimal('100.00'), 4),
#  ('Brunei Darussalam', 2018, Decimal('100.00'), 5),
#  ('Brunei Darussalam', 2015, Decimal('99.67'), 6),
#  ('Burkina Faso', 2015, Decimal('56.33'), 1),
#  ('Burkina Faso', 2016, Decimal('56.00'), 2),
#  ('Burkina Faso', 2017, Decimal('55.00'), 3),
#  ('Burkina Faso', 2018, Decimal('54.33'), 4),
#  ('Burkina Faso', 2019, Decimal('54.00'), 5),
#  ('Burkina Faso', 2020, Decimal('53.33'), 6),
#  ('Burundi', 2019, Decimal('70.33'), 1),
#  ('Burundi', 2020, Decimal('70.33'), 2),
#  ('Burundi', 2017, Decimal('69.33'), 3),
#  ('Burundi', 2018, Decimal('69.33'), 4),
#  ('Burundi', 2016, Decimal('68.33'), 5),
#  ('Burundi', 2015, Decimal('68.33'), 6),
#  ('Cabo Verde', 2020, Decimal('87.33'), 1),
#  ('Cabo Verde', 2019, Decimal('86.67'), 2),
#  ('Cabo Verde', 2018, Decimal('86.00'), 3),
#  ('Cabo Verde', 2017, Decimal('85.33'), 4),
#  ('Cabo Verde', 2016, Decimal('84.33'), 5),
#  ('Cabo Verde', 2015, Decimal('83.33'), 6),
#  ('Cambodia', 2019, Decimal('75.33'), 1),
#  ('Cambodia', 2020, Decimal('75.33'), 2),
#  ('Cambodia', 2018, Decimal('74.67'), 3),
#  ('Cambodia', 2017, Decimal('74.33'), 4),
#  ('Cambodia', 2016, Decimal('73.67'), 5),
#  ('Cambodia', 2015, Decimal('73.33'), 6),
#  ('Cameroon', 2020, Decimal('64.00'), 1),
#  ('Cameroon', 2019, Decimal('63.33'), 2),
#  ('Cameroon', 2018, Decimal('63.33'), 3),
#  ('Cameroon', 2017, Decimal('63.33'), 4),
#  ('Cameroon', 2015, Decimal('62.67'), 5),
#  ('Cameroon', 2016, Decimal('62.67'), 6),
#  ('Canada', 2015, Decimal('99.00'), 1),
#  ('Canada', 2016, Decimal('99.00'), 2),
#  ('Canada', 2017, Decimal('99.00'), 3),
#  ('Canada', 2018, Decimal('99.00'), 4),
#  ('Canada', 2019, Decimal('99.00'), 5),
#  ('Canada', 2020, Decimal('99.00'), 6),
#  ('Cayman Islands', 2015, Decimal('96.00'), 1),
#  ('Cayman Islands', 2016, Decimal('96.00'), 2),
#  ('Central African Republic', 2015, Decimal('44.00'), 1),
#  ('Central African Republic', 2016, Decimal('42.67'), 2),
#  ('Central African Republic', 2017, Decimal('41.33'), 3),
#  ('Central African Republic', 2018, Decimal('40.67'), 4),
#  ('Central African Republic', 2019, Decimal('39.33'), 5),
#  ('Central African Republic', 2020, Decimal('38.33'), 6),
#  ('Chad', 2020, Decimal('52.67'), 1),
#  ('Chad', 2019, Decimal('52.33'), 2),
#  ('Chad', 2018, Decimal('52.00'), 3),
#  ('Chad', 2017, Decimal('52.00'), 4),
#  ('Chad', 2016, Decimal('52.00'), 5),
#  ('Chad', 2015, Decimal('51.67'), 6),
#  ('Chile', 2017, Decimal('100.00'), 1),
#  ('Chile', 2018, Decimal('100.00'), 2),
#  ('Chile', 2019, Decimal('100.00'), 3),
#  ('Chile', 2020, Decimal('100.00'), 4),
#  ('Chile', 2016, Decimal('99.67'), 5),
#  ('Chile', 2015, Decimal('99.00'), 6),
#  ('China', 2020, Decimal('93.67'), 1),
#  ('China', 2019, Decimal('93.33'), 2),
#  ('China', 2018, Decimal('92.67'), 3),
#  ('China', 2017, Decimal('92.00'), 4),
#  ('China', 2015, Decimal('91.33'), 5),
#  ('China', 2016, Decimal('91.33'), 6),
#  ('Colombia', 2020, Decimal('94.67'), 1),
#  ('Colombia', 2019, Decimal('94.33'), 2),
#  ('Colombia', 2017, Decimal('94.00'), 3),
#  ('Colombia', 2018, Decimal('94.00'), 4),
#  ('Colombia', 2016, Decimal('93.67'), 5),
#  ('Colombia', 2015, Decimal('93.00'), 6),
#  ('Comoros', 2015, Decimal('81.67'), 1),
#  ('Comoros', 2019, Decimal('81.67'), 2),
#  ('Comoros', 2018, Decimal('81.67'), 3),
#  ('Comoros', 2017, Decimal('81.67'), 4),
#  ('Comoros', 2016, Decimal('81.67'), 5),
#  ('Congo', 2020, Decimal('69.00'), 1),
#  ('Congo', 2019, Decimal('69.00'), 2),
#  ('Congo', 2018, Decimal('68.67'), 3),
#  ('Congo', 2017, Decimal('68.67'), 4),
#  ('Congo', 2016, Decimal('67.67'), 5),
#  ('Congo', 2015, Decimal('66.33'), 6),
#  ('Cook Islands', 2019, Decimal('100.00'), 1),
#  ('Cook Islands', 2018, Decimal('100.00'), 2),
#  ('Cook Islands', 2017, Decimal('100.00'), 3),
#  ('Cook Islands', 2016, Decimal('100.00'), 4),
#  ('Cook Islands', 2015, Decimal('100.00'), 5),
#  ('Cook Islands', 2020, Decimal('100.00'), 6),
#  ('Costa Rica', 2017, Decimal('100.00'), 1),
#  ('Costa Rica', 2018, Decimal('100.00'), 2),
#  ('Costa Rica', 2019, Decimal('100.00'), 3),
#  ('Costa Rica', 2020, Decimal('100.00'), 4),
#  ('Costa Rica', 2016, Decimal('99.67'), 5),
#  ('Costa Rica', 2015, Decimal('99.00'), 6),
#  ("Côte d'Ivoire", 2015, Decimal('71.33'), 1),
#  ("Côte d'Ivoire", 2018, Decimal('71.00'), 2),
#  ("Côte d'Ivoire", 2017, Decimal('71.00'), 3),
#  ("Côte d'Ivoire", 2016, Decimal('71.00'), 4),
#  ("Côte d'Ivoire", 2020, Decimal('70.67'), 5),
#  ("Côte d'Ivoire", 2019, Decimal('70.67'), 6),
#  ('Cuba', 2020, Decimal('96.33'), 1),
#  ('Cuba', 2019, Decimal('96.33'), 2),
#  ('Cuba', 2018, Decimal('96.00'), 3),
#  ('Cuba', 2017, Decimal('95.33'), 4),
#  ('Cuba', 2016, Decimal('95.00'), 5),
#  ('Cuba', 2015, Decimal('94.67'), 6),
#  ('Curaçao', 2015, Decimal('99.00'), 1),
#  ('Curaçao', 2016, Decimal('99.00'), 2),
#  ('Curaçao', 2017, Decimal('99.00'), 3),
#  ('Cyprus', 2017, Decimal('100.00'), 1),
#  ('Cyprus', 2015, Decimal('100.00'), 2),
#  ('Cyprus', 2018, Decimal('100.00'), 3),
#  ('Cyprus', 2016, Decimal('100.00'), 4),
#  ('Cyprus', 2019, Decimal('100.00'), 5),
#  ('Cyprus', 2020, Decimal('100.00'), 6),
#  ("Democratic People's Republic of Korea", 2015, Decimal('94.67'), 1),
#  ("Democratic People's Republic of Korea", 2016, Decimal('94.33'), 2),
#  ("Democratic People's Republic of Korea", 2017, Decimal('94.00'), 3),
#  ("Democratic People's Republic of Korea", 2018, Decimal('93.33'), 4),
#  ("Democratic People's Republic of Korea", 2019, Decimal('93.33'), 5),
#  ("Democratic People's Republic of Korea", 2020, Decimal('93.33'), 6),
#  ('Democratic Republic of the Congo', 2020, Decimal('47.67'), 1),
#  ('Democratic Republic of the Congo', 2019, Decimal('47.00'), 2),
#  ('Democratic Republic of the Congo', 2018, Decimal('46.67'), 3),
#  ('Democratic Republic of the Congo', 2017, Decimal('46.00'), 4),
#  ('Democratic Republic of the Congo', 2016, Decimal('45.67'), 5),
#  ('Democratic Republic of the Congo', 2015, Decimal('45.33'), 6),
#  ('Djibouti', 2015, Decimal('69.67'), 1),
#  ('Djibouti', 2016, Decimal('69.33'), 2),
#  ('Djibouti', 2018, Decimal('69.33'), 3),
#  ('Djibouti', 2017, Decimal('69.33'), 4),
#  ('Djibouti', 2020, Decimal('69.00'), 5),
#  ('Djibouti', 2019, Decimal('69.00'), 6),
#  ('Dominica', 2017, Decimal('95.00'), 1),
#  ('Dominica', 2016, Decimal('95.00'), 2),
#  ('Dominica', 2015, Decimal('95.00'), 3),
#  ('Dominican Republic', 2020, Decimal('95.00'), 1),
#  ('Dominican Republic', 2019, Decimal('95.00'), 2),
#  ('Dominican Republic', 2018, Decimal('95.00'), 3),
#  ('Dominican Republic', 2017, Decimal('94.67'), 4),
#  ('Dominican Republic', 2016, Decimal('94.67'), 5),
#  ('Dominican Republic', 2015, Decimal('94.33'), 6),
#  ('Ecuador', 2020, Decimal('94.00'), 1),
#  ('Ecuador', 2019, Decimal('93.67'), 2),
#  ('Ecuador', 2018, Decimal('93.33'), 3),
#  ('Ecuador', 2017, Decimal('92.67'), 4),
#  ('Ecuador', 2016, Decimal('92.33'), 5),
#  ('Ecuador', 2015, Decimal('91.67'), 6),
#  ('Egypt', 2015, Decimal('99.33'), 1),
#  ('Egypt', 2016, Decimal('99.33'), 2),
#  ('Egypt', 2017, Decimal('99.33'), 3),
#  ('Egypt', 2018, Decimal('99.33'), 4),
#  ('Egypt', 2019, Decimal('99.33'), 5),
#  ('Egypt', 2020, Decimal('99.33'), 6),
#  ('El Salvador', 2018, Decimal('97.00'), 1),
#  ('El Salvador', 2019, Decimal('97.00'), 2),
#  ('El Salvador', 2020, Decimal('97.00'), 3),
#  ('El Salvador', 2017, Decimal('96.00'), 4),
#  ('El Salvador', 2016, Decimal('95.33'), 5),
#  ('El Salvador', 2015, Decimal('94.33'), 6),
#  ('Equatorial Guinea', 2017, Decimal('58.00'), 1),
#  ('Equatorial Guinea', 2016, Decimal('57.67'), 2),
#  ('Equatorial Guinea', 2015, Decimal('57.67'), 3),
#  ('Eritrea', 2016, Decimal('56.67'), 1),
#  ('Eritrea', 2015, Decimal('56.33'), 2),
#  ('Eswatini', 2020, Decimal('76.67'), 1),
#  ('Eswatini', 2019, Decimal('76.67'), 2),
#  ('Eswatini', 2018, Decimal('75.67'), 3),
#  ('Eswatini', 2017, Decimal('75.00'), 4),
#  ('Eswatini', 2016, Decimal('74.00'), 5),
#  ('Eswatini', 2015, Decimal('73.33'), 6),
#  ('Ethiopia', 2020, Decimal('58.00'), 1),
#  ('Ethiopia', 2019, Decimal('57.00'), 2),
#  ('Ethiopia', 2018, Decimal('55.67'), 3),
#  ('Ethiopia', 2017, Decimal('54.67'), 4),
#  ('Ethiopia', 2016, Decimal('53.33'), 5),
#  ('Ethiopia', 2015, Decimal('52.00'), 6),
#  ('Falkland Islands (Malvinas)', 2019, Decimal('91.00'), 1),
#  ('Falkland Islands (Malvinas)', 2018, Decimal('91.00'), 2),
#  ('Falkland Islands (Malvinas)', 2017, Decimal('91.00'), 3),
#  ('Falkland Islands (Malvinas)', 2015, Decimal('91.00'), 4),
#  ('Falkland Islands (Malvinas)', 2016, Decimal('91.00'), 5),
#  ('Falkland Islands (Malvinas)', 2020, Decimal('91.00'), 6),
#  ('Fiji', 2018, Decimal('93.67'), 1),
#  ('Fiji', 2017, Decimal('93.67'), 2),
#  ('Fiji', 2016, Decimal('93.67'), 3),
#  ('Fiji', 2019, Decimal('93.67'), 4),
#  ('Fiji', 2020, Decimal('93.67'), 5),
#  ('Fiji', 2015, Decimal('93.67'), 6),
#  ('French Guiana', 2020, Decimal('94.00'), 1),
#  ('French Guiana', 2019, Decimal('94.00'), 2),
#  ('French Guiana', 2018, Decimal('94.00'), 3),
#  ('French Guiana', 2015, Decimal('94.00'), 4),
#  ('French Guiana', 2016, Decimal('94.00'), 5),
#  ('French Guiana', 2017, Decimal('94.00'), 6),
#  ('French Polynesia', 2018, Decimal('100.00'), 1),
#  ('French Polynesia', 2017, Decimal('100.00'), 2),
#  ('French Polynesia', 2016, Decimal('100.00'), 3),
#  ('French Polynesia', 2015, Decimal('100.00'), 4),
#  ('French Polynesia', 2020, Decimal('100.00'), 5),
#  ('French Polynesia', 2019, Decimal('100.00'), 6),
#  ('Gabon', 2020, Decimal('73.33'), 1),
#  ('Gabon', 2019, Decimal('73.33'), 2),
#  ('Gabon', 2018, Decimal('73.00'), 3),
#  ('Gabon', 2017, Decimal('73.00'), 4),
#  ('Gabon', 2016, Decimal('72.33'), 5),
#  ('Gabon', 2015, Decimal('72.00'), 6),
#  ('Gambia', 2020, Decimal('79.33'), 1),
#  ('Gambia', 2019, Decimal('79.33'), 2),
#  ('Gambia', 2018, Decimal('78.67'), 3),
#  ('Gambia', 2017, Decimal('78.67'), 4),
#  ('Gambia', 2016, Decimal('78.33'), 5),
#  ('Gambia', 2015, Decimal('78.00'), 6),
#  ('Georgia', 2017, Decimal('96.67'), 1),
#  ('Georgia', 2020, Decimal('96.67'), 2),
#  ('Georgia', 2019, Decimal('96.67'), 3),
#  ('Georgia', 2018, Decimal('96.67'), 4),
#  ('Georgia', 2016, Decimal('96.00'), 5),
#  ('Georgia', 2015, Decimal('95.33'), 6),
#  ('Ghana', 2020, Decimal('84.67'), 1),
#  ('Ghana', 2019, Decimal('83.67'), 2),
#  ('Ghana', 2018, Decimal('82.67'), 3),
#  ('Ghana', 2017, Decimal('81.33'), 4),
#  ('Ghana', 2016, Decimal('80.33'), 5),
#  ('Ghana', 2015, Decimal('79.33'), 6),
#  ('Greenland', 2017, Decimal('100.00'), 1),
#  ('Greenland', 2015, Decimal('100.00'), 2),
#  ('Greenland', 2016, Decimal('100.00'), 3),
#  ('Greenland', 2018, Decimal('100.00'), 4),
#  ('Greenland', 2019, Decimal('100.00'), 5),
#  ('Greenland', 2020, Decimal('100.00'), 6),
#  ('Grenada', 2015, Decimal('96.00'), 1),
#  ('Grenada', 2016, Decimal('96.00'), 2),
#  ('Grenada', 2017, Decimal('96.00'), 3),
#  ('Guadeloupe', 2017, Decimal('100.00'), 1),
#  ('Guadeloupe', 2019, Decimal('100.00'), 2),
#  ('Guadeloupe', 2020, Decimal('100.00'), 3),
#  ('Guadeloupe', 2015, Decimal('100.00'), 4),
#  ('Guadeloupe', 2018, Decimal('100.00'), 5),
#  ('Guadeloupe', 2016, Decimal('100.00'), 6),
#  ('Guam', 2015, Decimal('100.00'), 1),
#  ('Guam', 2016, Decimal('100.00'), 2),
#  ('Guam', 2017, Decimal('100.00'), 3),
#  ('Guam', 2018, Decimal('100.00'), 4),
#  ('Guam', 2019, Decimal('100.00'), 5),
#  ('Guam', 2020, Decimal('100.00'), 6),
#  ('Guatemala', 2019, Decimal('94.00'), 1),
#  ('Guatemala', 2020, Decimal('94.00'), 2),
#  ('Guatemala', 2018, Decimal('93.00'), 3),
#  ('Guatemala', 2017, Decimal('92.67'), 4),
#  ('Guatemala', 2016, Decimal('92.33'), 5),
#  ('Guatemala', 2015, Decimal('92.00'), 6),
#  ('Guinea', 2020, Decimal('67.33'), 1),
#  ('Guinea', 2017, Decimal('67.33'), 2),
#  ('Guinea', 2019, Decimal('67.00'), 3),
#  ('Guinea', 2018, Decimal('67.00'), 4),
#  ('Guinea', 2015, Decimal('67.00'), 5),
#  ('Guinea', 2016, Decimal('67.00'), 6),
#  ('Guinea-Bissau', 2016, Decimal('60.33'), 1),
#  ('Guinea-Bissau', 2015, Decimal('60.00'), 2),
#  ('Guinea-Bissau', 2019, Decimal('60.00'), 3),
#  ('Guinea-Bissau', 2017, Decimal('60.00'), 4),
#  ('Guinea-Bissau', 2018, Decimal('60.00'), 5),
#  ('Guinea-Bissau', 2020, Decimal('60.00'), 6),
#  ('Guyana', 2020, Decimal('96.67'), 1),
#  ('Guyana', 2019, Decimal('96.67'), 2),
#  ('Guyana', 2018, Decimal('96.67'), 3),
#  ('Guyana', 2017, Decimal('96.67'), 4),
#  ('Guyana', 2016, Decimal('96.67'), 5),
#  ('Guyana', 2015, Decimal('96.00'), 6),
#  ('Haiti', 2020, Decimal('65.00'), 1),
#  ('Haiti', 2019, Decimal('64.67'), 2),
#  ('Haiti', 2018, Decimal('64.67'), 3),
#  ('Haiti', 2016, Decimal('64.33'), 4),
#  ('Haiti', 2017, Decimal('64.33'), 5),
#  ('Haiti', 2015, Decimal('64.00'), 6),
#  ('Honduras', 2020, Decimal('95.33'), 1),
#  ('Honduras', 2019, Decimal('94.67'), 2),
#  ('Honduras', 2018, Decimal('94.33'), 3),
#  ('Honduras', 2017, Decimal('93.67'), 4),
#  ('Honduras', 2016, Decimal('93.33'), 5),
#  ('Honduras', 2015, Decimal('92.67'), 6),
#  ('India', 2020, Decimal('91.00'), 1),
#  ('India', 2019, Decimal('90.67'), 2),
#  ('India', 2018, Decimal('90.33'), 3),
#  ('India', 2017, Decimal('90.00'), 4),
#  ('India', 2016, Decimal('89.33'), 5),
#  ('India', 2015, Decimal('89.00'), 6),
#  ('Indonesia', 2020, Decimal('92.00'), 1),
#  ('Indonesia', 2019, Decimal('91.33'), 2),
#  ('Indonesia', 2018, Decimal('90.67'), 3),
#  ('Indonesia', 2017, Decimal('89.67'), 4),
#  ('Indonesia', 2016, Decimal('89.00'), 5),
#  ('Indonesia', 2015, Decimal('88.33'), 6),
#  ('Iran (Islamic Republic of)', 2020, Decimal('96.67'), 1),
#  ('Iran (Islamic Republic of)', 2017, Decimal('96.33'), 2),
#  ('Iran (Islamic Republic of)', 2018, Decimal('96.33'), 3),
#  ('Iran (Islamic Republic of)', 2019, Decimal('96.33'), 4),
#  ('Iran (Islamic Republic of)', 2016, Decimal('96.00'), 5),
#  ('Iran (Islamic Republic of)', 2015, Decimal('95.67'), 6),
#  ('Iraq', 2020, Decimal('97.67'), 1),
#  ('Iraq', 2019, Decimal('97.00'), 2),
#  ('Iraq', 2018, Decimal('95.67'), 3),
#  ('Iraq', 2017, Decimal('94.67'), 4),
#  ('Iraq', 2016, Decimal('93.67'), 5),
#  ('Iraq', 2015, Decimal('92.33'), 6),
#  ('Israel', 2017, Decimal('100.00'), 1),
#  ('Israel', 2018, Decimal('100.00'), 2),
#  ('Israel', 2019, Decimal('100.00'), 3),
#  ('Israel', 2020, Decimal('100.00'), 4),
#  ('Israel', 2016, Decimal('100.00'), 5),
#  ('Israel', 2015, Decimal('100.00'), 6),
#  ('Jamaica', 2018, Decimal('90.33'), 1),
#  ('Jamaica', 2020, Decimal('90.33'), 2),
#  ('Jamaica', 2019, Decimal('90.33'), 3),
#  ('Jamaica', 2016, Decimal('90.33'), 4),
#  ('Jamaica', 2017, Decimal('90.33'), 5),
#  ('Jamaica', 2015, Decimal('90.00'), 6),
#  ('Japan', 2019, Decimal('99.00'), 1),
#  ('Japan', 2018, Decimal('99.00'), 2),
#  ('Japan', 2017, Decimal('99.00'), 3),
#  ('Japan', 2016, Decimal('99.00'), 4),
#  ('Japan', 2015, Decimal('99.00'), 5),
#  ('Japan', 2020, Decimal('99.00'), 6),
#  ('Jordan', 2017, Decimal('98.33'), 1),
#  ('Jordan', 2019, Decimal('98.33'), 2),
#  ('Jordan', 2020, Decimal('98.33'), 3),
#  ('Jordan', 2018, Decimal('98.33'), 4),
#  ('Jordan', 2015, Decimal('98.33'), 5),
#  ('Jordan', 2016, Decimal('98.33'), 6),
#  ('Kazakhstan', 2017, Decimal('95.00'), 1),
#  ('Kazakhstan', 2018, Decimal('95.00'), 2),
#  ('Kazakhstan', 2019, Decimal('95.00'), 3),
#  ('Kazakhstan', 2020, Decimal('95.00'), 4),
#  ('Kazakhstan', 2016, Decimal('94.67'), 5),
#  ('Kazakhstan', 2015, Decimal('94.67'), 6),
#  ('Kenya', 2020, Decimal('67.00'), 1),
#  ('Kenya', 2019, Decimal('66.33'), 2),
#  ('Kenya', 2018, Decimal('65.67'), 3),
#  ('Kenya', 2017, Decimal('65.67'), 4),
#  ('Kenya', 2016, Decimal('65.00'), 5),
#  ('Kenya', 2015, Decimal('64.33'), 6),
#  ('Kiribati', 2020, Decimal('77.00'), 1),
#  ('Kiribati', 2019, Decimal('76.00'), 2),
#  ('Kiribati', 2018, Decimal('75.33'), 3),
#  ('Kiribati', 2017, Decimal('75.00'), 4),
#  ('Kiribati', 2016, Decimal('74.33'), 5),
#  ('Kiribati', 2015, Decimal('73.67'), 6),
#  ('Kuwait', 2015, Decimal('100.00'), 1),
#  ('Kuwait', 2020, Decimal('100.00'), 2),
#  ('Kuwait', 2019, Decimal('100.00'), 3),
#  ('Kuwait', 2018, Decimal('100.00'), 4),
#  ('Kuwait', 2017, Decimal('100.00'), 5),
#  ('Kuwait', 2016, Decimal('100.00'), 6),
#  ('Kyrgyzstan', 2020, Decimal('92.67'), 1),
#  ('Kyrgyzstan', 2019, Decimal('91.67'), 2),
#  ('Kyrgyzstan', 2018, Decimal('91.33'), 3),
#  ('Kyrgyzstan', 2017, Decimal('91.00'), 4),
#  ('Kyrgyzstan', 2016, Decimal('90.33'), 5),
#  ('Kyrgyzstan', 2015, Decimal('89.67'), 6),
#  ("Lao People's Democratic Republic", 2019, Decimal('86.67'), 1),
#  ("Lao People's Democratic Republic", 2020, Decimal('86.67'), 2),
#  ("Lao People's Democratic Republic", 2018, Decimal('85.00'), 3),
#  ("Lao People's Democratic Republic", 2017, Decimal('83.33'), 4),
#  ("Lao People's Democratic Republic", 2016, Decimal('82.00'), 5),
#  ("Lao People's Democratic Republic", 2015, Decimal('79.67'), 6),
#  ('Lebanon', 2019, Decimal('93.00'), 1),
#  ('Lebanon', 2020, Decimal('93.00'), 2),
#  ('Lebanon', 2017, Decimal('92.00'), 3),
#  ('Lebanon', 2016, Decimal('92.00'), 4),
#  ('Lebanon', 2018, Decimal('92.00'), 5),
#  ('Lebanon', 2015, Decimal('91.00'), 6),
#  ('Lesotho', 2020, Decimal('76.33'), 1),
#  ('Lesotho', 2019, Decimal('76.00'), 2),
#  ('Lesotho', 2018, Decimal('76.00'), 3),
#  ('Lesotho', 2017, Decimal('75.33'), 4),
#  ('Lesotho', 2016, Decimal('75.00'), 5),
#  ('Lesotho', 2015, Decimal('74.67'), 6),
#  ('Liberia', 2019, Decimal('75.00'), 1),
#  ('Liberia', 2020, Decimal('75.00'), 2),
#  ('Liberia', 2017, Decimal('74.00'), 3),
#  ('Liberia', 2018, Decimal('74.00'), 4),
#  ('Liberia', 2016, Decimal('73.00'), 5),
#  ('Liberia', 2015, Decimal('72.67'), 6),
#  ('Libya', 2018, Decimal('100.00'), 1),
#  ('Libya', 2019, Decimal('100.00'), 2),
#  ('Libya', 2020, Decimal('100.00'), 3),
#  ('Libya', 2017, Decimal('99.00'), 4),
#  ('Libya', 2016, Decimal('98.00'), 5),
#  ('Libya', 2015, Decimal('97.00'), 6),
#  ('Madagascar', 2020, Decimal('56.33'), 1),
#  ('Madagascar', 2019, Decimal('56.00'), 2),
#  ('Madagascar', 2018, Decimal('55.33'), 3),
#  ('Madagascar', 2017, Decimal('54.67'), 4),
#  ('Madagascar', 2016, Decimal('54.00'), 5),
#  ('Madagascar', 2015, Decimal('53.33'), 6),
#  ('Malawi', 2020, Decimal('74.33'), 1),
#  ('Malawi', 2019, Decimal('73.67'), 2),
#  ('Malawi', 2018, Decimal('73.33'), 3),
#  ('Malawi', 2017, Decimal('72.67'), 4),
#  ('Malawi', 2016, Decimal('72.00'), 5),
#  ('Malawi', 2015, Decimal('71.33'), 6),
#  ('Malaysia', 2017, Decimal('95.67'), 1),
#  ('Malaysia', 2015, Decimal('95.67'), 2),
#  ('Malaysia', 2016, Decimal('95.67'), 3),
#  ('Malaysia', 2020, Decimal('95.33'), 4),
#  ('Malaysia', 2019, Decimal('95.33'), 5),
#  ('Malaysia', 2018, Decimal('95.33'), 6),
#  ('Maldives', 2019, Decimal('99.67'), 1),
#  ('Maldives', 2020, Decimal('99.67'), 2),
#  ('Maldives', 2017, Decimal('99.33'), 3),
#  ('Maldives', 2018, Decimal('99.33'), 4),
#  ('Maldives', 2015, Decimal('99.00'), 5),
#  ('Maldives', 2016, Decimal('99.00'), 6),
#  ('Mali', 2020, Decimal('83.67'), 1),
#  ('Mali', 2019, Decimal('82.00'), 2),
#  ('Mali', 2018, Decimal('80.67'), 3),
#  ('Mali', 2017, Decimal('79.33'), 4),
#  ('Mali', 2016, Decimal('77.67'), 5),
#  ('Mali', 2015, Decimal('76.00'), 6),
#  ('Marshall Islands', 2018, Decimal('90.00'), 1),
#  ('Marshall Islands', 2019, Decimal('90.00'), 2),
#  ('Marshall Islands', 2020, Decimal('90.00'), 3),
#  ('Marshall Islands', 2017, Decimal('89.67'), 4),
#  ('Marshall Islands', 2016, Decimal('89.67'), 5),
#  ('Marshall Islands', 2015, Decimal('89.33'), 6),
#  ('Martinique', 2020, Decimal('100.00'), 1),
#  ('Martinique', 2015, Decimal('100.00'), 2),
#  ('Martinique', 2016, Decimal('100.00'), 3),
#  ('Martinique', 2018, Decimal('100.00'), 4),
#  ('Martinique', 2019, Decimal('100.00'), 5),
#  ('Martinique', 2017, Decimal('100.00'), 6),
#  ('Mauritania', 2020, Decimal('70.33'), 1),
#  ('Mauritania', 2019, Decimal('70.00'), 2),
#  ('Mauritania', 2017, Decimal('70.00'), 3),
#  ('Mauritania', 2018, Decimal('70.00'), 4),
#  ('Mauritania', 2016, Decimal('68.33'), 5),
#  ('Mauritania', 2015, Decimal('66.67'), 6),
#  ('Mauritius', 2018, Decimal('100.00'), 1),
#  ('Mauritius', 2015, Decimal('100.00'), 2),
#  ('Mauritius', 2016, Decimal('100.00'), 3),
#  ('Mauritius', 2017, Decimal('100.00'), 4),
#  ('Mauritius', 2020, Decimal('100.00'), 5),
#  ('Mauritius', 2019, Decimal('100.00'), 6),
#  ('Mayotte', 2016, Decimal('97.00'), 1),
#  ('Mayotte', 2015, Decimal('97.00'), 2),
#  ('Mayotte', 2017, Decimal('97.00'), 3),
#  ('Mayotte', 2018, Decimal('96.00'), 4),
#  ('Mayotte', 2020, Decimal('96.00'), 5),
#  ('Mayotte', 2019, Decimal('96.00'), 6),
#  ('Mexico', 2020, Decimal('99.33'), 1),
#  ('Mexico', 2019, Decimal('98.67'), 2),
#  ('Mexico', 2018, Decimal('98.33'), 3),
#  ('Mexico', 2017, Decimal('98.00'), 4),
#  ('Mexico', 2016, Decimal('97.33'), 5),
#  ('Mexico', 2015, Decimal('96.67'), 6),
#  ('Micronesia (Federated States of)', 2019, Decimal('88.00'), 1),
#  ('Micronesia (Federated States of)', 2018, Decimal('88.00'), 2),
#  ('Micronesia (Federated States of)', 2016, Decimal('88.00'), 3),
#  ('Micronesia (Federated States of)', 2015, Decimal('88.00'), 4),
#  ('Micronesia (Federated States of)', 2017, Decimal('88.00'), 5),
#  ('Mongolia', 2020, Decimal('81.00'), 1),
#  ('Mongolia', 2019, Decimal('80.00'), 2),
#  ('Mongolia', 2018, Decimal('79.00'), 3),
#  ('Mongolia', 2017, Decimal('78.00'), 4),
#  ('Mongolia', 2016, Decimal('77.00'), 5),
#  ('Mongolia', 2015, Decimal('75.67'), 6),
#  ('Montserrat', 2020, Decimal('98.00'), 1),
#  ('Montserrat', 2019, Decimal('98.00'), 2),
#  ('Montserrat', 2018, Decimal('98.00'), 3),
#  ('Montserrat', 2017, Decimal('98.00'), 4),
#  ('Montserrat', 2016, Decimal('98.00'), 5),
#  ('Montserrat', 2015, Decimal('98.00'), 6),
#  ('Morocco', 2020, Decimal('88.33'), 1),
#  ('Morocco', 2019, Decimal('87.33'), 2),
#  ('Morocco', 2018, Decimal('85.67'), 3),
#  ('Morocco', 2017, Decimal('84.00'), 4),
#  ('Morocco', 2016, Decimal('83.00'), 5),
#  ('Morocco', 2015, Decimal('81.33'), 6),
#  ('Mozambique', 2020, Decimal('66.67'), 1),
#  ('Mozambique', 2019, Decimal('64.33'), 2),
#  ('Mozambique', 2018, Decimal('62.33'), 3),
#  ('Mozambique', 2017, Decimal('60.00'), 4),
#  ('Mozambique', 2016, Decimal('58.00'), 5),
#  ('Mozambique', 2015, Decimal('55.67'), 6),
#  ('Myanmar', 2020, Decimal('85.67'), 1),
#  ('Myanmar', 2019, Decimal('84.00'), 2),
#  ('Myanmar', 2018, Decimal('82.33'), 3),
#  ('Myanmar', 2017, Decimal('80.33'), 4),
#  ('Myanmar', 2016, Decimal('78.33'), 5),
#  ('Myanmar', 2015, Decimal('76.33'), 6),
#  ('Namibia', 2018, Decimal('83.67'), 1),
#  ('Namibia', 2019, Decimal('83.67'), 2),
#  ('Namibia', 2020, Decimal('83.67'), 3),
#  ('Namibia', 2017, Decimal('83.33'), 4),
#  ('Namibia', 2015, Decimal('83.33'), 5),
#  ('Namibia', 2016, Decimal('83.00'), 6),
#  ('Nauru', 2019, Decimal('100.00'), 1),
#  ('Nauru', 2016, Decimal('100.00'), 2),
#  ('Nauru', 2015, Decimal('100.00'), 3),
#  ('Nauru', 2020, Decimal('100.00'), 4),
#  ('Nauru', 2017, Decimal('100.00'), 5),
#  ('Nauru', 2018, Decimal('100.00'), 6),
#  ('Nepal', 2020, Decimal('90.00'), 1),
#  ('Nepal', 2019, Decimal('90.00'), 2),
#  ('Nepal', 2018, Decimal('89.33'), 3),
#  ('Nepal', 2017, Decimal('89.00'), 4),
#  ('Nepal', 2016, Decimal('88.67'), 5),
#  ('Nepal', 2015, Decimal('88.33'), 6),
#  ('New Caledonia', 2020, Decimal('99.00'), 1),
#  ('New Caledonia', 2017, Decimal('99.00'), 2),
#  ('New Caledonia', 2018, Decimal('99.00'), 3),
#  ('New Caledonia', 2019, Decimal('99.00'), 4),
#  ('New Caledonia', 2015, Decimal('98.00'), 5),
#  ('New Caledonia', 2016, Decimal('98.00'), 6),
#  ('New Zealand', 2016, Decimal('100.00'), 1),
#  ('New Zealand', 2015, Decimal('100.00'), 2),
#  ('New Zealand', 2020, Decimal('100.00'), 3),
#  ('New Zealand', 2019, Decimal('100.00'), 4),
#  ('New Zealand', 2018, Decimal('100.00'), 5),
#  ('New Zealand', 2017, Decimal('100.00'), 6),
#  ('Nicaragua', 2015, Decimal('79.33'), 1),
#  ('Nicaragua', 2018, Decimal('79.33'), 2),
#  ('Nicaragua', 2019, Decimal('79.33'), 3),
#  ('Nicaragua', 2020, Decimal('79.33'), 4),
#  ('Nicaragua', 2016, Decimal('79.00'), 5),
#  ('Nicaragua', 2017, Decimal('79.00'), 6),
#  ('Niger', 2019, Decimal('57.33'), 1),
#  ('Niger', 2020, Decimal('57.33'), 2),
#  ('Niger', 2016, Decimal('57.00'), 3),
#  ('Niger', 2017, Decimal('57.00'), 4),
#  ('Niger', 2018, Decimal('57.00'), 5),
#  ('Niger', 2015, Decimal('56.67'), 6),
#  ('Nigeria', 2020, Decimal('77.33'), 1),
#  ('Nigeria', 2019, Decimal('75.67'), 2),
#  ('Nigeria', 2018, Decimal('74.00'), 3),
#  ('Nigeria', 2017, Decimal('72.33'), 4),
#  ('Nigeria', 2016, Decimal('71.00'), 5),
#  ('Nigeria', 2015, Decimal('69.00'), 6),
#  ('Niue', 2015, Decimal('98.00'), 1),
#  ('Niue', 2019, Decimal('97.00'), 2),
#  ('Niue', 2020, Decimal('97.00'), 3),
#  ('Niue', 2018, Decimal('97.00'), 4),
#  ('Niue', 2016, Decimal('97.00'), 5),
#  ('Niue', 2017, Decimal('97.00'), 6),
#  ('Northern Mariana Islands', 2020, Decimal('100.00'), 1),
#  ('Northern Mariana Islands', 2019, Decimal('100.00'), 2),
#  ('Northern Mariana Islands', 2018, Decimal('100.00'), 3),
#  ('Northern Mariana Islands', 2017, Decimal('100.00'), 4),
#  ('Northern Mariana Islands', 2016, Decimal('100.00'), 5),
#  ('Northern Mariana Islands', 2015, Decimal('100.00'), 6),
#  ('Oman', 2020, Decimal('87.67'), 1),
#  ('Oman', 2019, Decimal('87.67'), 2),
#  ('Oman', 2018, Decimal('87.00'), 3),
#  ('Oman', 2016, Decimal('86.67'), 4),
#  ('Oman', 2017, Decimal('86.67'), 5),
#  ('Oman', 2015, Decimal('86.00'), 6),
#  ('Pakistan', 2020, Decimal('90.67'), 1),
#  ('Pakistan', 2017, Decimal('90.33'), 2),
#  ('Pakistan', 2018, Decimal('90.33'), 3),
#  ('Pakistan', 2019, Decimal('90.33'), 4),
#  ('Pakistan', 2015, Decimal('90.00'), 5),
#  ('Pakistan', 2016, Decimal('90.00'), 6),
#  ('Palau', 2016, Decimal('100.00'), 1),
#  ('Palau', 2017, Decimal('100.00'), 2),
#  ('Palau', 2018, Decimal('100.00'), 3),
#  ('Palau', 2015, Decimal('100.00'), 4),
#  ('Palau', 2019, Decimal('100.00'), 5),
#  ('Palau', 2020, Decimal('100.00'), 6),
#  ('Panama', 2019, Decimal('92.67'), 1),
#  ('Panama', 2020, Decimal('92.67'), 2),
#  ('Panama', 2018, Decimal('92.33'), 3),
#  ('Panama', 2017, Decimal('92.33'), 4),
#  ('Panama', 2016, Decimal('91.67'), 5),
#  ('Panama', 2015, Decimal('91.67'), 6),
#  ('Papua New Guinea', 2020, Decimal('56.67'), 1),
#  ('Papua New Guinea', 2019, Decimal('56.33'), 2),
#  ('Papua New Guinea', 2018, Decimal('55.67'), 3),
#  ('Papua New Guinea', 2017, Decimal('55.00'), 4),
#  ('Papua New Guinea', 2016, Decimal('54.33'), 5),
#  ('Papua New Guinea', 2015, Decimal('53.67'), 6),
#  ('Paraguay', 2018, Decimal('99.67'), 1),
#  ('Paraguay', 2019, Decimal('99.67'), 2),
#  ('Paraguay', 2020, Decimal('99.67'), 3),
#  ('Paraguay', 2017, Decimal('99.33'), 4),
#  ('Paraguay', 2016, Decimal('97.67'), 5),
#  ('Paraguay', 2015, Decimal('96.33'), 6),
#  ('Peru', 2020, Decimal('90.33'), 1),
#  ('Peru', 2019, Decimal('89.33'), 2),
#  ('Peru', 2018, Decimal('88.67'), 3),
#  ('Peru', 2017, Decimal('87.67'), 4),
#  ('Peru', 2016, Decimal('87.33'), 5),
#  ('Peru', 2015, Decimal('86.00'), 6),
#  ('Philippines', 2020, Decimal('94.00'), 1),
#  ('Philippines', 2019, Decimal('93.67'), 2),
#  ('Philippines', 2018, Decimal('93.33'), 3),
#  ('Philippines', 2017, Decimal('93.00'), 4),
#  ('Philippines', 2016, Decimal('92.67'), 5),
#  ('Philippines', 2015, Decimal('92.00'), 6),
#  ('Puerto Rico', 2019, Decimal('100.00'), 1),
#  ('Puerto Rico', 2018, Decimal('100.00'), 2),
#  ('Puerto Rico', 2017, Decimal('100.00'), 3),
#  ('Puerto Rico', 2016, Decimal('100.00'), 4),
#  ('Puerto Rico', 2020, Decimal('100.00'), 5),
#  ('Puerto Rico', 2015, Decimal('99.00'), 6),
#  ('Qatar', 2016, Decimal('100.00'), 1),
#  ('Qatar', 2015, Decimal('100.00'), 2),
#  ('Qatar', 2017, Decimal('100.00'), 3),
#  ('Qatar', 2020, Decimal('100.00'), 4),
#  ('Qatar', 2019, Decimal('100.00'), 5),
#  ('Qatar', 2018, Decimal('100.00'), 6),
#  ('Republic of Korea', 2020, Decimal('100.00'), 1),
#  ('Republic of Korea', 2016, Decimal('100.00'), 2),
#  ('Republic of Korea', 2017, Decimal('100.00'), 3),
#  ('Republic of Korea', 2018, Decimal('100.00'), 4),
#  ('Republic of Korea', 2019, Decimal('100.00'), 5),
#  ('Republic of Korea', 2015, Decimal('99.00'), 6),
#  ('Réunion', 2016, Decimal('100.00'), 1),
#  ('Réunion', 2020, Decimal('100.00'), 2),
#  ('Réunion', 2015, Decimal('100.00'), 3),
#  ('Réunion', 2017, Decimal('100.00'), 4),
#  ('Réunion', 2018, Decimal('100.00'), 5),
#  ('Réunion', 2019, Decimal('100.00'), 6),
#  ('Rwanda', 2019, Decimal('66.33'), 1),
#  ('Rwanda', 2020, Decimal('66.33'), 2),
#  ('Rwanda', 2018, Decimal('65.67'), 3),
#  ('Rwanda', 2017, Decimal('65.00'), 4),
#  ('Rwanda', 2016, Decimal('64.00'), 5),
#  ('Rwanda', 2015, Decimal('63.00'), 6),
#  ('Saint Barthélemy', 2018, Decimal('100.00'), 1),
#  ('Saint Barthélemy', 2019, Decimal('100.00'), 2),
#  ('Saint Barthélemy', 2020, Decimal('100.00'), 3),
#  ('Saint Barthélemy', 2015, Decimal('100.00'), 4),
#  ('Saint Barthélemy', 2016, Decimal('100.00'), 5),
#  ('Saint Barthélemy', 2017, Decimal('100.00'), 6),
#  ('Saint Helena', 2020, Decimal('99.00'), 1),
#  ('Saint Helena', 2015, Decimal('99.00'), 2),
#  ('Saint Helena', 2016, Decimal('99.00'), 3),
#  ('Saint Helena', 2017, Decimal('99.00'), 4),
#  ('Saint Helena', 2018, Decimal('99.00'), 5),
#  ('Saint Helena', 2019, Decimal('99.00'), 6),
#  ('Saint Kitts and Nevis', 2017, Decimal('99.00'), 1),
#  ('Saint Kitts and Nevis', 2016, Decimal('99.00'), 2),
#  ('Saint Kitts and Nevis', 2015, Decimal('99.00'), 3),
#  ('Saint Lucia', 2020, Decimal('97.00'), 1),
#  ('Saint Lucia', 2019, Decimal('97.00'), 2),
#  ('Saint Lucia', 2018, Decimal('97.00'), 3),
#  ('Saint Lucia', 2017, Decimal('96.33'), 4),
#  ('Saint Lucia', 2016, Decimal('96.33'), 5),
#  ('Saint Lucia', 2015, Decimal('96.00'), 6),
#  ('Saint Martin (French Part)', 2017, Decimal('100.00'), 1),
#  ('Saint Martin (French Part)', 2018, Decimal('100.00'), 2),
#  ('Saint Martin (French Part)', 2019, Decimal('100.00'), 3),
#  ('Saint Martin (French Part)', 2020, Decimal('100.00'), 4),
#  ('Saint Martin (French Part)', 2016, Decimal('100.00'), 5),
#  ('Saint Martin (French Part)', 2015, Decimal('100.00'), 6),
#  ('Saint Pierre and Miquelon', 2015, Decimal('91.00'), 1),
#  ('Saint Pierre and Miquelon', 2020, Decimal('91.00'), 2),
#  ('Saint Pierre and Miquelon', 2019, Decimal('91.00'), 3),
#  ('Saint Pierre and Miquelon', 2018, Decimal('91.00'), 4),
#  ('Saint Pierre and Miquelon', 2017, Decimal('91.00'), 5),
#  ('Saint Pierre and Miquelon', 2016, Decimal('91.00'), 6),
#  ('Saint Vincent and the Grenadines', 2018, Decimal('95.00'), 1),
#  ('Saint Vincent and the Grenadines', 2015, Decimal('95.00'), 2),
#  ('Saint Vincent and the Grenadines', 2017, Decimal('95.00'), 3),
#  ('Saint Vincent and the Grenadines', 2016, Decimal('95.00'), 4),
#  ('Samoa', 2018, Decimal('92.00'), 1),
#  ('Samoa', 2016, Decimal('92.00'), 2),
#  ('Samoa', 2017, Decimal('92.00'), 3),
#  ('Samoa', 2019, Decimal('92.00'), 4),
#  ('Samoa', 2020, Decimal('92.00'), 5),
#  ('Samoa', 2015, Decimal('91.00'), 6),
#  ('Sao Tome and Principe', 2020, Decimal('77.33'), 1),
#  ('Sao Tome and Principe', 2019, Decimal('77.33'), 2),
#  ('Sao Tome and Principe', 2017, Decimal('77.00'), 3),
#  ('Sao Tome and Principe', 2018, Decimal('77.00'), 4),
#  ('Sao Tome and Principe', 2016, Decimal('76.67'), 5),
#  ('Sao Tome and Principe', 2015, Decimal('76.00'), 6),
#  ('Saudi Arabia', 2018, Decimal('100.00'), 1),
#  ('Saudi Arabia', 2020, Decimal('100.00'), 2),
#  ('Saudi Arabia', 2019, Decimal('100.00'), 3),
#  ('Saudi Arabia', 2017, Decimal('100.00'), 4),
#  ('Saudi Arabia', 2016, Decimal('100.00'), 5),
#  ('Saudi Arabia', 2015, Decimal('100.00'), 6),
#  ('Senegal', 2020, Decimal('85.00'), 1),
#  ('Senegal', 2019, Decimal('84.00'), 2),
#  ('Senegal', 2018, Decimal('82.67'), 3),
#  ('Senegal', 2017, Decimal('81.67'), 4),
#  ('Senegal', 2016, Decimal('80.67'), 5),
#  ('Senegal', 2015, Decimal('79.67'), 6),
#  ('Seychelles', 2019, Decimal('97.00'), 1),
#  ('Seychelles', 2016, Decimal('96.00'), 2),
#  ('Seychelles', 2018, Decimal('96.00'), 3),
#  ('Seychelles', 2015, Decimal('96.00'), 4),
#  ('Seychelles', 2017, Decimal('96.00'), 5),
#  ('Sierra Leone', 2020, Decimal('65.00'), 1),
#  ('Sierra Leone', 2019, Decimal('64.00'), 2),
#  ('Sierra Leone', 2018, Decimal('62.67'), 3),
#  ('Sierra Leone', 2017, Decimal('61.67'), 4),
#  ('Sierra Leone', 2016, Decimal('60.67'), 5),
#  ('Sierra Leone', 2015, Decimal('60.00'), 6),
#  ('Singapore', 2015, Decimal('100.00'), 1),
#  ('Singapore', 2018, Decimal('100.00'), 2),
#  ('Singapore', 2017, Decimal('100.00'), 3),
#  ('Singapore', 2019, Decimal('100.00'), 4),
#  ('Singapore', 2020, Decimal('100.00'), 5),
#  ('Singapore', 2016, Decimal('100.00'), 6),
#  ('Sint Maarten (Dutch part)', 2016, Decimal('95.00'), 1),
#  ('Sint Maarten (Dutch part)', 2017, Decimal('95.00'), 2),
#  ('Sint Maarten (Dutch part)', 2015, Decimal('95.00'), 3),
#  ('Solomon Islands', 2015, Decimal('74.33'), 1),
#  ('Solomon Islands', 2016, Decimal('74.00'), 2),
#  ('Solomon Islands', 2017, Decimal('73.33'), 3),
#  ('Solomon Islands', 2020, Decimal('72.33'), 4),
#  ('Solomon Islands', 2018, Decimal('72.33'), 5),
#  ('Solomon Islands', 2019, Decimal('72.33'), 6),
#  ('Somalia', 2020, Decimal('57.33'), 1),
#  ('Somalia', 2019, Decimal('56.33'), 2),
#  ('Somalia', 2018, Decimal('54.67'), 3),
#  ('Somalia', 2017, Decimal('53.33'), 4),
#  ('Somalia', 2016, Decimal('52.00'), 5),
#  ('Somalia', 2015, Decimal('50.67'), 6),
#  ('South Africa', 2020, Decimal('92.00'), 1),
#  ('South Africa', 2019, Decimal('91.67'), 2),
#  ('South Africa', 2018, Decimal('91.33'), 3),
#  ('South Africa', 2017, Decimal('91.00'), 4),
#  ('South Africa', 2016, Decimal('90.33'), 5),
#  ('South Africa', 2015, Decimal('90.00'), 6),
#  ('South Sudan', 2020, Decimal('48.33'), 1),
#  ('South Sudan', 2019, Decimal('48.33'), 2),
#  ('South Sudan', 2018, Decimal('47.67'), 3),
#  ('South Sudan', 2017, Decimal('47.00'), 4),
#  ('South Sudan', 2016, Decimal('46.67'), 5),
#  ('South Sudan', 2015, Decimal('46.33'), 6),
#  ('Sri Lanka', 2020, Decimal('94.33'), 1),
#  ('Sri Lanka', 2019, Decimal('94.33'), 2),
#  ('Sri Lanka', 2018, Decimal('94.33'), 3),
#  ('Sri Lanka', 2017, Decimal('93.67'), 4),
#  ('Sri Lanka', 2016, Decimal('93.00'), 5),
#  ('Sri Lanka', 2015, Decimal('92.00'), 6),
#  ('State of Palestine', 2020, Decimal('98.33'), 1),
#  ('State of Palestine', 2019, Decimal('97.67'), 2),
#  ('State of Palestine', 2017, Decimal('97.00'), 3),
#  ('State of Palestine', 2018, Decimal('97.00'), 4),
#  ('State of Palestine', 2016, Decimal('96.67'), 5),
#  ('State of Palestine', 2015, Decimal('96.00'), 6),
#  ('Sudan', 2018, Decimal('62.33'), 1),
#  ('Sudan', 2017, Decimal('62.33'), 2),
#  ('Sudan', 2019, Decimal('62.33'), 3),
#  ('Sudan', 2020, Decimal('62.33'), 4),
#  ('Sudan', 2016, Decimal('62.33'), 5),
#  ('Sudan', 2015, Decimal('61.33'), 6),
#  ('Suriname', 2020, Decimal('98.00'), 1),
#  ('Suriname', 2019, Decimal('97.33'), 2),
#  ('Suriname', 2018, Decimal('96.67'), 3),
#  ('Suriname', 2017, Decimal('96.33'), 4),
#  ('Suriname', 2016, Decimal('95.33'), 5),
#  ('Suriname', 2015, Decimal('95.00'), 6),
#  ('Syrian Arab Republic', 2016, Decimal('93.67'), 1),
#  ('Syrian Arab Republic', 2017, Decimal('93.67'), 2),
#  ('Syrian Arab Republic', 2018, Decimal('93.67'), 3),
#  ('Syrian Arab Republic', 2019, Decimal('93.67'), 4),
#  ('Syrian Arab Republic', 2020, Decimal('93.67'), 5),
#  ('Syrian Arab Republic', 2015, Decimal('93.33'), 6),
#  ('Tajikistan', 2020, Decimal('85.00'), 1),
#  ('Tajikistan', 2019, Decimal('85.00'), 2),
#  ('Tajikistan', 2018, Decimal('83.33'), 3),
#  ('Tajikistan', 2017, Decimal('82.33'), 4),
#  ('Tajikistan', 2016, Decimal('81.33'), 5),
#  ('Tajikistan', 2015, Decimal('80.33'), 6),
#  ('Thailand', 2020, Decimal('100.00'), 1),
#  ('Thailand', 2019, Decimal('100.00'), 2),
#  ('Thailand', 2018, Decimal('100.00'), 3),
#  ('Thailand', 2017, Decimal('100.00'), 4),
#  ('Thailand', 2016, Decimal('99.33'), 5),
#  ('Thailand', 2015, Decimal('99.33'), 6),
#  ('Timor-Leste', 2020, Decimal('87.00'), 1),
#  ('Timor-Leste', 2019, Decimal('86.00'), 2),
#  ('Timor-Leste', 2018, Decimal('84.33'), 3),
#  ('Timor-Leste', 2017, Decimal('82.33'), 4),
#  ('Timor-Leste', 2016, Decimal('80.67'), 5),
#  ('Timor-Leste', 2015, Decimal('78.00'), 6),
#  ('Togo', 2020, Decimal('70.67'), 1),
#  ('Togo', 2019, Decimal('70.33'), 2),
#  ('Togo', 2018, Decimal('69.33'), 3),
#  ('Togo', 2017, Decimal('68.33'), 4),
#  ('Togo', 2016, Decimal('67.33'), 5),
#  ('Togo', 2015, Decimal('66.33'), 6),
#  ('Tokelau', 2020, Decimal('100.00'), 1),
#  ('Tokelau', 2018, Decimal('100.00'), 2),
#  ('Tokelau', 2016, Decimal('100.00'), 3),
#  ('Tokelau', 2017, Decimal('100.00'), 4),
#  ('Tokelau', 2019, Decimal('100.00'), 5),
#  ('Tokelau', 2015, Decimal('99.00'), 6),
#  ('Tonga', 2020, Decimal('99.00'), 1),
#  ('Tonga', 2018, Decimal('98.67'), 2),
#  ('Tonga', 2019, Decimal('98.67'), 3),
#  ('Tonga', 2015, Decimal('98.67'), 4),
#  ('Tonga', 2016, Decimal('98.67'), 5),
#  ('Tonga', 2017, Decimal('98.67'), 6),
#  ('Trinidad and Tobago', 2017, Decimal('99.00'), 1),
#  ('Trinidad and Tobago', 2016, Decimal('99.00'), 2),
#  ('Trinidad and Tobago', 2019, Decimal('99.00'), 3),
#  ('Trinidad and Tobago', 2018, Decimal('99.00'), 4),
#  ('Trinidad and Tobago', 2020, Decimal('99.00'), 5),
#  ('Trinidad and Tobago', 2015, Decimal('98.00'), 6),
#  ('Tunisia', 2020, Decimal('97.00'), 1),
#  ('Tunisia', 2019, Decimal('96.00'), 2),
#  ('Tunisia', 2018, Decimal('95.67'), 3),
#  ('Tunisia', 2017, Decimal('94.67'), 4),
#  ('Tunisia', 2016, Decimal('93.67'), 5),
#  ('Tunisia', 2015, Decimal('93.33'), 6),
#  ('Türkiye', 2020, Decimal('96.67'), 1),
#  ('Türkiye', 2019, Decimal('96.67'), 2),
#  ('Türkiye', 2018, Decimal('96.33'), 3),
#  ('Türkiye', 2017, Decimal('96.33'), 4),
#  ('Türkiye', 2016, Decimal('96.00'), 5),
#  ('Türkiye', 2015, Decimal('95.67'), 6),
#  ('Turkmenistan', 2019, Decimal('100.00'), 1),
#  ('Turkmenistan', 2020, Decimal('100.00'), 2),
#  ('Turkmenistan', 2018, Decimal('99.33'), 3),
#  ('Turkmenistan', 2017, Decimal('98.67'), 4),
#  ('Turkmenistan', 2016, Decimal('98.00'), 5),
#  ('Turkmenistan', 2015, Decimal('97.67'), 6),
#  ('Turks and Caicos Islands', 2016, Decimal('94.00'), 1),
#  ('Turks and Caicos Islands', 2017, Decimal('94.00'), 2),
#  ('Turks and Caicos Islands', 2018, Decimal('94.00'), 3),
#  ('Turks and Caicos Islands', 2015, Decimal('94.00'), 4),
#  ('Tuvalu', 2019, Decimal('100.00'), 1),
#  ('Tuvalu', 2020, Decimal('100.00'), 2),
#  ('Tuvalu', 2017, Decimal('100.00'), 3),
#  ('Tuvalu', 2018, Decimal('100.00'), 4),
#  ('Tuvalu', 2015, Decimal('100.00'), 5),
#  ('Tuvalu', 2016, Decimal('100.00'), 6),
#  ('Uganda', 2020, Decimal('61.00'), 1),
#  ('Uganda', 2019, Decimal('59.33'), 2),
#  ('Uganda', 2018, Decimal('58.67'), 3),
#  ('Uganda', 2017, Decimal('57.00'), 4),
#  ('Uganda', 2016, Decimal('55.67'), 5),
#  ('Uganda', 2015, Decimal('55.00'), 6),
#  ('United Arab Emirates', 2015, Decimal('100.00'), 1),
#  ('United Arab Emirates', 2017, Decimal('100.00'), 2),
#  ('United Arab Emirates', 2018, Decimal('100.00'), 3),
#  ('United Arab Emirates', 2020, Decimal('100.00'), 4),
#  ('United Arab Emirates', 2019, Decimal('100.00'), 5),
#  ('United Arab Emirates', 2016, Decimal('100.00'), 6),
#  ('United Republic of Tanzania', 2020, Decimal('65.00'), 1),
#  ('United Republic of Tanzania', 2019, Decimal('64.67'), 2),
#  ('United Republic of Tanzania', 2018, Decimal('63.33'), 3),
#  ('United Republic of Tanzania', 2017, Decimal('61.67'), 4),
#  ('United Republic of Tanzania', 2016, Decimal('60.00'), 5),
#  ('United Republic of Tanzania', 2015, Decimal('58.33'), 6),
#  ('United States of America', 2020, Decimal('100.00'), 1),
#  ('United States of America', 2017, Decimal('99.67'), 2),
#  ('United States of America', 2018, Decimal('99.67'), 3),
#  ('United States of America', 2019, Decimal('99.67'), 4),
#  ('United States of America', 2016, Decimal('99.33'), 5),
#  ('United States of America', 2015, Decimal('99.00'), 6),
#  ('United States Virgin Islands', 2019, Decimal('99.00'), 1),
#  ('United States Virgin Islands', 2018, Decimal('99.00'), 2),
#  ('United States Virgin Islands', 2017, Decimal('99.00'), 3),
#  ('United States Virgin Islands', 2016, Decimal('99.00'), 4),
#  ('United States Virgin Islands', 2015, Decimal('99.00'), 5),
#  ('United States Virgin Islands', 2020, Decimal('99.00'), 6),
#  ('Uruguay', 2017, Decimal('98.00'), 1),
#  ('Uruguay', 2018, Decimal('98.00'), 2),
#  ('Uruguay', 2019, Decimal('98.00'), 3),
#  ('Uruguay', 2020, Decimal('98.00'), 4),
#  ('Uruguay', 2016, Decimal('97.33'), 5),
#  ('Uruguay', 2015, Decimal('96.67'), 6),
#  ...]

# %% [markdown]
# Use the `DENSE_RANK()` function to order the countries based on their water access levels per year. And note the difference between it and ROW_NUMBER(). Remember The ORDER BY  changes here

# %%
# %%sql
# # Add your code here
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     DENSE_RANK() OVER (PARTITION BY Country_name ORDER BY Pct_managed_drinking_water_services DESC) AS Rank_water_access
# FROM
#     united_nations.Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Afghanistan', 2020, Decimal('80.33'), 1),
#  ('Afghanistan', 2019, Decimal('78.00'), 2),
#  ('Afghanistan', 2018, Decimal('75.33'), 3),
#  ('Afghanistan', 2017, Decimal('72.33'), 4),
#  ('Afghanistan', 2016, Decimal('69.67'), 5),
#  ('Afghanistan', 2015, Decimal('67.00'), 6),
#  ('Algeria', 2020, Decimal('93.33'), 1),
#  ('Algeria', 2019, Decimal('93.33'), 1),
#  ('Algeria', 2016, Decimal('93.00'), 2),
#  ('Algeria', 2018, Decimal('93.00'), 2),
#  ('Algeria', 2017, Decimal('93.00'), 2),
#  ('Algeria', 2015, Decimal('92.00'), 3),
#  ('American Samoa', 2020, Decimal('100.00'), 1),
#  ('American Samoa', 2018, Decimal('100.00'), 1),
#  ('American Samoa', 2017, Decimal('100.00'), 1),
#  ('American Samoa', 2016, Decimal('100.00'), 1),
#  ('American Samoa', 2019, Decimal('100.00'), 1),
#  ('American Samoa', 2015, Decimal('100.00'), 1),
#  ('Angola', 2020, Decimal('52.33'), 1),
#  ('Angola', 2018, Decimal('52.33'), 1),
#  ('Angola', 2019, Decimal('52.33'), 1),
#  ('Angola', 2017, Decimal('51.33'), 2),
#  ('Angola', 2016, Decimal('51.00'), 3),
#  ('Angola', 2015, Decimal('50.33'), 4),
#  ('Anguilla', 2015, Decimal('97.00'), 1),
#  ('Anguilla', 2016, Decimal('97.00'), 1),
#  ('Anguilla', 2017, Decimal('97.00'), 1),
#  ('Antigua and Barbuda', 2015, Decimal('97.00'), 1),
#  ('Antigua and Barbuda', 2017, Decimal('97.00'), 1),
#  ('Antigua and Barbuda', 2016, Decimal('97.00'), 1),
#  ('Argentina', 2020, Decimal('100.00'), 1),
#  ('Argentina', 2019, Decimal('100.00'), 1),
#  ('Argentina', 2018, Decimal('100.00'), 1),
#  ('Argentina', 2017, Decimal('100.00'), 1),
#  ('Argentina', 2016, Decimal('97.33'), 2),
#  ('Argentina', 2015, Decimal('97.33'), 2),
#  ('Armenia', 2018, Decimal('100.00'), 1),
#  ('Armenia', 2019, Decimal('100.00'), 1),
#  ('Armenia', 2020, Decimal('100.00'), 1),
#  ('Armenia', 2017, Decimal('100.00'), 1),
#  ('Armenia', 2016, Decimal('99.67'), 2),
#  ('Armenia', 2015, Decimal('99.67'), 2),
#  ('Aruba', 2016, Decimal('98.00'), 1),
#  ('Aruba', 2015, Decimal('98.00'), 1),
#  ('Australia', 2015, Decimal('100.00'), 1),
#  ('Australia', 2016, Decimal('100.00'), 1),
#  ('Australia', 2017, Decimal('100.00'), 1),
#  ('Australia', 2018, Decimal('100.00'), 1),
#  ('Australia', 2019, Decimal('100.00'), 1),
#  ('Australia', 2020, Decimal('100.00'), 1),
#  ('Azerbaijan', 2020, Decimal('95.67'), 1),
#  ('Azerbaijan', 2019, Decimal('95.00'), 2),
#  ('Azerbaijan', 2018, Decimal('94.33'), 3),
#  ('Azerbaijan', 2017, Decimal('93.67'), 4),
#  ('Azerbaijan', 2016, Decimal('92.33'), 5),
#  ('Azerbaijan', 2015, Decimal('91.67'), 6),
#  ('Bahamas', 2015, Decimal('99.00'), 1),
#  ('Bahamas', 2016, Decimal('99.00'), 1),
#  ('Bahamas', 2019, Decimal('99.00'), 1),
#  ('Bahamas', 2017, Decimal('99.00'), 1),
#  ('Bahamas', 2018, Decimal('99.00'), 1),
#  ('Bahrain', 2016, Decimal('100.00'), 1),
#  ('Bahrain', 2020, Decimal('100.00'), 1),
#  ('Bahrain', 2019, Decimal('100.00'), 1),
#  ('Bahrain', 2018, Decimal('100.00'), 1),
#  ('Bahrain', 2017, Decimal('100.00'), 1),
#  ('Bahrain', 2015, Decimal('100.00'), 1),
#  ('Bangladesh', 2019, Decimal('97.67'), 1),
#  ('Bangladesh', 2020, Decimal('97.67'), 1),
#  ('Bangladesh', 2017, Decimal('97.33'), 2),
#  ('Bangladesh', 2016, Decimal('97.33'), 2),
#  ('Bangladesh', 2018, Decimal('97.33'), 2),
#  ('Bangladesh', 2015, Decimal('97.33'), 2),
#  ('Barbados', 2020, Decimal('99.00'), 1),
#  ('Barbados', 2019, Decimal('99.00'), 1),
#  ('Barbados', 2018, Decimal('99.00'), 1),
#  ('Barbados', 2017, Decimal('98.00'), 2),
#  ('Barbados', 2016, Decimal('98.00'), 2),
#  ('Barbados', 2015, Decimal('98.00'), 2),
#  ('Belize', 2018, Decimal('98.33'), 1),
#  ('Belize', 2019, Decimal('98.33'), 1),
#  ('Belize', 2020, Decimal('98.33'), 1),
#  ('Belize', 2017, Decimal('98.00'), 2),
#  ('Belize', 2016, Decimal('97.67'), 3),
#  ('Belize', 2015, Decimal('97.33'), 4),
#  ('Benin', 2018, Decimal('65.67'), 1),
#  ('Benin', 2017, Decimal('65.33'), 2),
#  ('Benin', 2019, Decimal('65.33'), 2),
#  ('Benin', 2020, Decimal('65.33'), 2),
#  ('Benin', 2015, Decimal('65.33'), 2),
#  ('Benin', 2016, Decimal('65.33'), 2),
#  ('Bermuda', 2015, Decimal('100.00'), 1),
#  ('Bermuda', 2016, Decimal('100.00'), 1),
#  ('Bermuda', 2020, Decimal('100.00'), 1),
#  ('Bermuda', 2019, Decimal('100.00'), 1),
#  ('Bermuda', 2018, Decimal('100.00'), 1),
#  ('Bermuda', 2017, Decimal('100.00'), 1),
#  ('Bhutan', 2020, Decimal('97.33'), 1),
#  ('Bhutan', 2019, Decimal('97.33'), 1),
#  ('Bhutan', 2017, Decimal('97.33'), 1),
#  ('Bhutan', 2018, Decimal('97.33'), 1),
#  ('Bhutan', 2016, Decimal('97.00'), 2),
#  ('Bhutan', 2015, Decimal('96.33'), 3),
#  ('Bolivia (Plurinational State of)', 2020, Decimal('90.67'), 1),
#  ('Bolivia (Plurinational State of)', 2019, Decimal('90.33'), 2),
#  ('Bolivia (Plurinational State of)', 2018, Decimal('89.67'), 3),
#  ('Bolivia (Plurinational State of)', 2017, Decimal('89.00'), 4),
#  ('Bolivia (Plurinational State of)', 2016, Decimal('88.00'), 5),
#  ('Bolivia (Plurinational State of)', 2015, Decimal('87.33'), 6),
#  ('Botswana', 2019, Decimal('89.67'), 1),
#  ('Botswana', 2020, Decimal('89.67'), 1),
#  ('Botswana', 2018, Decimal('88.33'), 2),
#  ('Botswana', 2017, Decimal('87.67'), 3),
#  ('Botswana', 2016, Decimal('86.67'), 4),
#  ('Botswana', 2015, Decimal('85.67'), 5),
#  ('Brazil', 2020, Decimal('98.33'), 1),
#  ('Brazil', 2019, Decimal('97.33'), 2),
#  ('Brazil', 2018, Decimal('97.00'), 3),
#  ('Brazil', 2017, Decimal('96.33'), 4),
#  ('Brazil', 2015, Decimal('95.33'), 5),
#  ('Brazil', 2016, Decimal('95.33'), 5),
#  ('British Virgin Islands', 2019, Decimal('100.00'), 1),
#  ('British Virgin Islands', 2015, Decimal('100.00'), 1),
#  ('British Virgin Islands', 2017, Decimal('100.00'), 1),
#  ('British Virgin Islands', 2020, Decimal('100.00'), 1),
#  ('British Virgin Islands', 2016, Decimal('100.00'), 1),
#  ('British Virgin Islands', 2018, Decimal('100.00'), 1),
#  ('Brunei Darussalam', 2016, Decimal('100.00'), 1),
#  ('Brunei Darussalam', 2017, Decimal('100.00'), 1),
#  ('Brunei Darussalam', 2019, Decimal('100.00'), 1),
#  ('Brunei Darussalam', 2020, Decimal('100.00'), 1),
#  ('Brunei Darussalam', 2018, Decimal('100.00'), 1),
#  ('Brunei Darussalam', 2015, Decimal('99.67'), 2),
#  ('Burkina Faso', 2015, Decimal('56.33'), 1),
#  ('Burkina Faso', 2016, Decimal('56.00'), 2),
#  ('Burkina Faso', 2017, Decimal('55.00'), 3),
#  ('Burkina Faso', 2018, Decimal('54.33'), 4),
#  ('Burkina Faso', 2019, Decimal('54.00'), 5),
#  ('Burkina Faso', 2020, Decimal('53.33'), 6),
#  ('Burundi', 2019, Decimal('70.33'), 1),
#  ('Burundi', 2020, Decimal('70.33'), 1),
#  ('Burundi', 2017, Decimal('69.33'), 2),
#  ('Burundi', 2018, Decimal('69.33'), 2),
#  ('Burundi', 2016, Decimal('68.33'), 3),
#  ('Burundi', 2015, Decimal('68.33'), 3),
#  ('Cabo Verde', 2020, Decimal('87.33'), 1),
#  ('Cabo Verde', 2019, Decimal('86.67'), 2),
#  ('Cabo Verde', 2018, Decimal('86.00'), 3),
#  ('Cabo Verde', 2017, Decimal('85.33'), 4),
#  ('Cabo Verde', 2016, Decimal('84.33'), 5),
#  ('Cabo Verde', 2015, Decimal('83.33'), 6),
#  ('Cambodia', 2019, Decimal('75.33'), 1),
#  ('Cambodia', 2020, Decimal('75.33'), 1),
#  ('Cambodia', 2018, Decimal('74.67'), 2),
#  ('Cambodia', 2017, Decimal('74.33'), 3),
#  ('Cambodia', 2016, Decimal('73.67'), 4),
#  ('Cambodia', 2015, Decimal('73.33'), 5),
#  ('Cameroon', 2020, Decimal('64.00'), 1),
#  ('Cameroon', 2019, Decimal('63.33'), 2),
#  ('Cameroon', 2018, Decimal('63.33'), 2),
#  ('Cameroon', 2017, Decimal('63.33'), 2),
#  ('Cameroon', 2015, Decimal('62.67'), 3),
#  ('Cameroon', 2016, Decimal('62.67'), 3),
#  ('Canada', 2015, Decimal('99.00'), 1),
#  ('Canada', 2016, Decimal('99.00'), 1),
#  ('Canada', 2017, Decimal('99.00'), 1),
#  ('Canada', 2018, Decimal('99.00'), 1),
#  ('Canada', 2019, Decimal('99.00'), 1),
#  ('Canada', 2020, Decimal('99.00'), 1),
#  ('Cayman Islands', 2015, Decimal('96.00'), 1),
#  ('Cayman Islands', 2016, Decimal('96.00'), 1),
#  ('Central African Republic', 2015, Decimal('44.00'), 1),
#  ('Central African Republic', 2016, Decimal('42.67'), 2),
#  ('Central African Republic', 2017, Decimal('41.33'), 3),
#  ('Central African Republic', 2018, Decimal('40.67'), 4),
#  ('Central African Republic', 2019, Decimal('39.33'), 5),
#  ('Central African Republic', 2020, Decimal('38.33'), 6),
#  ('Chad', 2020, Decimal('52.67'), 1),
#  ('Chad', 2019, Decimal('52.33'), 2),
#  ('Chad', 2018, Decimal('52.00'), 3),
#  ('Chad', 2017, Decimal('52.00'), 3),
#  ('Chad', 2016, Decimal('52.00'), 3),
#  ('Chad', 2015, Decimal('51.67'), 4),
#  ('Chile', 2017, Decimal('100.00'), 1),
#  ('Chile', 2018, Decimal('100.00'), 1),
#  ('Chile', 2019, Decimal('100.00'), 1),
#  ('Chile', 2020, Decimal('100.00'), 1),
#  ('Chile', 2016, Decimal('99.67'), 2),
#  ('Chile', 2015, Decimal('99.00'), 3),
#  ('China', 2020, Decimal('93.67'), 1),
#  ('China', 2019, Decimal('93.33'), 2),
#  ('China', 2018, Decimal('92.67'), 3),
#  ('China', 2017, Decimal('92.00'), 4),
#  ('China', 2015, Decimal('91.33'), 5),
#  ('China', 2016, Decimal('91.33'), 5),
#  ('Colombia', 2020, Decimal('94.67'), 1),
#  ('Colombia', 2019, Decimal('94.33'), 2),
#  ('Colombia', 2017, Decimal('94.00'), 3),
#  ('Colombia', 2018, Decimal('94.00'), 3),
#  ('Colombia', 2016, Decimal('93.67'), 4),
#  ('Colombia', 2015, Decimal('93.00'), 5),
#  ('Comoros', 2015, Decimal('81.67'), 1),
#  ('Comoros', 2019, Decimal('81.67'), 1),
#  ('Comoros', 2018, Decimal('81.67'), 1),
#  ('Comoros', 2017, Decimal('81.67'), 1),
#  ('Comoros', 2016, Decimal('81.67'), 1),
#  ('Congo', 2020, Decimal('69.00'), 1),
#  ('Congo', 2019, Decimal('69.00'), 1),
#  ('Congo', 2018, Decimal('68.67'), 2),
#  ('Congo', 2017, Decimal('68.67'), 2),
#  ('Congo', 2016, Decimal('67.67'), 3),
#  ('Congo', 2015, Decimal('66.33'), 4),
#  ('Cook Islands', 2019, Decimal('100.00'), 1),
#  ('Cook Islands', 2018, Decimal('100.00'), 1),
#  ('Cook Islands', 2017, Decimal('100.00'), 1),
#  ('Cook Islands', 2016, Decimal('100.00'), 1),
#  ('Cook Islands', 2015, Decimal('100.00'), 1),
#  ('Cook Islands', 2020, Decimal('100.00'), 1),
#  ('Costa Rica', 2017, Decimal('100.00'), 1),
#  ('Costa Rica', 2018, Decimal('100.00'), 1),
#  ('Costa Rica', 2019, Decimal('100.00'), 1),
#  ('Costa Rica', 2020, Decimal('100.00'), 1),
#  ('Costa Rica', 2016, Decimal('99.67'), 2),
#  ('Costa Rica', 2015, Decimal('99.00'), 3),
#  ("Côte d'Ivoire", 2015, Decimal('71.33'), 1),
#  ("Côte d'Ivoire", 2018, Decimal('71.00'), 2),
#  ("Côte d'Ivoire", 2017, Decimal('71.00'), 2),
#  ("Côte d'Ivoire", 2016, Decimal('71.00'), 2),
#  ("Côte d'Ivoire", 2020, Decimal('70.67'), 3),
#  ("Côte d'Ivoire", 2019, Decimal('70.67'), 3),
#  ('Cuba', 2020, Decimal('96.33'), 1),
#  ('Cuba', 2019, Decimal('96.33'), 1),
#  ('Cuba', 2018, Decimal('96.00'), 2),
#  ('Cuba', 2017, Decimal('95.33'), 3),
#  ('Cuba', 2016, Decimal('95.00'), 4),
#  ('Cuba', 2015, Decimal('94.67'), 5),
#  ('Curaçao', 2015, Decimal('99.00'), 1),
#  ('Curaçao', 2016, Decimal('99.00'), 1),
#  ('Curaçao', 2017, Decimal('99.00'), 1),
#  ('Cyprus', 2017, Decimal('100.00'), 1),
#  ('Cyprus', 2015, Decimal('100.00'), 1),
#  ('Cyprus', 2018, Decimal('100.00'), 1),
#  ('Cyprus', 2016, Decimal('100.00'), 1),
#  ('Cyprus', 2019, Decimal('100.00'), 1),
#  ('Cyprus', 2020, Decimal('100.00'), 1),
#  ("Democratic People's Republic of Korea", 2015, Decimal('94.67'), 1),
#  ("Democratic People's Republic of Korea", 2016, Decimal('94.33'), 2),
#  ("Democratic People's Republic of Korea", 2017, Decimal('94.00'), 3),
#  ("Democratic People's Republic of Korea", 2018, Decimal('93.33'), 4),
#  ("Democratic People's Republic of Korea", 2019, Decimal('93.33'), 4),
#  ("Democratic People's Republic of Korea", 2020, Decimal('93.33'), 4),
#  ('Democratic Republic of the Congo', 2020, Decimal('47.67'), 1),
#  ('Democratic Republic of the Congo', 2019, Decimal('47.00'), 2),
#  ('Democratic Republic of the Congo', 2018, Decimal('46.67'), 3),
#  ('Democratic Republic of the Congo', 2017, Decimal('46.00'), 4),
#  ('Democratic Republic of the Congo', 2016, Decimal('45.67'), 5),
#  ('Democratic Republic of the Congo', 2015, Decimal('45.33'), 6),
#  ('Djibouti', 2015, Decimal('69.67'), 1),
#  ('Djibouti', 2016, Decimal('69.33'), 2),
#  ('Djibouti', 2018, Decimal('69.33'), 2),
#  ('Djibouti', 2017, Decimal('69.33'), 2),
#  ('Djibouti', 2020, Decimal('69.00'), 3),
#  ('Djibouti', 2019, Decimal('69.00'), 3),
#  ('Dominica', 2017, Decimal('95.00'), 1),
#  ('Dominica', 2016, Decimal('95.00'), 1),
#  ('Dominica', 2015, Decimal('95.00'), 1),
#  ('Dominican Republic', 2020, Decimal('95.00'), 1),
#  ('Dominican Republic', 2019, Decimal('95.00'), 1),
#  ('Dominican Republic', 2018, Decimal('95.00'), 1),
#  ('Dominican Republic', 2017, Decimal('94.67'), 2),
#  ('Dominican Republic', 2016, Decimal('94.67'), 2),
#  ('Dominican Republic', 2015, Decimal('94.33'), 3),
#  ('Ecuador', 2020, Decimal('94.00'), 1),
#  ('Ecuador', 2019, Decimal('93.67'), 2),
#  ('Ecuador', 2018, Decimal('93.33'), 3),
#  ('Ecuador', 2017, Decimal('92.67'), 4),
#  ('Ecuador', 2016, Decimal('92.33'), 5),
#  ('Ecuador', 2015, Decimal('91.67'), 6),
#  ('Egypt', 2015, Decimal('99.33'), 1),
#  ('Egypt', 2016, Decimal('99.33'), 1),
#  ('Egypt', 2017, Decimal('99.33'), 1),
#  ('Egypt', 2018, Decimal('99.33'), 1),
#  ('Egypt', 2019, Decimal('99.33'), 1),
#  ('Egypt', 2020, Decimal('99.33'), 1),
#  ('El Salvador', 2018, Decimal('97.00'), 1),
#  ('El Salvador', 2019, Decimal('97.00'), 1),
#  ('El Salvador', 2020, Decimal('97.00'), 1),
#  ('El Salvador', 2017, Decimal('96.00'), 2),
#  ('El Salvador', 2016, Decimal('95.33'), 3),
#  ('El Salvador', 2015, Decimal('94.33'), 4),
#  ('Equatorial Guinea', 2017, Decimal('58.00'), 1),
#  ('Equatorial Guinea', 2016, Decimal('57.67'), 2),
#  ('Equatorial Guinea', 2015, Decimal('57.67'), 2),
#  ('Eritrea', 2016, Decimal('56.67'), 1),
#  ('Eritrea', 2015, Decimal('56.33'), 2),
#  ('Eswatini', 2020, Decimal('76.67'), 1),
#  ('Eswatini', 2019, Decimal('76.67'), 1),
#  ('Eswatini', 2018, Decimal('75.67'), 2),
#  ('Eswatini', 2017, Decimal('75.00'), 3),
#  ('Eswatini', 2016, Decimal('74.00'), 4),
#  ('Eswatini', 2015, Decimal('73.33'), 5),
#  ('Ethiopia', 2020, Decimal('58.00'), 1),
#  ('Ethiopia', 2019, Decimal('57.00'), 2),
#  ('Ethiopia', 2018, Decimal('55.67'), 3),
#  ('Ethiopia', 2017, Decimal('54.67'), 4),
#  ('Ethiopia', 2016, Decimal('53.33'), 5),
#  ('Ethiopia', 2015, Decimal('52.00'), 6),
#  ('Falkland Islands (Malvinas)', 2019, Decimal('91.00'), 1),
#  ('Falkland Islands (Malvinas)', 2018, Decimal('91.00'), 1),
#  ('Falkland Islands (Malvinas)', 2017, Decimal('91.00'), 1),
#  ('Falkland Islands (Malvinas)', 2015, Decimal('91.00'), 1),
#  ('Falkland Islands (Malvinas)', 2016, Decimal('91.00'), 1),
#  ('Falkland Islands (Malvinas)', 2020, Decimal('91.00'), 1),
#  ('Fiji', 2018, Decimal('93.67'), 1),
#  ('Fiji', 2017, Decimal('93.67'), 1),
#  ('Fiji', 2016, Decimal('93.67'), 1),
#  ('Fiji', 2019, Decimal('93.67'), 1),
#  ('Fiji', 2020, Decimal('93.67'), 1),
#  ('Fiji', 2015, Decimal('93.67'), 1),
#  ('French Guiana', 2020, Decimal('94.00'), 1),
#  ('French Guiana', 2019, Decimal('94.00'), 1),
#  ('French Guiana', 2018, Decimal('94.00'), 1),
#  ('French Guiana', 2015, Decimal('94.00'), 1),
#  ('French Guiana', 2016, Decimal('94.00'), 1),
#  ('French Guiana', 2017, Decimal('94.00'), 1),
#  ('French Polynesia', 2018, Decimal('100.00'), 1),
#  ('French Polynesia', 2017, Decimal('100.00'), 1),
#  ('French Polynesia', 2016, Decimal('100.00'), 1),
#  ('French Polynesia', 2015, Decimal('100.00'), 1),
#  ('French Polynesia', 2020, Decimal('100.00'), 1),
#  ('French Polynesia', 2019, Decimal('100.00'), 1),
#  ('Gabon', 2020, Decimal('73.33'), 1),
#  ('Gabon', 2019, Decimal('73.33'), 1),
#  ('Gabon', 2018, Decimal('73.00'), 2),
#  ('Gabon', 2017, Decimal('73.00'), 2),
#  ('Gabon', 2016, Decimal('72.33'), 3),
#  ('Gabon', 2015, Decimal('72.00'), 4),
#  ('Gambia', 2020, Decimal('79.33'), 1),
#  ('Gambia', 2019, Decimal('79.33'), 1),
#  ('Gambia', 2018, Decimal('78.67'), 2),
#  ('Gambia', 2017, Decimal('78.67'), 2),
#  ('Gambia', 2016, Decimal('78.33'), 3),
#  ('Gambia', 2015, Decimal('78.00'), 4),
#  ('Georgia', 2017, Decimal('96.67'), 1),
#  ('Georgia', 2020, Decimal('96.67'), 1),
#  ('Georgia', 2019, Decimal('96.67'), 1),
#  ('Georgia', 2018, Decimal('96.67'), 1),
#  ('Georgia', 2016, Decimal('96.00'), 2),
#  ('Georgia', 2015, Decimal('95.33'), 3),
#  ('Ghana', 2020, Decimal('84.67'), 1),
#  ('Ghana', 2019, Decimal('83.67'), 2),
#  ('Ghana', 2018, Decimal('82.67'), 3),
#  ('Ghana', 2017, Decimal('81.33'), 4),
#  ('Ghana', 2016, Decimal('80.33'), 5),
#  ('Ghana', 2015, Decimal('79.33'), 6),
#  ('Greenland', 2017, Decimal('100.00'), 1),
#  ('Greenland', 2015, Decimal('100.00'), 1),
#  ('Greenland', 2016, Decimal('100.00'), 1),
#  ('Greenland', 2018, Decimal('100.00'), 1),
#  ('Greenland', 2019, Decimal('100.00'), 1),
#  ('Greenland', 2020, Decimal('100.00'), 1),
#  ('Grenada', 2015, Decimal('96.00'), 1),
#  ('Grenada', 2016, Decimal('96.00'), 1),
#  ('Grenada', 2017, Decimal('96.00'), 1),
#  ('Guadeloupe', 2017, Decimal('100.00'), 1),
#  ('Guadeloupe', 2019, Decimal('100.00'), 1),
#  ('Guadeloupe', 2020, Decimal('100.00'), 1),
#  ('Guadeloupe', 2015, Decimal('100.00'), 1),
#  ('Guadeloupe', 2018, Decimal('100.00'), 1),
#  ('Guadeloupe', 2016, Decimal('100.00'), 1),
#  ('Guam', 2015, Decimal('100.00'), 1),
#  ('Guam', 2016, Decimal('100.00'), 1),
#  ('Guam', 2017, Decimal('100.00'), 1),
#  ('Guam', 2018, Decimal('100.00'), 1),
#  ('Guam', 2019, Decimal('100.00'), 1),
#  ('Guam', 2020, Decimal('100.00'), 1),
#  ('Guatemala', 2019, Decimal('94.00'), 1),
#  ('Guatemala', 2020, Decimal('94.00'), 1),
#  ('Guatemala', 2018, Decimal('93.00'), 2),
#  ('Guatemala', 2017, Decimal('92.67'), 3),
#  ('Guatemala', 2016, Decimal('92.33'), 4),
#  ('Guatemala', 2015, Decimal('92.00'), 5),
#  ('Guinea', 2020, Decimal('67.33'), 1),
#  ('Guinea', 2017, Decimal('67.33'), 1),
#  ('Guinea', 2019, Decimal('67.00'), 2),
#  ('Guinea', 2018, Decimal('67.00'), 2),
#  ('Guinea', 2015, Decimal('67.00'), 2),
#  ('Guinea', 2016, Decimal('67.00'), 2),
#  ('Guinea-Bissau', 2016, Decimal('60.33'), 1),
#  ('Guinea-Bissau', 2015, Decimal('60.00'), 2),
#  ('Guinea-Bissau', 2019, Decimal('60.00'), 2),
#  ('Guinea-Bissau', 2017, Decimal('60.00'), 2),
#  ('Guinea-Bissau', 2018, Decimal('60.00'), 2),
#  ('Guinea-Bissau', 2020, Decimal('60.00'), 2),
#  ('Guyana', 2020, Decimal('96.67'), 1),
#  ('Guyana', 2019, Decimal('96.67'), 1),
#  ('Guyana', 2018, Decimal('96.67'), 1),
#  ('Guyana', 2017, Decimal('96.67'), 1),
#  ('Guyana', 2016, Decimal('96.67'), 1),
#  ('Guyana', 2015, Decimal('96.00'), 2),
#  ('Haiti', 2020, Decimal('65.00'), 1),
#  ('Haiti', 2019, Decimal('64.67'), 2),
#  ('Haiti', 2018, Decimal('64.67'), 2),
#  ('Haiti', 2016, Decimal('64.33'), 3),
#  ('Haiti', 2017, Decimal('64.33'), 3),
#  ('Haiti', 2015, Decimal('64.00'), 4),
#  ('Honduras', 2020, Decimal('95.33'), 1),
#  ('Honduras', 2019, Decimal('94.67'), 2),
#  ('Honduras', 2018, Decimal('94.33'), 3),
#  ('Honduras', 2017, Decimal('93.67'), 4),
#  ('Honduras', 2016, Decimal('93.33'), 5),
#  ('Honduras', 2015, Decimal('92.67'), 6),
#  ('India', 2020, Decimal('91.00'), 1),
#  ('India', 2019, Decimal('90.67'), 2),
#  ('India', 2018, Decimal('90.33'), 3),
#  ('India', 2017, Decimal('90.00'), 4),
#  ('India', 2016, Decimal('89.33'), 5),
#  ('India', 2015, Decimal('89.00'), 6),
#  ('Indonesia', 2020, Decimal('92.00'), 1),
#  ('Indonesia', 2019, Decimal('91.33'), 2),
#  ('Indonesia', 2018, Decimal('90.67'), 3),
#  ('Indonesia', 2017, Decimal('89.67'), 4),
#  ('Indonesia', 2016, Decimal('89.00'), 5),
#  ('Indonesia', 2015, Decimal('88.33'), 6),
#  ('Iran (Islamic Republic of)', 2020, Decimal('96.67'), 1),
#  ('Iran (Islamic Republic of)', 2017, Decimal('96.33'), 2),
#  ('Iran (Islamic Republic of)', 2018, Decimal('96.33'), 2),
#  ('Iran (Islamic Republic of)', 2019, Decimal('96.33'), 2),
#  ('Iran (Islamic Republic of)', 2016, Decimal('96.00'), 3),
#  ('Iran (Islamic Republic of)', 2015, Decimal('95.67'), 4),
#  ('Iraq', 2020, Decimal('97.67'), 1),
#  ('Iraq', 2019, Decimal('97.00'), 2),
#  ('Iraq', 2018, Decimal('95.67'), 3),
#  ('Iraq', 2017, Decimal('94.67'), 4),
#  ('Iraq', 2016, Decimal('93.67'), 5),
#  ('Iraq', 2015, Decimal('92.33'), 6),
#  ('Israel', 2017, Decimal('100.00'), 1),
#  ('Israel', 2018, Decimal('100.00'), 1),
#  ('Israel', 2019, Decimal('100.00'), 1),
#  ('Israel', 2020, Decimal('100.00'), 1),
#  ('Israel', 2016, Decimal('100.00'), 1),
#  ('Israel', 2015, Decimal('100.00'), 1),
#  ('Jamaica', 2018, Decimal('90.33'), 1),
#  ('Jamaica', 2020, Decimal('90.33'), 1),
#  ('Jamaica', 2019, Decimal('90.33'), 1),
#  ('Jamaica', 2016, Decimal('90.33'), 1),
#  ('Jamaica', 2017, Decimal('90.33'), 1),
#  ('Jamaica', 2015, Decimal('90.00'), 2),
#  ('Japan', 2019, Decimal('99.00'), 1),
#  ('Japan', 2018, Decimal('99.00'), 1),
#  ('Japan', 2017, Decimal('99.00'), 1),
#  ('Japan', 2016, Decimal('99.00'), 1),
#  ('Japan', 2015, Decimal('99.00'), 1),
#  ('Japan', 2020, Decimal('99.00'), 1),
#  ('Jordan', 2017, Decimal('98.33'), 1),
#  ('Jordan', 2019, Decimal('98.33'), 1),
#  ('Jordan', 2020, Decimal('98.33'), 1),
#  ('Jordan', 2018, Decimal('98.33'), 1),
#  ('Jordan', 2015, Decimal('98.33'), 1),
#  ('Jordan', 2016, Decimal('98.33'), 1),
#  ('Kazakhstan', 2017, Decimal('95.00'), 1),
#  ('Kazakhstan', 2018, Decimal('95.00'), 1),
#  ('Kazakhstan', 2019, Decimal('95.00'), 1),
#  ('Kazakhstan', 2020, Decimal('95.00'), 1),
#  ('Kazakhstan', 2016, Decimal('94.67'), 2),
#  ('Kazakhstan', 2015, Decimal('94.67'), 2),
#  ('Kenya', 2020, Decimal('67.00'), 1),
#  ('Kenya', 2019, Decimal('66.33'), 2),
#  ('Kenya', 2018, Decimal('65.67'), 3),
#  ('Kenya', 2017, Decimal('65.67'), 3),
#  ('Kenya', 2016, Decimal('65.00'), 4),
#  ('Kenya', 2015, Decimal('64.33'), 5),
#  ('Kiribati', 2020, Decimal('77.00'), 1),
#  ('Kiribati', 2019, Decimal('76.00'), 2),
#  ('Kiribati', 2018, Decimal('75.33'), 3),
#  ('Kiribati', 2017, Decimal('75.00'), 4),
#  ('Kiribati', 2016, Decimal('74.33'), 5),
#  ('Kiribati', 2015, Decimal('73.67'), 6),
#  ('Kuwait', 2015, Decimal('100.00'), 1),
#  ('Kuwait', 2020, Decimal('100.00'), 1),
#  ('Kuwait', 2019, Decimal('100.00'), 1),
#  ('Kuwait', 2018, Decimal('100.00'), 1),
#  ('Kuwait', 2017, Decimal('100.00'), 1),
#  ('Kuwait', 2016, Decimal('100.00'), 1),
#  ('Kyrgyzstan', 2020, Decimal('92.67'), 1),
#  ('Kyrgyzstan', 2019, Decimal('91.67'), 2),
#  ('Kyrgyzstan', 2018, Decimal('91.33'), 3),
#  ('Kyrgyzstan', 2017, Decimal('91.00'), 4),
#  ('Kyrgyzstan', 2016, Decimal('90.33'), 5),
#  ('Kyrgyzstan', 2015, Decimal('89.67'), 6),
#  ("Lao People's Democratic Republic", 2019, Decimal('86.67'), 1),
#  ("Lao People's Democratic Republic", 2020, Decimal('86.67'), 1),
#  ("Lao People's Democratic Republic", 2018, Decimal('85.00'), 2),
#  ("Lao People's Democratic Republic", 2017, Decimal('83.33'), 3),
#  ("Lao People's Democratic Republic", 2016, Decimal('82.00'), 4),
#  ("Lao People's Democratic Republic", 2015, Decimal('79.67'), 5),
#  ('Lebanon', 2019, Decimal('93.00'), 1),
#  ('Lebanon', 2020, Decimal('93.00'), 1),
#  ('Lebanon', 2017, Decimal('92.00'), 2),
#  ('Lebanon', 2016, Decimal('92.00'), 2),
#  ('Lebanon', 2018, Decimal('92.00'), 2),
#  ('Lebanon', 2015, Decimal('91.00'), 3),
#  ('Lesotho', 2020, Decimal('76.33'), 1),
#  ('Lesotho', 2019, Decimal('76.00'), 2),
#  ('Lesotho', 2018, Decimal('76.00'), 2),
#  ('Lesotho', 2017, Decimal('75.33'), 3),
#  ('Lesotho', 2016, Decimal('75.00'), 4),
#  ('Lesotho', 2015, Decimal('74.67'), 5),
#  ('Liberia', 2019, Decimal('75.00'), 1),
#  ('Liberia', 2020, Decimal('75.00'), 1),
#  ('Liberia', 2017, Decimal('74.00'), 2),
#  ('Liberia', 2018, Decimal('74.00'), 2),
#  ('Liberia', 2016, Decimal('73.00'), 3),
#  ('Liberia', 2015, Decimal('72.67'), 4),
#  ('Libya', 2018, Decimal('100.00'), 1),
#  ('Libya', 2019, Decimal('100.00'), 1),
#  ('Libya', 2020, Decimal('100.00'), 1),
#  ('Libya', 2017, Decimal('99.00'), 2),
#  ('Libya', 2016, Decimal('98.00'), 3),
#  ('Libya', 2015, Decimal('97.00'), 4),
#  ('Madagascar', 2020, Decimal('56.33'), 1),
#  ('Madagascar', 2019, Decimal('56.00'), 2),
#  ('Madagascar', 2018, Decimal('55.33'), 3),
#  ('Madagascar', 2017, Decimal('54.67'), 4),
#  ('Madagascar', 2016, Decimal('54.00'), 5),
#  ('Madagascar', 2015, Decimal('53.33'), 6),
#  ('Malawi', 2020, Decimal('74.33'), 1),
#  ('Malawi', 2019, Decimal('73.67'), 2),
#  ('Malawi', 2018, Decimal('73.33'), 3),
#  ('Malawi', 2017, Decimal('72.67'), 4),
#  ('Malawi', 2016, Decimal('72.00'), 5),
#  ('Malawi', 2015, Decimal('71.33'), 6),
#  ('Malaysia', 2017, Decimal('95.67'), 1),
#  ('Malaysia', 2015, Decimal('95.67'), 1),
#  ('Malaysia', 2016, Decimal('95.67'), 1),
#  ('Malaysia', 2020, Decimal('95.33'), 2),
#  ('Malaysia', 2019, Decimal('95.33'), 2),
#  ('Malaysia', 2018, Decimal('95.33'), 2),
#  ('Maldives', 2019, Decimal('99.67'), 1),
#  ('Maldives', 2020, Decimal('99.67'), 1),
#  ('Maldives', 2017, Decimal('99.33'), 2),
#  ('Maldives', 2018, Decimal('99.33'), 2),
#  ('Maldives', 2015, Decimal('99.00'), 3),
#  ('Maldives', 2016, Decimal('99.00'), 3),
#  ('Mali', 2020, Decimal('83.67'), 1),
#  ('Mali', 2019, Decimal('82.00'), 2),
#  ('Mali', 2018, Decimal('80.67'), 3),
#  ('Mali', 2017, Decimal('79.33'), 4),
#  ('Mali', 2016, Decimal('77.67'), 5),
#  ('Mali', 2015, Decimal('76.00'), 6),
#  ('Marshall Islands', 2018, Decimal('90.00'), 1),
#  ('Marshall Islands', 2019, Decimal('90.00'), 1),
#  ('Marshall Islands', 2020, Decimal('90.00'), 1),
#  ('Marshall Islands', 2017, Decimal('89.67'), 2),
#  ('Marshall Islands', 2016, Decimal('89.67'), 2),
#  ('Marshall Islands', 2015, Decimal('89.33'), 3),
#  ('Martinique', 2020, Decimal('100.00'), 1),
#  ('Martinique', 2015, Decimal('100.00'), 1),
#  ('Martinique', 2016, Decimal('100.00'), 1),
#  ('Martinique', 2018, Decimal('100.00'), 1),
#  ('Martinique', 2019, Decimal('100.00'), 1),
#  ('Martinique', 2017, Decimal('100.00'), 1),
#  ('Mauritania', 2020, Decimal('70.33'), 1),
#  ('Mauritania', 2019, Decimal('70.00'), 2),
#  ('Mauritania', 2017, Decimal('70.00'), 2),
#  ('Mauritania', 2018, Decimal('70.00'), 2),
#  ('Mauritania', 2016, Decimal('68.33'), 3),
#  ('Mauritania', 2015, Decimal('66.67'), 4),
#  ('Mauritius', 2018, Decimal('100.00'), 1),
#  ('Mauritius', 2015, Decimal('100.00'), 1),
#  ('Mauritius', 2016, Decimal('100.00'), 1),
#  ('Mauritius', 2017, Decimal('100.00'), 1),
#  ('Mauritius', 2020, Decimal('100.00'), 1),
#  ('Mauritius', 2019, Decimal('100.00'), 1),
#  ('Mayotte', 2016, Decimal('97.00'), 1),
#  ('Mayotte', 2015, Decimal('97.00'), 1),
#  ('Mayotte', 2017, Decimal('97.00'), 1),
#  ('Mayotte', 2018, Decimal('96.00'), 2),
#  ('Mayotte', 2020, Decimal('96.00'), 2),
#  ('Mayotte', 2019, Decimal('96.00'), 2),
#  ('Mexico', 2020, Decimal('99.33'), 1),
#  ('Mexico', 2019, Decimal('98.67'), 2),
#  ('Mexico', 2018, Decimal('98.33'), 3),
#  ('Mexico', 2017, Decimal('98.00'), 4),
#  ('Mexico', 2016, Decimal('97.33'), 5),
#  ('Mexico', 2015, Decimal('96.67'), 6),
#  ('Micronesia (Federated States of)', 2019, Decimal('88.00'), 1),
#  ('Micronesia (Federated States of)', 2018, Decimal('88.00'), 1),
#  ('Micronesia (Federated States of)', 2016, Decimal('88.00'), 1),
#  ('Micronesia (Federated States of)', 2015, Decimal('88.00'), 1),
#  ('Micronesia (Federated States of)', 2017, Decimal('88.00'), 1),
#  ('Mongolia', 2020, Decimal('81.00'), 1),
#  ('Mongolia', 2019, Decimal('80.00'), 2),
#  ('Mongolia', 2018, Decimal('79.00'), 3),
#  ('Mongolia', 2017, Decimal('78.00'), 4),
#  ('Mongolia', 2016, Decimal('77.00'), 5),
#  ('Mongolia', 2015, Decimal('75.67'), 6),
#  ('Montserrat', 2020, Decimal('98.00'), 1),
#  ('Montserrat', 2019, Decimal('98.00'), 1),
#  ('Montserrat', 2018, Decimal('98.00'), 1),
#  ('Montserrat', 2017, Decimal('98.00'), 1),
#  ('Montserrat', 2016, Decimal('98.00'), 1),
#  ('Montserrat', 2015, Decimal('98.00'), 1),
#  ('Morocco', 2020, Decimal('88.33'), 1),
#  ('Morocco', 2019, Decimal('87.33'), 2),
#  ('Morocco', 2018, Decimal('85.67'), 3),
#  ('Morocco', 2017, Decimal('84.00'), 4),
#  ('Morocco', 2016, Decimal('83.00'), 5),
#  ('Morocco', 2015, Decimal('81.33'), 6),
#  ('Mozambique', 2020, Decimal('66.67'), 1),
#  ('Mozambique', 2019, Decimal('64.33'), 2),
#  ('Mozambique', 2018, Decimal('62.33'), 3),
#  ('Mozambique', 2017, Decimal('60.00'), 4),
#  ('Mozambique', 2016, Decimal('58.00'), 5),
#  ('Mozambique', 2015, Decimal('55.67'), 6),
#  ('Myanmar', 2020, Decimal('85.67'), 1),
#  ('Myanmar', 2019, Decimal('84.00'), 2),
#  ('Myanmar', 2018, Decimal('82.33'), 3),
#  ('Myanmar', 2017, Decimal('80.33'), 4),
#  ('Myanmar', 2016, Decimal('78.33'), 5),
#  ('Myanmar', 2015, Decimal('76.33'), 6),
#  ('Namibia', 2018, Decimal('83.67'), 1),
#  ('Namibia', 2019, Decimal('83.67'), 1),
#  ('Namibia', 2020, Decimal('83.67'), 1),
#  ('Namibia', 2017, Decimal('83.33'), 2),
#  ('Namibia', 2015, Decimal('83.33'), 2),
#  ('Namibia', 2016, Decimal('83.00'), 3),
#  ('Nauru', 2019, Decimal('100.00'), 1),
#  ('Nauru', 2016, Decimal('100.00'), 1),
#  ('Nauru', 2015, Decimal('100.00'), 1),
#  ('Nauru', 2020, Decimal('100.00'), 1),
#  ('Nauru', 2017, Decimal('100.00'), 1),
#  ('Nauru', 2018, Decimal('100.00'), 1),
#  ('Nepal', 2020, Decimal('90.00'), 1),
#  ('Nepal', 2019, Decimal('90.00'), 1),
#  ('Nepal', 2018, Decimal('89.33'), 2),
#  ('Nepal', 2017, Decimal('89.00'), 3),
#  ('Nepal', 2016, Decimal('88.67'), 4),
#  ('Nepal', 2015, Decimal('88.33'), 5),
#  ('New Caledonia', 2020, Decimal('99.00'), 1),
#  ('New Caledonia', 2017, Decimal('99.00'), 1),
#  ('New Caledonia', 2018, Decimal('99.00'), 1),
#  ('New Caledonia', 2019, Decimal('99.00'), 1),
#  ('New Caledonia', 2015, Decimal('98.00'), 2),
#  ('New Caledonia', 2016, Decimal('98.00'), 2),
#  ('New Zealand', 2016, Decimal('100.00'), 1),
#  ('New Zealand', 2015, Decimal('100.00'), 1),
#  ('New Zealand', 2020, Decimal('100.00'), 1),
#  ('New Zealand', 2019, Decimal('100.00'), 1),
#  ('New Zealand', 2018, Decimal('100.00'), 1),
#  ('New Zealand', 2017, Decimal('100.00'), 1),
#  ('Nicaragua', 2015, Decimal('79.33'), 1),
#  ('Nicaragua', 2018, Decimal('79.33'), 1),
#  ('Nicaragua', 2019, Decimal('79.33'), 1),
#  ('Nicaragua', 2020, Decimal('79.33'), 1),
#  ('Nicaragua', 2016, Decimal('79.00'), 2),
#  ('Nicaragua', 2017, Decimal('79.00'), 2),
#  ('Niger', 2019, Decimal('57.33'), 1),
#  ('Niger', 2020, Decimal('57.33'), 1),
#  ('Niger', 2016, Decimal('57.00'), 2),
#  ('Niger', 2017, Decimal('57.00'), 2),
#  ('Niger', 2018, Decimal('57.00'), 2),
#  ('Niger', 2015, Decimal('56.67'), 3),
#  ('Nigeria', 2020, Decimal('77.33'), 1),
#  ('Nigeria', 2019, Decimal('75.67'), 2),
#  ('Nigeria', 2018, Decimal('74.00'), 3),
#  ('Nigeria', 2017, Decimal('72.33'), 4),
#  ('Nigeria', 2016, Decimal('71.00'), 5),
#  ('Nigeria', 2015, Decimal('69.00'), 6),
#  ('Niue', 2015, Decimal('98.00'), 1),
#  ('Niue', 2019, Decimal('97.00'), 2),
#  ('Niue', 2020, Decimal('97.00'), 2),
#  ('Niue', 2018, Decimal('97.00'), 2),
#  ('Niue', 2016, Decimal('97.00'), 2),
#  ('Niue', 2017, Decimal('97.00'), 2),
#  ('Northern Mariana Islands', 2020, Decimal('100.00'), 1),
#  ('Northern Mariana Islands', 2019, Decimal('100.00'), 1),
#  ('Northern Mariana Islands', 2018, Decimal('100.00'), 1),
#  ('Northern Mariana Islands', 2017, Decimal('100.00'), 1),
#  ('Northern Mariana Islands', 2016, Decimal('100.00'), 1),
#  ('Northern Mariana Islands', 2015, Decimal('100.00'), 1),
#  ('Oman', 2020, Decimal('87.67'), 1),
#  ('Oman', 2019, Decimal('87.67'), 1),
#  ('Oman', 2018, Decimal('87.00'), 2),
#  ('Oman', 2016, Decimal('86.67'), 3),
#  ('Oman', 2017, Decimal('86.67'), 3),
#  ('Oman', 2015, Decimal('86.00'), 4),
#  ('Pakistan', 2020, Decimal('90.67'), 1),
#  ('Pakistan', 2017, Decimal('90.33'), 2),
#  ('Pakistan', 2018, Decimal('90.33'), 2),
#  ('Pakistan', 2019, Decimal('90.33'), 2),
#  ('Pakistan', 2015, Decimal('90.00'), 3),
#  ('Pakistan', 2016, Decimal('90.00'), 3),
#  ('Palau', 2016, Decimal('100.00'), 1),
#  ('Palau', 2017, Decimal('100.00'), 1),
#  ('Palau', 2018, Decimal('100.00'), 1),
#  ('Palau', 2015, Decimal('100.00'), 1),
#  ('Palau', 2019, Decimal('100.00'), 1),
#  ('Palau', 2020, Decimal('100.00'), 1),
#  ('Panama', 2019, Decimal('92.67'), 1),
#  ('Panama', 2020, Decimal('92.67'), 1),
#  ('Panama', 2018, Decimal('92.33'), 2),
#  ('Panama', 2017, Decimal('92.33'), 2),
#  ('Panama', 2016, Decimal('91.67'), 3),
#  ('Panama', 2015, Decimal('91.67'), 3),
#  ('Papua New Guinea', 2020, Decimal('56.67'), 1),
#  ('Papua New Guinea', 2019, Decimal('56.33'), 2),
#  ('Papua New Guinea', 2018, Decimal('55.67'), 3),
#  ('Papua New Guinea', 2017, Decimal('55.00'), 4),
#  ('Papua New Guinea', 2016, Decimal('54.33'), 5),
#  ('Papua New Guinea', 2015, Decimal('53.67'), 6),
#  ('Paraguay', 2018, Decimal('99.67'), 1),
#  ('Paraguay', 2019, Decimal('99.67'), 1),
#  ('Paraguay', 2020, Decimal('99.67'), 1),
#  ('Paraguay', 2017, Decimal('99.33'), 2),
#  ('Paraguay', 2016, Decimal('97.67'), 3),
#  ('Paraguay', 2015, Decimal('96.33'), 4),
#  ('Peru', 2020, Decimal('90.33'), 1),
#  ('Peru', 2019, Decimal('89.33'), 2),
#  ('Peru', 2018, Decimal('88.67'), 3),
#  ('Peru', 2017, Decimal('87.67'), 4),
#  ('Peru', 2016, Decimal('87.33'), 5),
#  ('Peru', 2015, Decimal('86.00'), 6),
#  ('Philippines', 2020, Decimal('94.00'), 1),
#  ('Philippines', 2019, Decimal('93.67'), 2),
#  ('Philippines', 2018, Decimal('93.33'), 3),
#  ('Philippines', 2017, Decimal('93.00'), 4),
#  ('Philippines', 2016, Decimal('92.67'), 5),
#  ('Philippines', 2015, Decimal('92.00'), 6),
#  ('Puerto Rico', 2019, Decimal('100.00'), 1),
#  ('Puerto Rico', 2018, Decimal('100.00'), 1),
#  ('Puerto Rico', 2017, Decimal('100.00'), 1),
#  ('Puerto Rico', 2016, Decimal('100.00'), 1),
#  ('Puerto Rico', 2020, Decimal('100.00'), 1),
#  ('Puerto Rico', 2015, Decimal('99.00'), 2),
#  ('Qatar', 2016, Decimal('100.00'), 1),
#  ('Qatar', 2015, Decimal('100.00'), 1),
#  ('Qatar', 2017, Decimal('100.00'), 1),
#  ('Qatar', 2020, Decimal('100.00'), 1),
#  ('Qatar', 2019, Decimal('100.00'), 1),
#  ('Qatar', 2018, Decimal('100.00'), 1),
#  ('Republic of Korea', 2020, Decimal('100.00'), 1),
#  ('Republic of Korea', 2016, Decimal('100.00'), 1),
#  ('Republic of Korea', 2017, Decimal('100.00'), 1),
#  ('Republic of Korea', 2018, Decimal('100.00'), 1),
#  ('Republic of Korea', 2019, Decimal('100.00'), 1),
#  ('Republic of Korea', 2015, Decimal('99.00'), 2),
#  ('Réunion', 2016, Decimal('100.00'), 1),
#  ('Réunion', 2020, Decimal('100.00'), 1),
#  ('Réunion', 2015, Decimal('100.00'), 1),
#  ('Réunion', 2017, Decimal('100.00'), 1),
#  ('Réunion', 2018, Decimal('100.00'), 1),
#  ('Réunion', 2019, Decimal('100.00'), 1),
#  ('Rwanda', 2019, Decimal('66.33'), 1),
#  ('Rwanda', 2020, Decimal('66.33'), 1),
#  ('Rwanda', 2018, Decimal('65.67'), 2),
#  ('Rwanda', 2017, Decimal('65.00'), 3),
#  ('Rwanda', 2016, Decimal('64.00'), 4),
#  ('Rwanda', 2015, Decimal('63.00'), 5),
#  ('Saint Barthélemy', 2018, Decimal('100.00'), 1),
#  ('Saint Barthélemy', 2019, Decimal('100.00'), 1),
#  ('Saint Barthélemy', 2020, Decimal('100.00'), 1),
#  ('Saint Barthélemy', 2015, Decimal('100.00'), 1),
#  ('Saint Barthélemy', 2016, Decimal('100.00'), 1),
#  ('Saint Barthélemy', 2017, Decimal('100.00'), 1),
#  ('Saint Helena', 2020, Decimal('99.00'), 1),
#  ('Saint Helena', 2015, Decimal('99.00'), 1),
#  ('Saint Helena', 2016, Decimal('99.00'), 1),
#  ('Saint Helena', 2017, Decimal('99.00'), 1),
#  ('Saint Helena', 2018, Decimal('99.00'), 1),
#  ('Saint Helena', 2019, Decimal('99.00'), 1),
#  ('Saint Kitts and Nevis', 2017, Decimal('99.00'), 1),
#  ('Saint Kitts and Nevis', 2016, Decimal('99.00'), 1),
#  ('Saint Kitts and Nevis', 2015, Decimal('99.00'), 1),
#  ('Saint Lucia', 2020, Decimal('97.00'), 1),
#  ('Saint Lucia', 2019, Decimal('97.00'), 1),
#  ('Saint Lucia', 2018, Decimal('97.00'), 1),
#  ('Saint Lucia', 2017, Decimal('96.33'), 2),
#  ('Saint Lucia', 2016, Decimal('96.33'), 2),
#  ('Saint Lucia', 2015, Decimal('96.00'), 3),
#  ('Saint Martin (French Part)', 2017, Decimal('100.00'), 1),
#  ('Saint Martin (French Part)', 2018, Decimal('100.00'), 1),
#  ('Saint Martin (French Part)', 2019, Decimal('100.00'), 1),
#  ('Saint Martin (French Part)', 2020, Decimal('100.00'), 1),
#  ('Saint Martin (French Part)', 2016, Decimal('100.00'), 1),
#  ('Saint Martin (French Part)', 2015, Decimal('100.00'), 1),
#  ('Saint Pierre and Miquelon', 2015, Decimal('91.00'), 1),
#  ('Saint Pierre and Miquelon', 2020, Decimal('91.00'), 1),
#  ('Saint Pierre and Miquelon', 2019, Decimal('91.00'), 1),
#  ('Saint Pierre and Miquelon', 2018, Decimal('91.00'), 1),
#  ('Saint Pierre and Miquelon', 2017, Decimal('91.00'), 1),
#  ('Saint Pierre and Miquelon', 2016, Decimal('91.00'), 1),
#  ('Saint Vincent and the Grenadines', 2018, Decimal('95.00'), 1),
#  ('Saint Vincent and the Grenadines', 2015, Decimal('95.00'), 1),
#  ('Saint Vincent and the Grenadines', 2017, Decimal('95.00'), 1),
#  ('Saint Vincent and the Grenadines', 2016, Decimal('95.00'), 1),
#  ('Samoa', 2018, Decimal('92.00'), 1),
#  ('Samoa', 2016, Decimal('92.00'), 1),
#  ('Samoa', 2017, Decimal('92.00'), 1),
#  ('Samoa', 2019, Decimal('92.00'), 1),
#  ('Samoa', 2020, Decimal('92.00'), 1),
#  ('Samoa', 2015, Decimal('91.00'), 2),
#  ('Sao Tome and Principe', 2020, Decimal('77.33'), 1),
#  ('Sao Tome and Principe', 2019, Decimal('77.33'), 1),
#  ('Sao Tome and Principe', 2017, Decimal('77.00'), 2),
#  ('Sao Tome and Principe', 2018, Decimal('77.00'), 2),
#  ('Sao Tome and Principe', 2016, Decimal('76.67'), 3),
#  ('Sao Tome and Principe', 2015, Decimal('76.00'), 4),
#  ('Saudi Arabia', 2018, Decimal('100.00'), 1),
#  ('Saudi Arabia', 2020, Decimal('100.00'), 1),
#  ('Saudi Arabia', 2019, Decimal('100.00'), 1),
#  ('Saudi Arabia', 2017, Decimal('100.00'), 1),
#  ('Saudi Arabia', 2016, Decimal('100.00'), 1),
#  ('Saudi Arabia', 2015, Decimal('100.00'), 1),
#  ('Senegal', 2020, Decimal('85.00'), 1),
#  ('Senegal', 2019, Decimal('84.00'), 2),
#  ('Senegal', 2018, Decimal('82.67'), 3),
#  ('Senegal', 2017, Decimal('81.67'), 4),
#  ('Senegal', 2016, Decimal('80.67'), 5),
#  ('Senegal', 2015, Decimal('79.67'), 6),
#  ('Seychelles', 2019, Decimal('97.00'), 1),
#  ('Seychelles', 2016, Decimal('96.00'), 2),
#  ('Seychelles', 2018, Decimal('96.00'), 2),
#  ('Seychelles', 2015, Decimal('96.00'), 2),
#  ('Seychelles', 2017, Decimal('96.00'), 2),
#  ('Sierra Leone', 2020, Decimal('65.00'), 1),
#  ('Sierra Leone', 2019, Decimal('64.00'), 2),
#  ('Sierra Leone', 2018, Decimal('62.67'), 3),
#  ('Sierra Leone', 2017, Decimal('61.67'), 4),
#  ('Sierra Leone', 2016, Decimal('60.67'), 5),
#  ('Sierra Leone', 2015, Decimal('60.00'), 6),
#  ('Singapore', 2015, Decimal('100.00'), 1),
#  ('Singapore', 2018, Decimal('100.00'), 1),
#  ('Singapore', 2017, Decimal('100.00'), 1),
#  ('Singapore', 2019, Decimal('100.00'), 1),
#  ('Singapore', 2020, Decimal('100.00'), 1),
#  ('Singapore', 2016, Decimal('100.00'), 1),
#  ('Sint Maarten (Dutch part)', 2016, Decimal('95.00'), 1),
#  ('Sint Maarten (Dutch part)', 2017, Decimal('95.00'), 1),
#  ('Sint Maarten (Dutch part)', 2015, Decimal('95.00'), 1),
#  ('Solomon Islands', 2015, Decimal('74.33'), 1),
#  ('Solomon Islands', 2016, Decimal('74.00'), 2),
#  ('Solomon Islands', 2017, Decimal('73.33'), 3),
#  ('Solomon Islands', 2020, Decimal('72.33'), 4),
#  ('Solomon Islands', 2018, Decimal('72.33'), 4),
#  ('Solomon Islands', 2019, Decimal('72.33'), 4),
#  ('Somalia', 2020, Decimal('57.33'), 1),
#  ('Somalia', 2019, Decimal('56.33'), 2),
#  ('Somalia', 2018, Decimal('54.67'), 3),
#  ('Somalia', 2017, Decimal('53.33'), 4),
#  ('Somalia', 2016, Decimal('52.00'), 5),
#  ('Somalia', 2015, Decimal('50.67'), 6),
#  ('South Africa', 2020, Decimal('92.00'), 1),
#  ('South Africa', 2019, Decimal('91.67'), 2),
#  ('South Africa', 2018, Decimal('91.33'), 3),
#  ('South Africa', 2017, Decimal('91.00'), 4),
#  ('South Africa', 2016, Decimal('90.33'), 5),
#  ('South Africa', 2015, Decimal('90.00'), 6),
#  ('South Sudan', 2020, Decimal('48.33'), 1),
#  ('South Sudan', 2019, Decimal('48.33'), 1),
#  ('South Sudan', 2018, Decimal('47.67'), 2),
#  ('South Sudan', 2017, Decimal('47.00'), 3),
#  ('South Sudan', 2016, Decimal('46.67'), 4),
#  ('South Sudan', 2015, Decimal('46.33'), 5),
#  ('Sri Lanka', 2020, Decimal('94.33'), 1),
#  ('Sri Lanka', 2019, Decimal('94.33'), 1),
#  ('Sri Lanka', 2018, Decimal('94.33'), 1),
#  ('Sri Lanka', 2017, Decimal('93.67'), 2),
#  ('Sri Lanka', 2016, Decimal('93.00'), 3),
#  ('Sri Lanka', 2015, Decimal('92.00'), 4),
#  ('State of Palestine', 2020, Decimal('98.33'), 1),
#  ('State of Palestine', 2019, Decimal('97.67'), 2),
#  ('State of Palestine', 2017, Decimal('97.00'), 3),
#  ('State of Palestine', 2018, Decimal('97.00'), 3),
#  ('State of Palestine', 2016, Decimal('96.67'), 4),
#  ('State of Palestine', 2015, Decimal('96.00'), 5),
#  ('Sudan', 2018, Decimal('62.33'), 1),
#  ('Sudan', 2017, Decimal('62.33'), 1),
#  ('Sudan', 2019, Decimal('62.33'), 1),
#  ('Sudan', 2020, Decimal('62.33'), 1),
#  ('Sudan', 2016, Decimal('62.33'), 1),
#  ('Sudan', 2015, Decimal('61.33'), 2),
#  ('Suriname', 2020, Decimal('98.00'), 1),
#  ('Suriname', 2019, Decimal('97.33'), 2),
#  ('Suriname', 2018, Decimal('96.67'), 3),
#  ('Suriname', 2017, Decimal('96.33'), 4),
#  ('Suriname', 2016, Decimal('95.33'), 5),
#  ('Suriname', 2015, Decimal('95.00'), 6),
#  ('Syrian Arab Republic', 2016, Decimal('93.67'), 1),
#  ('Syrian Arab Republic', 2017, Decimal('93.67'), 1),
#  ('Syrian Arab Republic', 2018, Decimal('93.67'), 1),
#  ('Syrian Arab Republic', 2019, Decimal('93.67'), 1),
#  ('Syrian Arab Republic', 2020, Decimal('93.67'), 1),
#  ('Syrian Arab Republic', 2015, Decimal('93.33'), 2),
#  ('Tajikistan', 2020, Decimal('85.00'), 1),
#  ('Tajikistan', 2019, Decimal('85.00'), 1),
#  ('Tajikistan', 2018, Decimal('83.33'), 2),
#  ('Tajikistan', 2017, Decimal('82.33'), 3),
#  ('Tajikistan', 2016, Decimal('81.33'), 4),
#  ('Tajikistan', 2015, Decimal('80.33'), 5),
#  ('Thailand', 2020, Decimal('100.00'), 1),
#  ('Thailand', 2019, Decimal('100.00'), 1),
#  ('Thailand', 2018, Decimal('100.00'), 1),
#  ('Thailand', 2017, Decimal('100.00'), 1),
#  ('Thailand', 2016, Decimal('99.33'), 2),
#  ('Thailand', 2015, Decimal('99.33'), 2),
#  ('Timor-Leste', 2020, Decimal('87.00'), 1),
#  ('Timor-Leste', 2019, Decimal('86.00'), 2),
#  ('Timor-Leste', 2018, Decimal('84.33'), 3),
#  ('Timor-Leste', 2017, Decimal('82.33'), 4),
#  ('Timor-Leste', 2016, Decimal('80.67'), 5),
#  ('Timor-Leste', 2015, Decimal('78.00'), 6),
#  ('Togo', 2020, Decimal('70.67'), 1),
#  ('Togo', 2019, Decimal('70.33'), 2),
#  ('Togo', 2018, Decimal('69.33'), 3),
#  ('Togo', 2017, Decimal('68.33'), 4),
#  ('Togo', 2016, Decimal('67.33'), 5),
#  ('Togo', 2015, Decimal('66.33'), 6),
#  ('Tokelau', 2020, Decimal('100.00'), 1),
#  ('Tokelau', 2018, Decimal('100.00'), 1),
#  ('Tokelau', 2016, Decimal('100.00'), 1),
#  ('Tokelau', 2017, Decimal('100.00'), 1),
#  ('Tokelau', 2019, Decimal('100.00'), 1),
#  ('Tokelau', 2015, Decimal('99.00'), 2),
#  ('Tonga', 2020, Decimal('99.00'), 1),
#  ('Tonga', 2018, Decimal('98.67'), 2),
#  ('Tonga', 2019, Decimal('98.67'), 2),
#  ('Tonga', 2015, Decimal('98.67'), 2),
#  ('Tonga', 2016, Decimal('98.67'), 2),
#  ('Tonga', 2017, Decimal('98.67'), 2),
#  ('Trinidad and Tobago', 2017, Decimal('99.00'), 1),
#  ('Trinidad and Tobago', 2016, Decimal('99.00'), 1),
#  ('Trinidad and Tobago', 2019, Decimal('99.00'), 1),
#  ('Trinidad and Tobago', 2018, Decimal('99.00'), 1),
#  ('Trinidad and Tobago', 2020, Decimal('99.00'), 1),
#  ('Trinidad and Tobago', 2015, Decimal('98.00'), 2),
#  ('Tunisia', 2020, Decimal('97.00'), 1),
#  ('Tunisia', 2019, Decimal('96.00'), 2),
#  ('Tunisia', 2018, Decimal('95.67'), 3),
#  ('Tunisia', 2017, Decimal('94.67'), 4),
#  ('Tunisia', 2016, Decimal('93.67'), 5),
#  ('Tunisia', 2015, Decimal('93.33'), 6),
#  ('Türkiye', 2020, Decimal('96.67'), 1),
#  ('Türkiye', 2019, Decimal('96.67'), 1),
#  ('Türkiye', 2018, Decimal('96.33'), 2),
#  ('Türkiye', 2017, Decimal('96.33'), 2),
#  ('Türkiye', 2016, Decimal('96.00'), 3),
#  ('Türkiye', 2015, Decimal('95.67'), 4),
#  ('Turkmenistan', 2019, Decimal('100.00'), 1),
#  ('Turkmenistan', 2020, Decimal('100.00'), 1),
#  ('Turkmenistan', 2018, Decimal('99.33'), 2),
#  ('Turkmenistan', 2017, Decimal('98.67'), 3),
#  ('Turkmenistan', 2016, Decimal('98.00'), 4),
#  ('Turkmenistan', 2015, Decimal('97.67'), 5),
#  ('Turks and Caicos Islands', 2016, Decimal('94.00'), 1),
#  ('Turks and Caicos Islands', 2017, Decimal('94.00'), 1),
#  ('Turks and Caicos Islands', 2018, Decimal('94.00'), 1),
#  ('Turks and Caicos Islands', 2015, Decimal('94.00'), 1),
#  ('Tuvalu', 2019, Decimal('100.00'), 1),
#  ('Tuvalu', 2020, Decimal('100.00'), 1),
#  ('Tuvalu', 2017, Decimal('100.00'), 1),
#  ('Tuvalu', 2018, Decimal('100.00'), 1),
#  ('Tuvalu', 2015, Decimal('100.00'), 1),
#  ('Tuvalu', 2016, Decimal('100.00'), 1),
#  ('Uganda', 2020, Decimal('61.00'), 1),
#  ('Uganda', 2019, Decimal('59.33'), 2),
#  ('Uganda', 2018, Decimal('58.67'), 3),
#  ('Uganda', 2017, Decimal('57.00'), 4),
#  ('Uganda', 2016, Decimal('55.67'), 5),
#  ('Uganda', 2015, Decimal('55.00'), 6),
#  ('United Arab Emirates', 2015, Decimal('100.00'), 1),
#  ('United Arab Emirates', 2017, Decimal('100.00'), 1),
#  ('United Arab Emirates', 2018, Decimal('100.00'), 1),
#  ('United Arab Emirates', 2020, Decimal('100.00'), 1),
#  ('United Arab Emirates', 2019, Decimal('100.00'), 1),
#  ('United Arab Emirates', 2016, Decimal('100.00'), 1),
#  ('United Republic of Tanzania', 2020, Decimal('65.00'), 1),
#  ('United Republic of Tanzania', 2019, Decimal('64.67'), 2),
#  ('United Republic of Tanzania', 2018, Decimal('63.33'), 3),
#  ('United Republic of Tanzania', 2017, Decimal('61.67'), 4),
#  ('United Republic of Tanzania', 2016, Decimal('60.00'), 5),
#  ('United Republic of Tanzania', 2015, Decimal('58.33'), 6),
#  ('United States of America', 2020, Decimal('100.00'), 1),
#  ('United States of America', 2017, Decimal('99.67'), 2),
#  ('United States of America', 2018, Decimal('99.67'), 2),
#  ('United States of America', 2019, Decimal('99.67'), 2),
#  ('United States of America', 2016, Decimal('99.33'), 3),
#  ('United States of America', 2015, Decimal('99.00'), 4),
#  ('United States Virgin Islands', 2019, Decimal('99.00'), 1),
#  ('United States Virgin Islands', 2018, Decimal('99.00'), 1),
#  ('United States Virgin Islands', 2017, Decimal('99.00'), 1),
#  ('United States Virgin Islands', 2016, Decimal('99.00'), 1),
#  ('United States Virgin Islands', 2015, Decimal('99.00'), 1),
#  ('United States Virgin Islands', 2020, Decimal('99.00'), 1),
#  ('Uruguay', 2017, Decimal('98.00'), 1),
#  ('Uruguay', 2018, Decimal('98.00'), 1),
#  ('Uruguay', 2019, Decimal('98.00'), 1),
#  ('Uruguay', 2020, Decimal('98.00'), 1),
#  ('Uruguay', 2016, Decimal('97.33'), 2),
#  ('Uruguay', 2015, Decimal('96.67'), 3),
#  ...]

# %% [markdown]
# ### 2. Assess the rankings for countries with the same water level access in a given year.
#
# We expect countries with the same water level access in a given year to have the same rank since they are exactly the same value. Let us assess whether this is the case by filtering our results such that only records with 100% water level access are retrieved.

# %%
# %%sql
# # Add your code here
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     ROW_NUMBER() OVER (PARTITION BY Country_name ORDER BY Time_period DESC) AS Rank_water_access
# FROM
#     united_nations.Access_to_Basic_Services
# WHERE
#     Pct_managed_drinking_water_services = 100;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 208 rows affected.
# [('American Samoa', 2020, Decimal('100.00'), 1),
#  ('American Samoa', 2019, Decimal('100.00'), 2),
#  ('American Samoa', 2018, Decimal('100.00'), 3),
#  ('American Samoa', 2017, Decimal('100.00'), 4),
#  ('American Samoa', 2016, Decimal('100.00'), 5),
#  ('American Samoa', 2015, Decimal('100.00'), 6),
#  ('Argentina', 2020, Decimal('100.00'), 1),
#  ('Argentina', 2019, Decimal('100.00'), 2),
#  ('Argentina', 2018, Decimal('100.00'), 3),
#  ('Argentina', 2017, Decimal('100.00'), 4),
#  ('Armenia', 2020, Decimal('100.00'), 1),
#  ('Armenia', 2019, Decimal('100.00'), 2),
#  ('Armenia', 2018, Decimal('100.00'), 3),
#  ('Armenia', 2017, Decimal('100.00'), 4),
#  ('Australia', 2020, Decimal('100.00'), 1),
#  ('Australia', 2019, Decimal('100.00'), 2),
#  ('Australia', 2018, Decimal('100.00'), 3),
#  ('Australia', 2017, Decimal('100.00'), 4),
#  ('Australia', 2016, Decimal('100.00'), 5),
#  ('Australia', 2015, Decimal('100.00'), 6),
#  ('Bahrain', 2020, Decimal('100.00'), 1),
#  ('Bahrain', 2019, Decimal('100.00'), 2),
#  ('Bahrain', 2018, Decimal('100.00'), 3),
#  ('Bahrain', 2017, Decimal('100.00'), 4),
#  ('Bahrain', 2016, Decimal('100.00'), 5),
#  ('Bahrain', 2015, Decimal('100.00'), 6),
#  ('Bermuda', 2020, Decimal('100.00'), 1),
#  ('Bermuda', 2019, Decimal('100.00'), 2),
#  ('Bermuda', 2018, Decimal('100.00'), 3),
#  ('Bermuda', 2017, Decimal('100.00'), 4),
#  ('Bermuda', 2016, Decimal('100.00'), 5),
#  ('Bermuda', 2015, Decimal('100.00'), 6),
#  ('British Virgin Islands', 2020, Decimal('100.00'), 1),
#  ('British Virgin Islands', 2019, Decimal('100.00'), 2),
#  ('British Virgin Islands', 2018, Decimal('100.00'), 3),
#  ('British Virgin Islands', 2017, Decimal('100.00'), 4),
#  ('British Virgin Islands', 2016, Decimal('100.00'), 5),
#  ('British Virgin Islands', 2015, Decimal('100.00'), 6),
#  ('Brunei Darussalam', 2020, Decimal('100.00'), 1),
#  ('Brunei Darussalam', 2019, Decimal('100.00'), 2),
#  ('Brunei Darussalam', 2018, Decimal('100.00'), 3),
#  ('Brunei Darussalam', 2017, Decimal('100.00'), 4),
#  ('Brunei Darussalam', 2016, Decimal('100.00'), 5),
#  ('Chile', 2020, Decimal('100.00'), 1),
#  ('Chile', 2019, Decimal('100.00'), 2),
#  ('Chile', 2018, Decimal('100.00'), 3),
#  ('Chile', 2017, Decimal('100.00'), 4),
#  ('Cook Islands', 2020, Decimal('100.00'), 1),
#  ('Cook Islands', 2019, Decimal('100.00'), 2),
#  ('Cook Islands', 2018, Decimal('100.00'), 3),
#  ('Cook Islands', 2017, Decimal('100.00'), 4),
#  ('Cook Islands', 2016, Decimal('100.00'), 5),
#  ('Cook Islands', 2015, Decimal('100.00'), 6),
#  ('Costa Rica', 2020, Decimal('100.00'), 1),
#  ('Costa Rica', 2019, Decimal('100.00'), 2),
#  ('Costa Rica', 2018, Decimal('100.00'), 3),
#  ('Costa Rica', 2017, Decimal('100.00'), 4),
#  ('Cyprus', 2020, Decimal('100.00'), 1),
#  ('Cyprus', 2019, Decimal('100.00'), 2),
#  ('Cyprus', 2018, Decimal('100.00'), 3),
#  ('Cyprus', 2017, Decimal('100.00'), 4),
#  ('Cyprus', 2016, Decimal('100.00'), 5),
#  ('Cyprus', 2015, Decimal('100.00'), 6),
#  ('French Polynesia', 2020, Decimal('100.00'), 1),
#  ('French Polynesia', 2019, Decimal('100.00'), 2),
#  ('French Polynesia', 2018, Decimal('100.00'), 3),
#  ('French Polynesia', 2017, Decimal('100.00'), 4),
#  ('French Polynesia', 2016, Decimal('100.00'), 5),
#  ('French Polynesia', 2015, Decimal('100.00'), 6),
#  ('Greenland', 2020, Decimal('100.00'), 1),
#  ('Greenland', 2019, Decimal('100.00'), 2),
#  ('Greenland', 2018, Decimal('100.00'), 3),
#  ('Greenland', 2017, Decimal('100.00'), 4),
#  ('Greenland', 2016, Decimal('100.00'), 5),
#  ('Greenland', 2015, Decimal('100.00'), 6),
#  ('Guadeloupe', 2020, Decimal('100.00'), 1),
#  ('Guadeloupe', 2019, Decimal('100.00'), 2),
#  ('Guadeloupe', 2018, Decimal('100.00'), 3),
#  ('Guadeloupe', 2017, Decimal('100.00'), 4),
#  ('Guadeloupe', 2016, Decimal('100.00'), 5),
#  ('Guadeloupe', 2015, Decimal('100.00'), 6),
#  ('Guam', 2020, Decimal('100.00'), 1),
#  ('Guam', 2019, Decimal('100.00'), 2),
#  ('Guam', 2018, Decimal('100.00'), 3),
#  ('Guam', 2017, Decimal('100.00'), 4),
#  ('Guam', 2016, Decimal('100.00'), 5),
#  ('Guam', 2015, Decimal('100.00'), 6),
#  ('Israel', 2020, Decimal('100.00'), 1),
#  ('Israel', 2019, Decimal('100.00'), 2),
#  ('Israel', 2018, Decimal('100.00'), 3),
#  ('Israel', 2017, Decimal('100.00'), 4),
#  ('Israel', 2016, Decimal('100.00'), 5),
#  ('Israel', 2015, Decimal('100.00'), 6),
#  ('Kuwait', 2020, Decimal('100.00'), 1),
#  ('Kuwait', 2019, Decimal('100.00'), 2),
#  ('Kuwait', 2018, Decimal('100.00'), 3),
#  ('Kuwait', 2017, Decimal('100.00'), 4),
#  ('Kuwait', 2016, Decimal('100.00'), 5),
#  ('Kuwait', 2015, Decimal('100.00'), 6),
#  ('Libya', 2020, Decimal('100.00'), 1),
#  ('Libya', 2019, Decimal('100.00'), 2),
#  ('Libya', 2018, Decimal('100.00'), 3),
#  ('Martinique', 2020, Decimal('100.00'), 1),
#  ('Martinique', 2019, Decimal('100.00'), 2),
#  ('Martinique', 2018, Decimal('100.00'), 3),
#  ('Martinique', 2017, Decimal('100.00'), 4),
#  ('Martinique', 2016, Decimal('100.00'), 5),
#  ('Martinique', 2015, Decimal('100.00'), 6),
#  ('Mauritius', 2020, Decimal('100.00'), 1),
#  ('Mauritius', 2019, Decimal('100.00'), 2),
#  ('Mauritius', 2018, Decimal('100.00'), 3),
#  ('Mauritius', 2017, Decimal('100.00'), 4),
#  ('Mauritius', 2016, Decimal('100.00'), 5),
#  ('Mauritius', 2015, Decimal('100.00'), 6),
#  ('Nauru', 2020, Decimal('100.00'), 1),
#  ('Nauru', 2019, Decimal('100.00'), 2),
#  ('Nauru', 2018, Decimal('100.00'), 3),
#  ('Nauru', 2017, Decimal('100.00'), 4),
#  ('Nauru', 2016, Decimal('100.00'), 5),
#  ('Nauru', 2015, Decimal('100.00'), 6),
#  ('New Zealand', 2020, Decimal('100.00'), 1),
#  ('New Zealand', 2019, Decimal('100.00'), 2),
#  ('New Zealand', 2018, Decimal('100.00'), 3),
#  ('New Zealand', 2017, Decimal('100.00'), 4),
#  ('New Zealand', 2016, Decimal('100.00'), 5),
#  ('New Zealand', 2015, Decimal('100.00'), 6),
#  ('Northern Mariana Islands', 2020, Decimal('100.00'), 1),
#  ('Northern Mariana Islands', 2019, Decimal('100.00'), 2),
#  ('Northern Mariana Islands', 2018, Decimal('100.00'), 3),
#  ('Northern Mariana Islands', 2017, Decimal('100.00'), 4),
#  ('Northern Mariana Islands', 2016, Decimal('100.00'), 5),
#  ('Northern Mariana Islands', 2015, Decimal('100.00'), 6),
#  ('Palau', 2020, Decimal('100.00'), 1),
#  ('Palau', 2019, Decimal('100.00'), 2),
#  ('Palau', 2018, Decimal('100.00'), 3),
#  ('Palau', 2017, Decimal('100.00'), 4),
#  ('Palau', 2016, Decimal('100.00'), 5),
#  ('Palau', 2015, Decimal('100.00'), 6),
#  ('Puerto Rico', 2020, Decimal('100.00'), 1),
#  ('Puerto Rico', 2019, Decimal('100.00'), 2),
#  ('Puerto Rico', 2018, Decimal('100.00'), 3),
#  ('Puerto Rico', 2017, Decimal('100.00'), 4),
#  ('Puerto Rico', 2016, Decimal('100.00'), 5),
#  ('Qatar', 2020, Decimal('100.00'), 1),
#  ('Qatar', 2019, Decimal('100.00'), 2),
#  ('Qatar', 2018, Decimal('100.00'), 3),
#  ('Qatar', 2017, Decimal('100.00'), 4),
#  ('Qatar', 2016, Decimal('100.00'), 5),
#  ('Qatar', 2015, Decimal('100.00'), 6),
#  ('Republic of Korea', 2020, Decimal('100.00'), 1),
#  ('Republic of Korea', 2019, Decimal('100.00'), 2),
#  ('Republic of Korea', 2018, Decimal('100.00'), 3),
#  ('Republic of Korea', 2017, Decimal('100.00'), 4),
#  ('Republic of Korea', 2016, Decimal('100.00'), 5),
#  ('Réunion', 2020, Decimal('100.00'), 1),
#  ('Réunion', 2019, Decimal('100.00'), 2),
#  ('Réunion', 2018, Decimal('100.00'), 3),
#  ('Réunion', 2017, Decimal('100.00'), 4),
#  ('Réunion', 2016, Decimal('100.00'), 5),
#  ('Réunion', 2015, Decimal('100.00'), 6),
#  ('Saint Barthélemy', 2020, Decimal('100.00'), 1),
#  ('Saint Barthélemy', 2019, Decimal('100.00'), 2),
#  ('Saint Barthélemy', 2018, Decimal('100.00'), 3),
#  ('Saint Barthélemy', 2017, Decimal('100.00'), 4),
#  ('Saint Barthélemy', 2016, Decimal('100.00'), 5),
#  ('Saint Barthélemy', 2015, Decimal('100.00'), 6),
#  ('Saint Martin (French Part)', 2020, Decimal('100.00'), 1),
#  ('Saint Martin (French Part)', 2019, Decimal('100.00'), 2),
#  ('Saint Martin (French Part)', 2018, Decimal('100.00'), 3),
#  ('Saint Martin (French Part)', 2017, Decimal('100.00'), 4),
#  ('Saint Martin (French Part)', 2016, Decimal('100.00'), 5),
#  ('Saint Martin (French Part)', 2015, Decimal('100.00'), 6),
#  ('Saudi Arabia', 2020, Decimal('100.00'), 1),
#  ('Saudi Arabia', 2019, Decimal('100.00'), 2),
#  ('Saudi Arabia', 2018, Decimal('100.00'), 3),
#  ('Saudi Arabia', 2017, Decimal('100.00'), 4),
#  ('Saudi Arabia', 2016, Decimal('100.00'), 5),
#  ('Saudi Arabia', 2015, Decimal('100.00'), 6),
#  ('Singapore', 2020, Decimal('100.00'), 1),
#  ('Singapore', 2019, Decimal('100.00'), 2),
#  ('Singapore', 2018, Decimal('100.00'), 3),
#  ('Singapore', 2017, Decimal('100.00'), 4),
#  ('Singapore', 2016, Decimal('100.00'), 5),
#  ('Singapore', 2015, Decimal('100.00'), 6),
#  ('Thailand', 2020, Decimal('100.00'), 1),
#  ('Thailand', 2019, Decimal('100.00'), 2),
#  ('Thailand', 2018, Decimal('100.00'), 3),
#  ('Thailand', 2017, Decimal('100.00'), 4),
#  ('Tokelau', 2020, Decimal('100.00'), 1),
#  ('Tokelau', 2019, Decimal('100.00'), 2),
#  ('Tokelau', 2018, Decimal('100.00'), 3),
#  ('Tokelau', 2017, Decimal('100.00'), 4),
#  ('Tokelau', 2016, Decimal('100.00'), 5),
#  ('Turkmenistan', 2020, Decimal('100.00'), 1),
#  ('Turkmenistan', 2019, Decimal('100.00'), 2),
#  ('Tuvalu', 2020, Decimal('100.00'), 1),
#  ('Tuvalu', 2019, Decimal('100.00'), 2),
#  ('Tuvalu', 2018, Decimal('100.00'), 3),
#  ('Tuvalu', 2017, Decimal('100.00'), 4),
#  ('Tuvalu', 2016, Decimal('100.00'), 5),
#  ('Tuvalu', 2015, Decimal('100.00'), 6),
#  ('United Arab Emirates', 2020, Decimal('100.00'), 1),
#  ('United Arab Emirates', 2019, Decimal('100.00'), 2),
#  ('United Arab Emirates', 2018, Decimal('100.00'), 3),
#  ('United Arab Emirates', 2017, Decimal('100.00'), 4),
#  ('United Arab Emirates', 2016, Decimal('100.00'), 5),
#  ('United Arab Emirates', 2015, Decimal('100.00'), 6),
#  ('United States of America', 2020, Decimal('100.00'), 1)]

# %% [markdown]
# ### 3. Apply the `RANK` function instead.
#
# Replace the ranking function used in Exercise 1 with the `RANK()` function, and observe how the results differ.

# %%
# %%sql
# # Add your code here
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     RANK() OVER (PARTITION BY Country_name ORDER BY Pct_managed_drinking_water_services desc) AS Rank_water_access
# FROM
#     united_nations.Access_to_Basic_Services
# WHERE
#     Pct_managed_drinking_water_services = 100;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 208 rows affected.
# [('American Samoa', 2020, Decimal('100.00'), 1),
#  ('American Samoa', 2019, Decimal('100.00'), 1),
#  ('American Samoa', 2018, Decimal('100.00'), 1),
#  ('American Samoa', 2017, Decimal('100.00'), 1),
#  ('American Samoa', 2016, Decimal('100.00'), 1),
#  ('American Samoa', 2015, Decimal('100.00'), 1),
#  ('Argentina', 2020, Decimal('100.00'), 1),
#  ('Argentina', 2019, Decimal('100.00'), 1),
#  ('Argentina', 2018, Decimal('100.00'), 1),
#  ('Argentina', 2017, Decimal('100.00'), 1),
#  ('Armenia', 2020, Decimal('100.00'), 1),
#  ('Armenia', 2019, Decimal('100.00'), 1),
#  ('Armenia', 2018, Decimal('100.00'), 1),
#  ('Armenia', 2017, Decimal('100.00'), 1),
#  ('Australia', 2015, Decimal('100.00'), 1),
#  ('Australia', 2016, Decimal('100.00'), 1),
#  ('Australia', 2017, Decimal('100.00'), 1),
#  ('Australia', 2018, Decimal('100.00'), 1),
#  ('Australia', 2019, Decimal('100.00'), 1),
#  ('Australia', 2020, Decimal('100.00'), 1),
#  ('Bahrain', 2020, Decimal('100.00'), 1),
#  ('Bahrain', 2019, Decimal('100.00'), 1),
#  ('Bahrain', 2018, Decimal('100.00'), 1),
#  ('Bahrain', 2017, Decimal('100.00'), 1),
#  ('Bahrain', 2016, Decimal('100.00'), 1),
#  ('Bahrain', 2015, Decimal('100.00'), 1),
#  ('Bermuda', 2019, Decimal('100.00'), 1),
#  ('Bermuda', 2016, Decimal('100.00'), 1),
#  ('Bermuda', 2020, Decimal('100.00'), 1),
#  ('Bermuda', 2018, Decimal('100.00'), 1),
#  ('Bermuda', 2017, Decimal('100.00'), 1),
#  ('Bermuda', 2015, Decimal('100.00'), 1),
#  ('British Virgin Islands', 2015, Decimal('100.00'), 1),
#  ('British Virgin Islands', 2016, Decimal('100.00'), 1),
#  ('British Virgin Islands', 2017, Decimal('100.00'), 1),
#  ('British Virgin Islands', 2018, Decimal('100.00'), 1),
#  ('British Virgin Islands', 2019, Decimal('100.00'), 1),
#  ('British Virgin Islands', 2020, Decimal('100.00'), 1),
#  ('Brunei Darussalam', 2018, Decimal('100.00'), 1),
#  ('Brunei Darussalam', 2016, Decimal('100.00'), 1),
#  ('Brunei Darussalam', 2017, Decimal('100.00'), 1),
#  ('Brunei Darussalam', 2019, Decimal('100.00'), 1),
#  ('Brunei Darussalam', 2020, Decimal('100.00'), 1),
#  ('Chile', 2020, Decimal('100.00'), 1),
#  ('Chile', 2019, Decimal('100.00'), 1),
#  ('Chile', 2018, Decimal('100.00'), 1),
#  ('Chile', 2017, Decimal('100.00'), 1),
#  ('Cook Islands', 2020, Decimal('100.00'), 1),
#  ('Cook Islands', 2019, Decimal('100.00'), 1),
#  ('Cook Islands', 2018, Decimal('100.00'), 1),
#  ('Cook Islands', 2017, Decimal('100.00'), 1),
#  ('Cook Islands', 2015, Decimal('100.00'), 1),
#  ('Cook Islands', 2016, Decimal('100.00'), 1),
#  ('Costa Rica', 2020, Decimal('100.00'), 1),
#  ('Costa Rica', 2019, Decimal('100.00'), 1),
#  ('Costa Rica', 2018, Decimal('100.00'), 1),
#  ('Costa Rica', 2017, Decimal('100.00'), 1),
#  ('Cyprus', 2018, Decimal('100.00'), 1),
#  ('Cyprus', 2017, Decimal('100.00'), 1),
#  ('Cyprus', 2016, Decimal('100.00'), 1),
#  ('Cyprus', 2015, Decimal('100.00'), 1),
#  ('Cyprus', 2020, Decimal('100.00'), 1),
#  ('Cyprus', 2019, Decimal('100.00'), 1),
#  ('French Polynesia', 2015, Decimal('100.00'), 1),
#  ('French Polynesia', 2016, Decimal('100.00'), 1),
#  ('French Polynesia', 2017, Decimal('100.00'), 1),
#  ('French Polynesia', 2019, Decimal('100.00'), 1),
#  ('French Polynesia', 2020, Decimal('100.00'), 1),
#  ('French Polynesia', 2018, Decimal('100.00'), 1),
#  ('Greenland', 2020, Decimal('100.00'), 1),
#  ('Greenland', 2017, Decimal('100.00'), 1),
#  ('Greenland', 2019, Decimal('100.00'), 1),
#  ('Greenland', 2018, Decimal('100.00'), 1),
#  ('Greenland', 2015, Decimal('100.00'), 1),
#  ('Greenland', 2016, Decimal('100.00'), 1),
#  ('Guadeloupe', 2017, Decimal('100.00'), 1),
#  ('Guadeloupe', 2018, Decimal('100.00'), 1),
#  ('Guadeloupe', 2016, Decimal('100.00'), 1),
#  ('Guadeloupe', 2015, Decimal('100.00'), 1),
#  ('Guadeloupe', 2019, Decimal('100.00'), 1),
#  ('Guadeloupe', 2020, Decimal('100.00'), 1),
#  ('Guam', 2016, Decimal('100.00'), 1),
#  ('Guam', 2017, Decimal('100.00'), 1),
#  ('Guam', 2018, Decimal('100.00'), 1),
#  ('Guam', 2019, Decimal('100.00'), 1),
#  ('Guam', 2020, Decimal('100.00'), 1),
#  ('Guam', 2015, Decimal('100.00'), 1),
#  ('Israel', 2017, Decimal('100.00'), 1),
#  ('Israel', 2015, Decimal('100.00'), 1),
#  ('Israel', 2018, Decimal('100.00'), 1),
#  ('Israel', 2020, Decimal('100.00'), 1),
#  ('Israel', 2019, Decimal('100.00'), 1),
#  ('Israel', 2016, Decimal('100.00'), 1),
#  ('Kuwait', 2016, Decimal('100.00'), 1),
#  ('Kuwait', 2017, Decimal('100.00'), 1),
#  ('Kuwait', 2018, Decimal('100.00'), 1),
#  ('Kuwait', 2019, Decimal('100.00'), 1),
#  ('Kuwait', 2020, Decimal('100.00'), 1),
#  ('Kuwait', 2015, Decimal('100.00'), 1),
#  ('Libya', 2020, Decimal('100.00'), 1),
#  ('Libya', 2019, Decimal('100.00'), 1),
#  ('Libya', 2018, Decimal('100.00'), 1),
#  ('Martinique', 2018, Decimal('100.00'), 1),
#  ('Martinique', 2019, Decimal('100.00'), 1),
#  ('Martinique', 2020, Decimal('100.00'), 1),
#  ('Martinique', 2015, Decimal('100.00'), 1),
#  ('Martinique', 2016, Decimal('100.00'), 1),
#  ('Martinique', 2017, Decimal('100.00'), 1),
#  ('Mauritius', 2020, Decimal('100.00'), 1),
#  ('Mauritius', 2019, Decimal('100.00'), 1),
#  ('Mauritius', 2017, Decimal('100.00'), 1),
#  ('Mauritius', 2016, Decimal('100.00'), 1),
#  ('Mauritius', 2015, Decimal('100.00'), 1),
#  ('Mauritius', 2018, Decimal('100.00'), 1),
#  ('Nauru', 2017, Decimal('100.00'), 1),
#  ('Nauru', 2020, Decimal('100.00'), 1),
#  ('Nauru', 2019, Decimal('100.00'), 1),
#  ('Nauru', 2018, Decimal('100.00'), 1),
#  ('Nauru', 2016, Decimal('100.00'), 1),
#  ('Nauru', 2015, Decimal('100.00'), 1),
#  ('New Zealand', 2016, Decimal('100.00'), 1),
#  ('New Zealand', 2019, Decimal('100.00'), 1),
#  ('New Zealand', 2018, Decimal('100.00'), 1),
#  ('New Zealand', 2017, Decimal('100.00'), 1),
#  ('New Zealand', 2015, Decimal('100.00'), 1),
#  ('New Zealand', 2020, Decimal('100.00'), 1),
#  ('Northern Mariana Islands', 2019, Decimal('100.00'), 1),
#  ('Northern Mariana Islands', 2016, Decimal('100.00'), 1),
#  ('Northern Mariana Islands', 2017, Decimal('100.00'), 1),
#  ('Northern Mariana Islands', 2015, Decimal('100.00'), 1),
#  ('Northern Mariana Islands', 2020, Decimal('100.00'), 1),
#  ('Northern Mariana Islands', 2018, Decimal('100.00'), 1),
#  ('Palau', 2015, Decimal('100.00'), 1),
#  ('Palau', 2020, Decimal('100.00'), 1),
#  ('Palau', 2019, Decimal('100.00'), 1),
#  ('Palau', 2018, Decimal('100.00'), 1),
#  ('Palau', 2016, Decimal('100.00'), 1),
#  ('Palau', 2017, Decimal('100.00'), 1),
#  ('Puerto Rico', 2020, Decimal('100.00'), 1),
#  ('Puerto Rico', 2018, Decimal('100.00'), 1),
#  ('Puerto Rico', 2017, Decimal('100.00'), 1),
#  ('Puerto Rico', 2016, Decimal('100.00'), 1),
#  ('Puerto Rico', 2019, Decimal('100.00'), 1),
#  ('Qatar', 2017, Decimal('100.00'), 1),
#  ('Qatar', 2020, Decimal('100.00'), 1),
#  ('Qatar', 2019, Decimal('100.00'), 1),
#  ('Qatar', 2018, Decimal('100.00'), 1),
#  ('Qatar', 2016, Decimal('100.00'), 1),
#  ('Qatar', 2015, Decimal('100.00'), 1),
#  ('Republic of Korea', 2020, Decimal('100.00'), 1),
#  ('Republic of Korea', 2019, Decimal('100.00'), 1),
#  ('Republic of Korea', 2018, Decimal('100.00'), 1),
#  ('Republic of Korea', 2017, Decimal('100.00'), 1),
#  ('Republic of Korea', 2016, Decimal('100.00'), 1),
#  ('Réunion', 2020, Decimal('100.00'), 1),
#  ('Réunion', 2015, Decimal('100.00'), 1),
#  ('Réunion', 2016, Decimal('100.00'), 1),
#  ('Réunion', 2017, Decimal('100.00'), 1),
#  ('Réunion', 2018, Decimal('100.00'), 1),
#  ('Réunion', 2019, Decimal('100.00'), 1),
#  ('Saint Barthélemy', 2015, Decimal('100.00'), 1),
#  ('Saint Barthélemy', 2016, Decimal('100.00'), 1),
#  ('Saint Barthélemy', 2018, Decimal('100.00'), 1),
#  ('Saint Barthélemy', 2017, Decimal('100.00'), 1),
#  ('Saint Barthélemy', 2019, Decimal('100.00'), 1),
#  ('Saint Barthélemy', 2020, Decimal('100.00'), 1),
#  ('Saint Martin (French Part)', 2018, Decimal('100.00'), 1),
#  ('Saint Martin (French Part)', 2016, Decimal('100.00'), 1),
#  ('Saint Martin (French Part)', 2015, Decimal('100.00'), 1),
#  ('Saint Martin (French Part)', 2017, Decimal('100.00'), 1),
#  ('Saint Martin (French Part)', 2019, Decimal('100.00'), 1),
#  ('Saint Martin (French Part)', 2020, Decimal('100.00'), 1),
#  ('Saudi Arabia', 2016, Decimal('100.00'), 1),
#  ('Saudi Arabia', 2020, Decimal('100.00'), 1),
#  ('Saudi Arabia', 2019, Decimal('100.00'), 1),
#  ('Saudi Arabia', 2018, Decimal('100.00'), 1),
#  ('Saudi Arabia', 2017, Decimal('100.00'), 1),
#  ('Saudi Arabia', 2015, Decimal('100.00'), 1),
#  ('Singapore', 2017, Decimal('100.00'), 1),
#  ('Singapore', 2016, Decimal('100.00'), 1),
#  ('Singapore', 2015, Decimal('100.00'), 1),
#  ('Singapore', 2019, Decimal('100.00'), 1),
#  ('Singapore', 2020, Decimal('100.00'), 1),
#  ('Singapore', 2018, Decimal('100.00'), 1),
#  ('Thailand', 2019, Decimal('100.00'), 1),
#  ('Thailand', 2020, Decimal('100.00'), 1),
#  ('Thailand', 2018, Decimal('100.00'), 1),
#  ('Thailand', 2017, Decimal('100.00'), 1),
#  ('Tokelau', 2016, Decimal('100.00'), 1),
#  ('Tokelau', 2017, Decimal('100.00'), 1),
#  ('Tokelau', 2018, Decimal('100.00'), 1),
#  ('Tokelau', 2019, Decimal('100.00'), 1),
#  ('Tokelau', 2020, Decimal('100.00'), 1),
#  ('Turkmenistan', 2020, Decimal('100.00'), 1),
#  ('Turkmenistan', 2019, Decimal('100.00'), 1),
#  ('Tuvalu', 2015, Decimal('100.00'), 1),
#  ('Tuvalu', 2016, Decimal('100.00'), 1),
#  ('Tuvalu', 2017, Decimal('100.00'), 1),
#  ('Tuvalu', 2018, Decimal('100.00'), 1),
#  ('Tuvalu', 2019, Decimal('100.00'), 1),
#  ('Tuvalu', 2020, Decimal('100.00'), 1),
#  ('United Arab Emirates', 2017, Decimal('100.00'), 1),
#  ('United Arab Emirates', 2015, Decimal('100.00'), 1),
#  ('United Arab Emirates', 2016, Decimal('100.00'), 1),
#  ('United Arab Emirates', 2020, Decimal('100.00'), 1),
#  ('United Arab Emirates', 2019, Decimal('100.00'), 1),
#  ('United Arab Emirates', 2018, Decimal('100.00'), 1),
#  ('United States of America', 2020, Decimal('100.00'), 1)]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Order countries based on their water access levels per year.
# We apply the `ROW_NUMBER` function as follows:
#
# Firstly, this will partition our dataset by year, that is, the `Time_period` column, then order each partition by water access level, that is, the `Percentage of managed drinking water` column, from the lowest to the highest.
#
# Then, the `ROW_NUMBER` function will assign a rank to each row within a year partition based on the resulting order of rows from the `ORDER BY` clause. The results will then be stored in a new column, `Rank_of_water_services`.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     ROW_NUMBER() OVER( PARTITION BY Time_period
#     ORDER BY Pct_managed_drinking_water_services ASC) AS Rank_of_water_services
# FROM
#     united_nations.Access_to_Basic_Services;

# %% [markdown]
# It seems to have worked correctly, seeing that we now have a fourth column which has the ranks for each country based on their water access levels per year, from lowest to highest.

# %% [markdown]
# ### 2.   Assess the rankings for countries with the same water level access in a given year.
#
# Looking at our results, we notice that countries with the same water level access in a given year have different ranks.
#
# To take a closer look, we add a `WHERE` clause that will filter our results such that only records with 100% water level access remain.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     ROW_NUMBER() OVER( PARTITION BY Time_period
#     ORDER BY Pct_managed_drinking_water_services ASC) AS Rank_of_water_services
# FROM
#     united_nations.Access_to_Basic_Services
# WHERE
#     Pct_managed_drinking_water_services = 100;

# %% [markdown]
#  Looking at the year 2016, Korea, Brunei, and Singapore, whose access levels were all 100%, have been ranked differently. This is what `ROW_NUMBER()` does, but we want to rank the countries by access level, and countries that have the same access level should share the rank.

# %% [markdown]
# ### 3. Apply the `RANK` function instead.
#
# We can try to correct this by using the `RANK()` function instead, since it assigns the same rank to similar values.
#
# The following query works the same as the previous one with the `ROW_NUMBER()` function, it's just that we now have the `RANK()` function and rows with the same values will receive the same rank, and the next rank(s) are skipped accordingly.

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     RANK() OVER( PARTITION BY Time_period
#     ORDER BY Pct_managed_drinking_water_services ASC) AS Rank_of_water_services
# FROM
#     united_nations.Access_to_Basic_Services;

# %% [markdown]
# This has worked as expected since we now have the same ranking values for countries with the same water level access in a given year.
#
# We can see that in `2015`, the country with the lowest percentage of managed drinking water services was Afghanistan. Within the same year, we have countries that had the same percentage, such as Nepal and Indonesia, and as a result, they have the same rank, `7`. Due to this, the next rank, `8`, was skipped and the next country, India, given a rank of `9`.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
